# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Apr 19 13:55:28 2023

@author: Saba
"""

import gc
import os
import numpy as np
import pandas as pd
from keras.layers import Conv1D, Conv2D, BatchNormalization, MaxPool1D, MaxPool2D, GlobalMaxPool1D, GlobalMaxPool2D
from keras.layers import TimeDistributed, GRU, Dense, Dropout
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow import keras
from sklearn.metrics import precision_score, recall_score
from keras.models import load_model
from keras.models import Sequential
from sklearn.model_selection import KFold
import matplotlib.lines as mlines
import utm
from collections import Counter
import random
import cv2
import seaborn as sns
import math
import pickle 

np.random.seed(42)
tf.random.set_seed(42)  # Set TensorFlow seed as well
random.seed = 42

#%% Main                
#Score function
def compute_acc(y_pred, y_true, top_k=[1,3,5]):
    """ Computes top-k accuracy given prediction and ground truth labels."""
    n_top_k = len(top_k)
    total_hits = np.zeros(n_top_k)
    
    n_test_samples = len(y_true)
    if len(y_pred) != n_test_samples:
        raise Exception('Number of predicted beams does not match number of labels.')
    
    # For each test sample, count times where true beam is in k top guesses
    for samp_idx in range(len(y_true)):
        for k_idx in range(n_top_k):
            hit = np.any(y_pred[samp_idx,:top_k[k_idx]] == y_true[samp_idx, -1])
            total_hits[k_idx] += 1 if hit else 0
    
    # Average the number of correct guesses (over the total samples)
    return np.round(total_hits / len(y_true), 4)

def save_pred_to_csv(sample_index, y_pred, top_k=[1,2,3], target_csv='beam_pred.csv'):
    """ 
    Saves the predicted beam results to a csv file. 
    Expects y_pred: n_samples x N_BEAMS, and saves the top_k columns only. 
    """
    
    cols = [f'top-{i} beam' for i in top_k]
    df = pd.DataFrame(data=y_pred[:, np.array(top_k)-1], columns=cols)
    df.index.name = 'index'
    df['sample_index'] = sample_index
    df.to_csv(target_csv)

def compute_DBA_score(y_pred, y_true, max_k=3, delta=5):
    """ 
    The top-k MBD (Minimum Beam Distance) as the minimum distance
    of any beam in the top-k set of predicted beams to the ground truth beam. 
    
    Then we take the average across all samples.
    
    Then we average that number over all the considered Ks.
    """
    n_samples = y_pred.shape[0]
    #n_beams = y_pred.shape[-1] 
    
    yk = np.zeros(max_k)
    for k in range(max_k):
        acc_avg_min_beam_dist = 0
        idxs_up_to_k = np.arange(k+1)
        for i in range(n_samples):
            aux1 = np.abs(y_pred[i, idxs_up_to_k] - y_true[i]) / delta
            # Compute min between beam diff and 1
            aux2 = np.min(np.stack((aux1, np.zeros_like(aux1)+1), axis=0), axis=0)
            acc_avg_min_beam_dist += np.min(aux2)
            
        yk[k] = 1 - acc_avg_min_beam_dist / n_samples
    
    return np.mean(yk)

#%% Power factor
def compute_powerfactor(y_pred, pwrs_array, k=3):
    '''
    Calculate the maximum power factor for top-1 to top-k predictions.
    
    Args:
    y_pred (numpy array): Sorted predictions (n_samples, 64), indices of beams sorted by probability.
    pwrs_array (numpy array): Power values for beams (n_samples, 64).
    k (int): The top-k predictions to consider.
    
    Returns:
    numpy array: Array of average max PFs from top-1 to top-k.
    '''
    max_Pr = np.max(pwrs_array, axis=1)  # Maximum power across all beams for each sample
    PF_max_k = np.zeros(k)  # Array to store the average of maximum PFs for each top-k
    #PF_max_k_stds = np.zeros(k)  # Array to store the standard deviation of maximum PFs for each top-k
    
    for i in range(1, k+1):
        max_PF = np.zeros(pwrs_array.shape[0])  # Array to hold the max PF for each sample for current top-i
        for j in range(pwrs_array.shape[0]):  # Iterate over each sample
            # Calculate PFs for the top-i predictions and find the maximum
            top_k_PFs = pwrs_array[j, y_pred[j, :i]] / max_Pr[j]
            max_PF[j] = np.max(top_k_PFs)  # Maximum PF for this sample among top-i
        PF_max_k[i-1] = np.round(np.mean(max_PF), 2)  # Average of maximum PFs across all samples for top-i
        #PF_max_k_stds[i-1] = np.round(np.std(max_PF), 2)  # Standard deviation of maximum PFs for top-i

    return PF_max_k #, PF_max_k_stds

def calculate_top_beams(predictions, truths):
    correct_top1_count = 0
    correct_top3_count = 0
    total_count = len(predictions)  # Assuming predictions and truths are lists of numpy arrays
    
    for pred, true in zip(predictions, truths):
        # Find the index of the highest value in the predicted array
        top_pred_index = np.argmax(pred)
        
        # Find the indices of the top 3 highest values in the true array
        top_true_indices = np.argsort(true)[-3:]
        
        # Check if the top predicted index is among the top 3 true indices for top-1 accuracy
        if top_pred_index in top_true_indices:
            correct_top1_count += 1
        
        # Find the indices of the top 3 highest values in the predicted array
        top_pred_indices = np.argsort(pred)[-3:]
        
        # Check if there is any intersection between the top 3 predicted indices and the top 3 true indices for top-3 accuracy
        if set(top_pred_indices) & set(top_true_indices):
            correct_top3_count += 1
    
    # Calculate the percentage of correct predictions for top-1 and top-3 accuracies
    top1_accuracy = (correct_top1_count / total_count)
    top3_accuracy = (correct_top3_count / total_count) 
    top1_accuracy  = round(top1_accuracy, 2)
    top3_accuracy  = round(top3_accuracy, 2)
    return [top1_accuracy,top3_accuracy]
# Out:
# 2024-08-24 22:38:13.731249: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-24 22:38:13.847406: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-24 22:38:14.372623: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/sa457043/miniconda3/envs/tf_jupyter/lib/:/home/sa457043/lib/python3.10/site-packages/nvidia/cudnn/lib:
# 2024-08-24 22:38:14.372692: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/sa457043/miniconda3/envs/tf_jupyter/lib/:/home/sa457043/lib/python3.10/site-packages/nvidia/cudnn/lib:
# 2024-08-24 22:38:14.372698: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
'''
#%% GPU optimization
#
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
        
#
os.environ["TF_GPU_ALLOCATOR"]="cuda_malloc_async" #to allow automatic assignment of operations to different GPUs to prevent OOM issue
'''   

# Set environment variables to disable GPU usage and use CPU instead
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'  # This line disables GPU

# %%
#%% some global params
model_name = "L_remake_v1_2_multipleRuns"

# %%
#%%Load data
def add_noise(data, noise_level):
    noisy_data = data + np.random.normal(scale=noise_level, size=data.shape)
    return noisy_data

'''
def add_gps_noise(GPS, noise_level):
    GPS_noisy = np.zeros(GPS.shape)
    GPS_noisy[:,:,0] = GPS[:,:,0] + np.random.normal(scale=noise_level, size=GPS[:,:,0].shape)
    GPS_noisy[:,:,1] = GPS[:,:,1] + np.random.normal(scale=noise_level, size=GPS[:,:,1].shape)
    return GPS_noisy
'''

df_train =  pd.read_csv('./ml_challenge_dev_multi_modal_v2.csv')
index = df_train['unit1_beam'].values

imagex = 150
imagey = 150

import cv2
def rescale(data): #to rescale from 11143x5x210x360 to 11143,5,210,225
    resized_data= np.zeros((data.shape[0],5,imagex,imagey))
    for i in range(data.shape[0]):
        for j in range(data.shape[1]):
            resized_data[i, j] = cv2.resize(data[i, j], (imagey, imagex), interpolation=cv2.INTER_NEAREST)
    return resized_data
    
data = np.load('lidar_DepthInten_11143x5x210x360_v2.npz') 
lidar = rescale(data['Lidar'])
print(round(np.min(lidar), 2),round(np.max(lidar), 2))

gc.collect()

classes = to_categorical(df_train['unit1_beam'].values - 1, num_classes = 64, dtype ="int32")
# Out:
# 0.0 225.6

# %%
#%%Model
def build_convnet(shape=(imagex,imagey)):
    momentum = .9

    model = keras.Sequential()
    model.add(Conv1D(16, 3, input_shape=shape,padding='same', activation='relu'))
    model.add(Conv1D(16, (3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    model.add(MaxPool1D(pool_size=3))
    model.add(MaxPool1D(pool_size=3))
    
    model.add(Conv1D(16, 3, padding='same', activation='relu'))
    model.add(Conv1D(16, (3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    model.add(MaxPool1D(pool_size=3))

    model.add(Conv1D(128, 3, padding='same', activation='relu'))
    model.add(Conv1D(128, (3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    model.add(MaxPool1D(pool_size=3))
    
    model.add(Conv1D(256, 3, padding='same', activation='relu'))
    model.add(Conv1D(256, (3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    
    model.add(GlobalMaxPool1D())
    return model

def GRU_model(input_shape=(5,imagex,imagey), nbout=64): 
    # Create our convnet with (112, 112, 3) input shape
    convnet = build_convnet(input_shape[1:])
    
    # then create our final model
    model = keras.Sequential()
    # add the convnet with (5, 128,125,4) shape
    model.add(TimeDistributed(convnet, input_shape=input_shape))
    # here, you can also use GRU or LSTM
    model.add(GRU(64))
    # and finally, we make a decision network
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(.5))

    model.add(Dense(nbout, activation='softmax'))
    return model

# %%
seeds = [42, 123, 456, 789, 101112]

results = []

for seed in seeds:
    print(f"\nRunning model with seed {seed}")

    # Train-Test Split with the current seed
    X_train, X_test, y_train, y_test, train_indices, test_indices = train_test_split(
        lidar, classes, np.arange(len(lidar)), test_size=0.1, stratify=classes, random_state=seed)

    gc.collect()

    #%% Scenarios and LoS NLoS analysis of train and test samples
    df_train = pd.read_csv('./ml_challenge_dev_multi_modal_v3_all_scenarios_with_LoS_status.csv')

    # Find LoS and NLoS samples in the train and test indices
    train_los_indices = df_train[df_train['LoS_status'] == 'LoS'].index.intersection(train_indices)
    train_nlos_indices = df_train[df_train['LoS_status'] == 'NLoS'].index.intersection(train_indices)
    test_los_indices = df_train[df_train['LoS_status'] == 'LoS'].index.intersection(test_indices)
    test_nlos_indices = df_train[df_train['LoS_status'] == 'NLoS'].index.intersection(test_indices)

    # Verify that all train and test samples are classified
    assert len(train_los_indices) + len(train_nlos_indices) == len(train_indices), "Mismatch in total train samples"
    assert len(test_los_indices) + len(test_nlos_indices) == len(test_indices), "Mismatch in total test samples"

    # Identify scenarios
    scenario_path = df_train['unit2_loc_1']

    # Function to count LoS and NLoS samples for a scenario
    def count_scenario_samples(scenario_keyword, los_indices, nlos_indices):
        scenario_indices = df_train[scenario_path.str.contains(scenario_keyword)].index
        los_count = len(np.intersect1d(los_indices, scenario_indices))
        nlos_count = len(np.intersect1d(nlos_indices, scenario_indices))
        return los_count, nlos_count

    # Count LoS and NLoS samples for each scenario in train and test sets
    scenario_los_nlos_counts_train = {}
    scenario_los_nlos_counts_test = {}
    for scenario_keyword in ['scenario32', 'scenario33', 'scenario34']:
        los_count_train, nlos_count_train = count_scenario_samples(scenario_keyword, train_los_indices, train_nlos_indices)
        los_count_test, nlos_count_test = count_scenario_samples(scenario_keyword, test_los_indices, test_nlos_indices)
        scenario_los_nlos_counts_train[scenario_keyword] = {'LoS': los_count_train, 'NLoS': nlos_count_train}
        scenario_los_nlos_counts_test[scenario_keyword] = {'LoS': los_count_test, 'NLoS': nlos_count_test}

    # Print the counts for each scenario in train and test sets
    print("Train Data Scenario Counts:")
    for scenario, counts in scenario_los_nlos_counts_train.items():
        print(f"{scenario} - LoS samples count: {counts['LoS']}, NLoS samples count: {counts['NLoS']}")

    print("\nTest Data Scenario Counts:")
    for scenario, counts in scenario_los_nlos_counts_test.items():
        print(f"{scenario} - LoS samples count: {counts['LoS']}, NLoS samples count: {counts['NLoS']}")

    # Extract LoS and NLoS samples from the modalities and classes
    X_train_los = lidar[train_los_indices]
    X_train_nlos = lidar[train_nlos_indices]
    X_test_los = lidar[test_los_indices]
    X_test_nlos = lidar[test_nlos_indices]
    y_train_los = classes[train_los_indices]
    y_train_nlos = classes[train_nlos_indices]
    y_test_los = classes[test_los_indices]
    y_test_nlos = classes[test_nlos_indices]

    # Print shapes of train and test datasets for each modality
    print(f'LoS Train Shape: {X_train_los.shape}, LoS Test Shape: {X_test_los.shape}')
    print(f'NLoS Train Shape: {X_train_nlos.shape}, NLoS Test Shape: {X_test_nlos.shape}')

    # Print shapes of train and test labels
    print(f'Train Labels Shape: {y_train.shape}')
    print(f'Test Labels Shape: {y_test.shape}')
    print(f'Train LoS Labels Shape: {y_train_los.shape}')
    print(f'Train NLoS Labels Shape: {y_train_nlos.shape}')
    print(f'Test LoS Labels Shape: {y_test_los.shape}')
    print(f'Test NLoS Labels Shape: {y_test_nlos.shape}')

    gc.collect()


    # some global params
    NBFRAME = 5
    N_CLASSES = 64
    INSHAPE = (5,imagex,imagey)

    model = GRU_model(INSHAPE, N_CLASSES)
    optimizer = keras.optimizers.Adam(0.001) 
    model.compile(optimizer, 'categorical_crossentropy', metrics=['acc'])
    print(model.summary())

    # Run the training
    EPOCHS = 300
    BS = 30

    callbacks = [
        keras.callbacks.EarlyStopping(monitor='val_loss', patience=12, mode='min', verbose=1),
        keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=8, mode='min', verbose=1),
        keras.callbacks.ModelCheckpoint(
            f'chkp/{model_name}_seed_{seed}.hdf5', 
            monitor='val_acc',  # Monitor validation accuracy
            save_best_only=True,
            mode='max',  # Maximize the monitored quantity
            verbose=1),
    ]

    history = model.fit(
        x=X_train,
        y=y_train,
        validation_split=0.2,
        verbose=1,
        epochs=EPOCHS,
        batch_size=BS,
        callbacks=callbacks
    )
# Out:
# Running model with seed 42
# Train Data Scenario Counts:
# scenario32 - LoS samples count: 2683, NLoS samples count: 110
# scenario33 - LoS samples count: 3329, NLoS samples count: 120
# scenario34 - LoS samples count: 3691, NLoS samples count: 95
#
# Test Data Scenario Counts:
# scenario32 - LoS samples count: 311, NLoS samples count: 11
# scenario33 - LoS samples count: 372, NLoS samples count: 16
# scenario34 - LoS samples count: 391, NLoS samples count: 14
# LoS Train Shape: (9703, 5, 150, 150), LoS Test Shape: (1074, 5, 150, 150)
# NLoS Train Shape: (325, 5, 150, 150), NLoS Test Shape: (41, 5, 150, 150)
# Train Labels Shape: (10028, 64)
# Test Labels Shape: (1115, 64)
# Train LoS Labels Shape: (9703, 64)
# Train NLoS Labels Shape: (325, 64)
# Test LoS Labels Shape: (1074, 64)
# Test NLoS Labels Shape: (41, 64)
# 2024-08-20 18:26:07.906332: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2024-08-20 18:26:07.906366: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: edison
# 2024-08-20 18:26:07.906371: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: edison
# 2024-08-20 18:26:07.906522: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 560.28.3
# 2024-08-20 18:26:07.906547: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: NOT_FOUND: could not find kernel module information in driver version file contents: "NVRM version: NVIDIA UNIX Open Kernel Module for x86_64  560.28.03  Release Build  (dvs-builder@U16-A24-27-4)  Thu Jul 18 20:46:24 UTC 2024
# GCC version:  gcc version 11.4.0 (Ubuntu 11.4.0-1ubuntu1~22.04)
# "
# 2024-08-20 18:26:07.906864: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 5, 256)           362208
#  ibuted)
#
#  gru (GRU)                   (None, 64)                61824
#
#  dense (Dense)               (None, 128)               8320
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
# =================================================================
# Total params: 440,608
# Trainable params: 439,776
# Non-trainable params: 832
# _________________________________________________________________
# None
# Epoch 1/300
# 268/268 [==============================] - ETA: 0s - loss: 3.7516 - acc: 0.1040
# Epoch 1: val_acc improved from -inf to 0.12164, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 22s 67ms/step - loss: 3.7516 - acc: 0.1040 - val_loss: 3.6650 - val_acc: 0.1216 - lr: 0.0010
# Epoch 2/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.6158 - acc: 0.1137
# Epoch 2: val_acc improved from 0.12164 to 0.12612, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 16s 58ms/step - loss: 3.6154 - acc: 0.1138 - val_loss: 3.5591 - val_acc: 0.1261 - lr: 0.0010
# Epoch 3/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.5570 - acc: 0.1182
# Epoch 3: val_acc improved from 0.12612 to 0.12861, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 16s 58ms/step - loss: 3.5564 - acc: 0.1183 - val_loss: 3.4845 - val_acc: 0.1286 - lr: 0.0010
# Epoch 4/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.4968 - acc: 0.1267
# Epoch 4: val_acc did not improve from 0.12861
# 268/268 [==============================] - 15s 57ms/step - loss: 3.4966 - acc: 0.1265 - val_loss: 3.5147 - val_acc: 0.1211 - lr: 0.0010
# Epoch 5/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.4450 - acc: 0.1313
# Epoch 5: val_acc improved from 0.12861 to 0.13310, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 3.4444 - acc: 0.1314 - val_loss: 3.4594 - val_acc: 0.1331 - lr: 0.0010
# Epoch 6/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.4051 - acc: 0.1355
# Epoch 6: val_acc improved from 0.13310 to 0.14357, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 3.4050 - acc: 0.1356 - val_loss: 3.3859 - val_acc: 0.1436 - lr: 0.0010
# Epoch 7/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.3478 - acc: 0.1457
# Epoch 7: val_acc improved from 0.14357 to 0.14656, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 3.3474 - acc: 0.1457 - val_loss: 3.3962 - val_acc: 0.1466 - lr: 0.0010
# Epoch 8/300
# 268/268 [==============================] - ETA: 0s - loss: 3.3083 - acc: 0.1498
# Epoch 8: val_acc improved from 0.14656 to 0.15204, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 3.3083 - acc: 0.1498 - val_loss: 3.2819 - val_acc: 0.1520 - lr: 0.0010
# Epoch 9/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.2437 - acc: 0.1543
# Epoch 9: val_acc did not improve from 0.15204
# 268/268 [==============================] - 15s 56ms/step - loss: 3.2440 - acc: 0.1543 - val_loss: 3.2745 - val_acc: 0.1481 - lr: 0.0010
# Epoch 10/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.2172 - acc: 0.1602
# Epoch 10: val_acc improved from 0.15204 to 0.15603, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 3.2179 - acc: 0.1602 - val_loss: 3.2119 - val_acc: 0.1560 - lr: 0.0010
# Epoch 11/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.1784 - acc: 0.1687
# Epoch 11: val_acc improved from 0.15603 to 0.17198, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 3.1784 - acc: 0.1685 - val_loss: 3.1993 - val_acc: 0.1720 - lr: 0.0010
# Epoch 12/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.1267 - acc: 0.1709
# Epoch 12: val_acc improved from 0.17198 to 0.17348, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 3.1261 - acc: 0.1710 - val_loss: 3.1617 - val_acc: 0.1735 - lr: 0.0010
# Epoch 13/300
# 268/268 [==============================] - ETA: 0s - loss: 3.0717 - acc: 0.1795
# Epoch 13: val_acc did not improve from 0.17348
# 268/268 [==============================] - 15s 56ms/step - loss: 3.0717 - acc: 0.1795 - val_loss: 3.1479 - val_acc: 0.1690 - lr: 0.0010
# Epoch 14/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.0462 - acc: 0.1848
# Epoch 14: val_acc improved from 0.17348 to 0.19342, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 3.0465 - acc: 0.1846 - val_loss: 3.1001 - val_acc: 0.1934 - lr: 0.0010
# Epoch 15/300
# 268/268 [==============================] - ETA: 0s - loss: 2.9972 - acc: 0.1904
# Epoch 15: val_acc did not improve from 0.19342
# 268/268 [==============================] - 15s 56ms/step - loss: 2.9972 - acc: 0.1904 - val_loss: 3.1041 - val_acc: 0.1820 - lr: 0.0010
# Epoch 16/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.9637 - acc: 0.1971
# Epoch 16: val_acc did not improve from 0.19342
# 268/268 [==============================] - 15s 56ms/step - loss: 2.9647 - acc: 0.1970 - val_loss: 3.0709 - val_acc: 0.1864 - lr: 0.0010
# Epoch 17/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.8999 - acc: 0.2012
# Epoch 17: val_acc did not improve from 0.19342
# 268/268 [==============================] - 15s 56ms/step - loss: 2.8998 - acc: 0.2011 - val_loss: 3.0411 - val_acc: 0.1909 - lr: 0.0010
# Epoch 18/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.8530 - acc: 0.2104
# Epoch 18: val_acc did not improve from 0.19342
# 268/268 [==============================] - 15s 56ms/step - loss: 2.8532 - acc: 0.2103 - val_loss: 3.2790 - val_acc: 0.1660 - lr: 0.0010
# Epoch 19/300
# 268/268 [==============================] - ETA: 0s - loss: 2.8034 - acc: 0.2191
# Epoch 19: val_acc did not improve from 0.19342
# 268/268 [==============================] - 15s 56ms/step - loss: 2.8034 - acc: 0.2191 - val_loss: 2.9594 - val_acc: 0.1904 - lr: 0.0010
# Epoch 20/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.7941 - acc: 0.2232
# Epoch 20: val_acc improved from 0.19342 to 0.19990, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.7936 - acc: 0.2234 - val_loss: 2.9481 - val_acc: 0.1999 - lr: 0.0010
# Epoch 21/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.7425 - acc: 0.2282
# Epoch 21: val_acc did not improve from 0.19990
# 268/268 [==============================] - 15s 57ms/step - loss: 2.7434 - acc: 0.2281 - val_loss: 2.9390 - val_acc: 0.1879 - lr: 0.0010
# Epoch 22/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.6465 - acc: 0.2403
# Epoch 22: val_acc improved from 0.19990 to 0.23180, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 2.6455 - acc: 0.2405 - val_loss: 2.8081 - val_acc: 0.2318 - lr: 0.0010
# Epoch 23/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.6532 - acc: 0.2441
# Epoch 23: val_acc did not improve from 0.23180
# 268/268 [==============================] - 15s 56ms/step - loss: 2.6538 - acc: 0.2440 - val_loss: 2.8055 - val_acc: 0.2308 - lr: 0.0010
# Epoch 24/300
# 268/268 [==============================] - ETA: 0s - loss: 2.5839 - acc: 0.2565
# Epoch 24: val_acc improved from 0.23180 to 0.23629, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.5839 - acc: 0.2565 - val_loss: 2.7795 - val_acc: 0.2363 - lr: 0.0010
# Epoch 25/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.5599 - acc: 0.2605
# Epoch 25: val_acc did not improve from 0.23629
# 268/268 [==============================] - 15s 56ms/step - loss: 2.5600 - acc: 0.2603 - val_loss: 2.8098 - val_acc: 0.2243 - lr: 0.0010
# Epoch 26/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.4954 - acc: 0.2677
# Epoch 26: val_acc did not improve from 0.23629
# 268/268 [==============================] - 15s 56ms/step - loss: 2.4951 - acc: 0.2678 - val_loss: 2.8096 - val_acc: 0.2353 - lr: 0.0010
# Epoch 27/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.4649 - acc: 0.2748
# Epoch 27: val_acc improved from 0.23629 to 0.23679, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.4648 - acc: 0.2749 - val_loss: 2.7616 - val_acc: 0.2368 - lr: 0.0010
# Epoch 28/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.4187 - acc: 0.2874
# Epoch 28: val_acc did not improve from 0.23679
# 268/268 [==============================] - 15s 56ms/step - loss: 2.4187 - acc: 0.2876 - val_loss: 2.8150 - val_acc: 0.2288 - lr: 0.0010
# Epoch 29/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.3747 - acc: 0.2924
# Epoch 29: val_acc improved from 0.23679 to 0.25025, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.3748 - acc: 0.2923 - val_loss: 2.7044 - val_acc: 0.2502 - lr: 0.0010
# Epoch 30/300
# 268/268 [==============================] - ETA: 0s - loss: 2.3441 - acc: 0.3020
# Epoch 30: val_acc did not improve from 0.25025
# 268/268 [==============================] - 15s 56ms/step - loss: 2.3441 - acc: 0.3020 - val_loss: 2.7426 - val_acc: 0.2363 - lr: 0.0010
# Epoch 31/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.3103 - acc: 0.3029
# Epoch 31: val_acc improved from 0.25025 to 0.25972, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.3106 - acc: 0.3027 - val_loss: 2.5960 - val_acc: 0.2597 - lr: 0.0010
# Epoch 32/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.2442 - acc: 0.3126
# Epoch 32: val_acc improved from 0.25972 to 0.26520, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.2436 - acc: 0.3128 - val_loss: 2.5634 - val_acc: 0.2652 - lr: 0.0010
# Epoch 33/300
# 268/268 [==============================] - ETA: 0s - loss: 2.2101 - acc: 0.3202
# Epoch 33: val_acc did not improve from 0.26520
# 268/268 [==============================] - 15s 56ms/step - loss: 2.2101 - acc: 0.3202 - val_loss: 2.6642 - val_acc: 0.2612 - lr: 0.0010
# Epoch 34/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1745 - acc: 0.3278
# Epoch 34: val_acc improved from 0.26520 to 0.27966, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.1748 - acc: 0.3277 - val_loss: 2.5424 - val_acc: 0.2797 - lr: 0.0010
# Epoch 35/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1757 - acc: 0.3227
# Epoch 35: val_acc did not improve from 0.27966
# 268/268 [==============================] - 15s 56ms/step - loss: 2.1758 - acc: 0.3227 - val_loss: 2.6889 - val_acc: 0.2607 - lr: 0.0010
# Epoch 36/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1273 - acc: 0.3375
# Epoch 36: val_acc did not improve from 0.27966
# 268/268 [==============================] - 15s 57ms/step - loss: 2.1287 - acc: 0.3374 - val_loss: 2.5736 - val_acc: 0.2767 - lr: 0.0010
# Epoch 37/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0855 - acc: 0.3433
# Epoch 37: val_acc improved from 0.27966 to 0.28514, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.0862 - acc: 0.3431 - val_loss: 2.5645 - val_acc: 0.2851 - lr: 0.0010
# Epoch 38/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0579 - acc: 0.3497
# Epoch 38: val_acc did not improve from 0.28514
# 268/268 [==============================] - 15s 56ms/step - loss: 2.0577 - acc: 0.3498 - val_loss: 2.6507 - val_acc: 0.2527 - lr: 0.0010
# Epoch 39/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0240 - acc: 0.3630
# Epoch 39: val_acc did not improve from 0.28514
# 268/268 [==============================] - 15s 56ms/step - loss: 2.0251 - acc: 0.3626 - val_loss: 2.5515 - val_acc: 0.2702 - lr: 0.0010
# Epoch 40/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9818 - acc: 0.3682
# Epoch 40: val_acc improved from 0.28514 to 0.29113, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.9813 - acc: 0.3681 - val_loss: 2.4947 - val_acc: 0.2911 - lr: 0.0010
# Epoch 41/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9515 - acc: 0.3740
# Epoch 41: val_acc did not improve from 0.29113
# 268/268 [==============================] - 15s 56ms/step - loss: 1.9510 - acc: 0.3742 - val_loss: 2.6592 - val_acc: 0.2682 - lr: 0.0010
# Epoch 42/300
# 268/268 [==============================] - ETA: 0s - loss: 1.9418 - acc: 0.3767
# Epoch 42: val_acc did not improve from 0.29113
# 268/268 [==============================] - 15s 56ms/step - loss: 1.9418 - acc: 0.3767 - val_loss: 2.5598 - val_acc: 0.2752 - lr: 0.0010
# Epoch 43/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9091 - acc: 0.3866
# Epoch 43: val_acc improved from 0.29113 to 0.29611, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.9090 - acc: 0.3869 - val_loss: 2.4727 - val_acc: 0.2961 - lr: 0.0010
# Epoch 44/300
# 268/268 [==============================] - ETA: 0s - loss: 1.8617 - acc: 0.3943
# Epoch 44: val_acc did not improve from 0.29611
# 268/268 [==============================] - 15s 56ms/step - loss: 1.8617 - acc: 0.3943 - val_loss: 2.5912 - val_acc: 0.2851 - lr: 0.0010
# Epoch 45/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8727 - acc: 0.3914
# Epoch 45: val_acc did not improve from 0.29611
# 268/268 [==============================] - 15s 56ms/step - loss: 1.8720 - acc: 0.3915 - val_loss: 2.4997 - val_acc: 0.2881 - lr: 0.0010
# Epoch 46/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8244 - acc: 0.4004
# Epoch 46: val_acc improved from 0.29611 to 0.30758, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.8250 - acc: 0.4000 - val_loss: 2.4591 - val_acc: 0.3076 - lr: 0.0010
# Epoch 47/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7757 - acc: 0.4162
# Epoch 47: val_acc did not improve from 0.30758
# 268/268 [==============================] - 15s 55ms/step - loss: 1.7759 - acc: 0.4164 - val_loss: 2.5710 - val_acc: 0.2752 - lr: 0.0010
# Epoch 48/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7790 - acc: 0.4206
# Epoch 48: val_acc did not improve from 0.30758
# 268/268 [==============================] - 15s 56ms/step - loss: 1.7809 - acc: 0.4200 - val_loss: 2.5618 - val_acc: 0.2931 - lr: 0.0010
# Epoch 49/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7468 - acc: 0.4213
# Epoch 49: val_acc did not improve from 0.30758
# 268/268 [==============================] - 15s 56ms/step - loss: 1.7474 - acc: 0.4213 - val_loss: 2.4588 - val_acc: 0.3056 - lr: 0.0010
# Epoch 50/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7176 - acc: 0.4260
# Epoch 50: val_acc did not improve from 0.30758
# 268/268 [==============================] - 15s 55ms/step - loss: 1.7179 - acc: 0.4257 - val_loss: 2.5544 - val_acc: 0.2996 - lr: 0.0010
# Epoch 51/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7150 - acc: 0.4325
# Epoch 51: val_acc improved from 0.30758 to 0.30907, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.7153 - acc: 0.4324 - val_loss: 2.4305 - val_acc: 0.3091 - lr: 0.0010
# Epoch 52/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6445 - acc: 0.4414
# Epoch 52: val_acc did not improve from 0.30907
# 268/268 [==============================] - 15s 56ms/step - loss: 1.6446 - acc: 0.4417 - val_loss: 2.6100 - val_acc: 0.2817 - lr: 0.0010
# Epoch 53/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6546 - acc: 0.4412
# Epoch 53: val_acc improved from 0.30907 to 0.31107, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.6553 - acc: 0.4412 - val_loss: 2.5014 - val_acc: 0.3111 - lr: 0.0010
# Epoch 54/300
# 268/268 [==============================] - ETA: 0s - loss: 1.6857 - acc: 0.4380
# Epoch 54: val_acc did not improve from 0.31107
# 268/268 [==============================] - 15s 56ms/step - loss: 1.6857 - acc: 0.4380 - val_loss: 2.4992 - val_acc: 0.3011 - lr: 0.0010
# Epoch 55/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6092 - acc: 0.4548
# Epoch 55: val_acc improved from 0.31107 to 0.31555, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.6087 - acc: 0.4550 - val_loss: 2.5415 - val_acc: 0.3156 - lr: 0.0010
# Epoch 56/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.5960 - acc: 0.4543
# Epoch 56: val_acc did not improve from 0.31555
# 268/268 [==============================] - 15s 56ms/step - loss: 1.5961 - acc: 0.4543 - val_loss: 2.5708 - val_acc: 0.3071 - lr: 0.0010
# Epoch 57/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.5591 - acc: 0.4620
# Epoch 57: val_acc did not improve from 0.31555
# 268/268 [==============================] - 15s 56ms/step - loss: 1.5597 - acc: 0.4620 - val_loss: 2.5390 - val_acc: 0.3091 - lr: 0.0010
# Epoch 58/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.5661 - acc: 0.4634
# Epoch 58: val_acc did not improve from 0.31555
# 268/268 [==============================] - 15s 56ms/step - loss: 1.5667 - acc: 0.4635 - val_loss: 2.5530 - val_acc: 0.3001 - lr: 0.0010
# Epoch 59/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.5414 - acc: 0.4783
# Epoch 59: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 59: val_acc did not improve from 0.31555
# 268/268 [==============================] - 15s 56ms/step - loss: 1.5414 - acc: 0.4782 - val_loss: 2.5648 - val_acc: 0.3051 - lr: 0.0010
# Epoch 60/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3342 - acc: 0.5221
# Epoch 60: val_acc improved from 0.31555 to 0.33998, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.3348 - acc: 0.5218 - val_loss: 2.4191 - val_acc: 0.3400 - lr: 1.0000e-04
# Epoch 61/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2478 - acc: 0.5504
# Epoch 61: val_acc improved from 0.33998 to 0.35294, saving model to chkp/L_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 55ms/step - loss: 1.2486 - acc: 0.5501 - val_loss: 2.3906 - val_acc: 0.3529 - lr: 1.0000e-04
# Epoch 62/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2142 - acc: 0.5658
# Epoch 62: val_acc did not improve from 0.35294
# 268/268 [==============================] - 15s 55ms/step - loss: 1.2143 - acc: 0.5656 - val_loss: 2.4330 - val_acc: 0.3395 - lr: 1.0000e-04
# Epoch 63/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.1787 - acc: 0.5759
# Epoch 63: val_acc did not improve from 0.35294
# 268/268 [==============================] - 15s 57ms/step - loss: 1.1789 - acc: 0.5760 - val_loss: 2.4146 - val_acc: 0.3375 - lr: 1.0000e-04
# Epoch 64/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.1545 - acc: 0.5843
# Epoch 64: val_acc did not improve from 0.35294
# 268/268 [==============================] - 15s 56ms/step - loss: 1.1542 - acc: 0.5845 - val_loss: 2.4429 - val_acc: 0.3445 - lr: 1.0000e-04
# Epoch 65/300
# 268/268 [==============================] - ETA: 0s - loss: 1.1391 - acc: 0.5835
# Epoch 65: val_acc did not improve from 0.35294
# 268/268 [==============================] - 15s 56ms/step - loss: 1.1391 - acc: 0.5835 - val_loss: 2.5137 - val_acc: 0.3415 - lr: 1.0000e-04
# Epoch 66/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.1335 - acc: 0.5820
# Epoch 66: val_acc did not improve from 0.35294
# 268/268 [==============================] - 15s 56ms/step - loss: 1.1333 - acc: 0.5820 - val_loss: 2.4987 - val_acc: 0.3365 - lr: 1.0000e-04
# Epoch 67/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.1076 - acc: 0.5929
# Epoch 67: val_acc did not improve from 0.35294
# 268/268 [==============================] - 15s 55ms/step - loss: 1.1077 - acc: 0.5926 - val_loss: 2.4911 - val_acc: 0.3430 - lr: 1.0000e-04
# Epoch 68/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.1009 - acc: 0.5959
# Epoch 68: val_acc did not improve from 0.35294
# 268/268 [==============================] - 15s 56ms/step - loss: 1.1023 - acc: 0.5956 - val_loss: 2.5398 - val_acc: 0.3435 - lr: 1.0000e-04
# Epoch 69/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.0644 - acc: 0.6037
# Epoch 69: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 69: val_acc did not improve from 0.35294
# 268/268 [==============================] - 15s 56ms/step - loss: 1.0654 - acc: 0.6037 - val_loss: 2.5429 - val_acc: 0.3380 - lr: 1.0000e-04
# Epoch 70/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.0477 - acc: 0.6200
# Epoch 70: val_acc did not improve from 0.35294
# 268/268 [==============================] - 15s 56ms/step - loss: 1.0486 - acc: 0.6200 - val_loss: 2.5483 - val_acc: 0.3405 - lr: 1.0000e-05
# Epoch 71/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.0363 - acc: 0.6208
# Epoch 71: val_acc did not improve from 0.35294
# 268/268 [==============================] - 15s 56ms/step - loss: 1.0366 - acc: 0.6209 - val_loss: 2.5514 - val_acc: 0.3490 - lr: 1.0000e-05
# Epoch 72/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.0329 - acc: 0.6255
# Epoch 72: val_acc did not improve from 0.35294
# 268/268 [==============================] - 15s 55ms/step - loss: 1.0335 - acc: 0.6253 - val_loss: 2.5110 - val_acc: 0.3405 - lr: 1.0000e-05
# Epoch 73/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.0445 - acc: 0.6170
# Epoch 73: val_acc did not improve from 0.35294
# 268/268 [==============================] - 15s 55ms/step - loss: 1.0440 - acc: 0.6169 - val_loss: 2.5561 - val_acc: 0.3405 - lr: 1.0000e-05
# Epoch 73: early stopping
#
# Running model with seed 123
# Train Data Scenario Counts:
# scenario32 - LoS samples count: 2729, NLoS samples count: 109
# scenario33 - LoS samples count: 3322, NLoS samples count: 119
# scenario34 - LoS samples count: 3652, NLoS samples count: 97
#
# Test Data Scenario Counts:
# scenario32 - LoS samples count: 265, NLoS samples count: 12
# scenario33 - LoS samples count: 379, NLoS samples count: 17
# scenario34 - LoS samples count: 430, NLoS samples count: 12
# LoS Train Shape: (9703, 5, 150, 150), LoS Test Shape: (1074, 5, 150, 150)
# NLoS Train Shape: (325, 5, 150, 150), NLoS Test Shape: (41, 5, 150, 150)
# Train Labels Shape: (10028, 64)
# Test Labels Shape: (1115, 64)
# Train LoS Labels Shape: (9703, 64)
# Train NLoS Labels Shape: (325, 64)
# Test LoS Labels Shape: (1074, 64)
# Test NLoS Labels Shape: (41, 64)
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_1 (TimeDis  (None, 5, 256)           362208
#  tributed)
#
#  gru_1 (GRU)                 (None, 64)                61824
#
#  dense_2 (Dense)             (None, 128)               8320
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
# =================================================================
# Total params: 440,608
# Trainable params: 439,776
# Non-trainable params: 832
# _________________________________________________________________
# None
# Epoch 1/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.7672 - acc: 0.0990
# Epoch 1: val_acc improved from -inf to 0.10618, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 20s 63ms/step - loss: 3.7673 - acc: 0.0990 - val_loss: 3.6339 - val_acc: 0.1062 - lr: 0.0010
# Epoch 2/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.6422 - acc: 0.1107
# Epoch 2: val_acc did not improve from 0.10618
# 268/268 [==============================] - 15s 57ms/step - loss: 3.6426 - acc: 0.1106 - val_loss: 3.6253 - val_acc: 0.0937 - lr: 0.0010
# Epoch 3/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.5839 - acc: 0.1150
# Epoch 3: val_acc improved from 0.10618 to 0.11366, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 3.5840 - acc: 0.1149 - val_loss: 3.5709 - val_acc: 0.1137 - lr: 0.0010
# Epoch 4/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.5197 - acc: 0.1235
# Epoch 4: val_acc did not improve from 0.11366
# 268/268 [==============================] - 15s 57ms/step - loss: 3.5200 - acc: 0.1237 - val_loss: 3.5352 - val_acc: 0.1117 - lr: 0.0010
# Epoch 5/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.4777 - acc: 0.1231
# Epoch 5: val_acc improved from 0.11366 to 0.12562, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 3.4781 - acc: 0.1232 - val_loss: 3.4274 - val_acc: 0.1256 - lr: 0.0010
# Epoch 6/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.4236 - acc: 0.1260
# Epoch 6: val_acc improved from 0.12562 to 0.13260, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 3.4232 - acc: 0.1259 - val_loss: 3.4272 - val_acc: 0.1326 - lr: 0.0010
# Epoch 7/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.3902 - acc: 0.1331
# Epoch 7: val_acc improved from 0.13260 to 0.13509, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 3.3900 - acc: 0.1331 - val_loss: 3.4658 - val_acc: 0.1351 - lr: 0.0010
# Epoch 8/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.3419 - acc: 0.1423
# Epoch 8: val_acc improved from 0.13509 to 0.13908, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 3.3421 - acc: 0.1424 - val_loss: 3.3739 - val_acc: 0.1391 - lr: 0.0010
# Epoch 9/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.2948 - acc: 0.1516
# Epoch 9: val_acc did not improve from 0.13908
# 268/268 [==============================] - 15s 57ms/step - loss: 3.2943 - acc: 0.1516 - val_loss: 3.4345 - val_acc: 0.1311 - lr: 0.0010
# Epoch 10/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.2622 - acc: 0.1561
# Epoch 10: val_acc improved from 0.13908 to 0.14606, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 3.2632 - acc: 0.1558 - val_loss: 3.3054 - val_acc: 0.1461 - lr: 0.0010
# Epoch 11/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.2223 - acc: 0.1578
# Epoch 11: val_acc improved from 0.14606 to 0.14905, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 3.2235 - acc: 0.1577 - val_loss: 3.2560 - val_acc: 0.1491 - lr: 0.0010
# Epoch 12/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.1689 - acc: 0.1618
# Epoch 12: val_acc improved from 0.14905 to 0.15503, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 3.1692 - acc: 0.1619 - val_loss: 3.2409 - val_acc: 0.1550 - lr: 0.0010
# Epoch 13/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.1464 - acc: 0.1650
# Epoch 13: val_acc did not improve from 0.15503
# 268/268 [==============================] - 15s 56ms/step - loss: 3.1469 - acc: 0.1649 - val_loss: 3.4667 - val_acc: 0.1326 - lr: 0.0010
# Epoch 14/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.0997 - acc: 0.1722
# Epoch 14: val_acc improved from 0.15503 to 0.16650, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 3.0992 - acc: 0.1723 - val_loss: 3.2297 - val_acc: 0.1665 - lr: 0.0010
# Epoch 15/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.0506 - acc: 0.1797
# Epoch 15: val_acc did not improve from 0.16650
# 268/268 [==============================] - 15s 57ms/step - loss: 3.0514 - acc: 0.1795 - val_loss: 3.2766 - val_acc: 0.1590 - lr: 0.0010
# Epoch 16/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.0192 - acc: 0.1859
# Epoch 16: val_acc improved from 0.16650 to 0.18694, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 3.0188 - acc: 0.1860 - val_loss: 3.0727 - val_acc: 0.1869 - lr: 0.0010
# Epoch 17/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.9595 - acc: 0.1904
# Epoch 17: val_acc did not improve from 0.18694
# 268/268 [==============================] - 15s 57ms/step - loss: 2.9603 - acc: 0.1905 - val_loss: 3.0693 - val_acc: 0.1844 - lr: 0.0010
# Epoch 18/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.9162 - acc: 0.2070
# Epoch 18: val_acc did not improve from 0.18694
# 268/268 [==============================] - 15s 57ms/step - loss: 2.9166 - acc: 0.2068 - val_loss: 3.0512 - val_acc: 0.1695 - lr: 0.0010
# Epoch 19/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.8620 - acc: 0.2086
# Epoch 19: val_acc did not improve from 0.18694
# 268/268 [==============================] - 15s 57ms/step - loss: 2.8619 - acc: 0.2087 - val_loss: 2.9948 - val_acc: 0.1805 - lr: 0.0010
# Epoch 20/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.8026 - acc: 0.2217
# Epoch 20: val_acc improved from 0.18694 to 0.19292, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 2.8019 - acc: 0.2220 - val_loss: 3.0479 - val_acc: 0.1929 - lr: 0.0010
# Epoch 21/300
# 268/268 [==============================] - ETA: 0s - loss: 2.7755 - acc: 0.2273
# Epoch 21: val_acc improved from 0.19292 to 0.21137, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 2.7755 - acc: 0.2273 - val_loss: 2.9293 - val_acc: 0.2114 - lr: 0.0010
# Epoch 22/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.7403 - acc: 0.2281
# Epoch 22: val_acc did not improve from 0.21137
# 268/268 [==============================] - 15s 57ms/step - loss: 2.7416 - acc: 0.2277 - val_loss: 2.9365 - val_acc: 0.2069 - lr: 0.0010
# Epoch 23/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.6613 - acc: 0.2466
# Epoch 23: val_acc did not improve from 0.21137
# 268/268 [==============================] - 15s 57ms/step - loss: 2.6606 - acc: 0.2467 - val_loss: 2.9997 - val_acc: 0.2074 - lr: 0.0010
# Epoch 24/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.6060 - acc: 0.2466
# Epoch 24: val_acc improved from 0.21137 to 0.22084, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 2.6073 - acc: 0.2463 - val_loss: 2.8853 - val_acc: 0.2208 - lr: 0.0010
# Epoch 25/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.5732 - acc: 0.2568
# Epoch 25: val_acc did not improve from 0.22084
# 268/268 [==============================] - 15s 56ms/step - loss: 2.5728 - acc: 0.2569 - val_loss: 2.8383 - val_acc: 0.2119 - lr: 0.0010
# Epoch 26/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.5067 - acc: 0.2660
# Epoch 26: val_acc improved from 0.22084 to 0.22832, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 2.5076 - acc: 0.2658 - val_loss: 2.7251 - val_acc: 0.2283 - lr: 0.0010
# Epoch 27/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.4619 - acc: 0.2760
# Epoch 27: val_acc improved from 0.22832 to 0.25623, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 2.4628 - acc: 0.2757 - val_loss: 2.6925 - val_acc: 0.2562 - lr: 0.0010
# Epoch 28/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.4294 - acc: 0.2767
# Epoch 28: val_acc did not improve from 0.25623
# 268/268 [==============================] - 15s 57ms/step - loss: 2.4297 - acc: 0.2765 - val_loss: 2.7152 - val_acc: 0.2378 - lr: 0.0010
# Epoch 29/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.3746 - acc: 0.2891
# Epoch 29: val_acc did not improve from 0.25623
# 268/268 [==============================] - 15s 57ms/step - loss: 2.3740 - acc: 0.2892 - val_loss: 2.6396 - val_acc: 0.2532 - lr: 0.0010
# Epoch 30/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.3363 - acc: 0.3002
# Epoch 30: val_acc did not improve from 0.25623
# 268/268 [==============================] - 15s 56ms/step - loss: 2.3361 - acc: 0.3003 - val_loss: 2.7741 - val_acc: 0.2378 - lr: 0.0010
# Epoch 31/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.2801 - acc: 0.3081
# Epoch 31: val_acc did not improve from 0.25623
# 268/268 [==============================] - 15s 57ms/step - loss: 2.2803 - acc: 0.3080 - val_loss: 2.6524 - val_acc: 0.2393 - lr: 0.0010
# Epoch 32/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.2260 - acc: 0.3169
# Epoch 32: val_acc did not improve from 0.25623
# 268/268 [==============================] - 15s 57ms/step - loss: 2.2257 - acc: 0.3170 - val_loss: 2.6355 - val_acc: 0.2522 - lr: 0.0010
# Epoch 33/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1939 - acc: 0.3164
# Epoch 33: val_acc improved from 0.25623 to 0.26720, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 2.1927 - acc: 0.3169 - val_loss: 2.5707 - val_acc: 0.2672 - lr: 0.0010
# Epoch 34/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1903 - acc: 0.3245
# Epoch 34: val_acc did not improve from 0.26720
# 268/268 [==============================] - 15s 57ms/step - loss: 2.1906 - acc: 0.3244 - val_loss: 2.5957 - val_acc: 0.2547 - lr: 0.0010
# Epoch 35/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1287 - acc: 0.3321
# Epoch 35: val_acc improved from 0.26720 to 0.26919, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 2.1293 - acc: 0.3318 - val_loss: 2.5672 - val_acc: 0.2692 - lr: 0.0010
# Epoch 36/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0730 - acc: 0.3451
# Epoch 36: val_acc improved from 0.26919 to 0.27069, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 2.0735 - acc: 0.3449 - val_loss: 2.5243 - val_acc: 0.2707 - lr: 0.0010
# Epoch 37/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0558 - acc: 0.3499
# Epoch 37: val_acc did not improve from 0.27069
# 268/268 [==============================] - 15s 57ms/step - loss: 2.0566 - acc: 0.3498 - val_loss: 2.5710 - val_acc: 0.2682 - lr: 0.0010
# Epoch 38/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0263 - acc: 0.3518
# Epoch 38: val_acc did not improve from 0.27069
# 268/268 [==============================] - 15s 57ms/step - loss: 2.0263 - acc: 0.3517 - val_loss: 2.6775 - val_acc: 0.2652 - lr: 0.0010
# Epoch 39/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0003 - acc: 0.3553
# Epoch 39: val_acc improved from 0.27069 to 0.27717, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 2.0003 - acc: 0.3551 - val_loss: 2.5245 - val_acc: 0.2772 - lr: 0.0010
# Epoch 40/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9375 - acc: 0.3739
# Epoch 40: val_acc improved from 0.27717 to 0.28664, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 1.9372 - acc: 0.3741 - val_loss: 2.5223 - val_acc: 0.2866 - lr: 0.0010
# Epoch 41/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9496 - acc: 0.3685
# Epoch 41: val_acc improved from 0.28664 to 0.29661, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 1.9512 - acc: 0.3684 - val_loss: 2.4820 - val_acc: 0.2966 - lr: 0.0010
# Epoch 42/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8818 - acc: 0.3830
# Epoch 42: val_acc did not improve from 0.29661
# 268/268 [==============================] - 15s 57ms/step - loss: 1.8823 - acc: 0.3828 - val_loss: 2.5791 - val_acc: 0.2861 - lr: 0.0010
# Epoch 43/300
# 268/268 [==============================] - ETA: 0s - loss: 1.8629 - acc: 0.3897
# Epoch 43: val_acc did not improve from 0.29661
# 268/268 [==============================] - 15s 57ms/step - loss: 1.8629 - acc: 0.3897 - val_loss: 2.5045 - val_acc: 0.2956 - lr: 0.0010
# Epoch 44/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8474 - acc: 0.3921
# Epoch 44: val_acc did not improve from 0.29661
# 268/268 [==============================] - 15s 57ms/step - loss: 1.8478 - acc: 0.3919 - val_loss: 2.4754 - val_acc: 0.2891 - lr: 0.0010
# Epoch 45/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8164 - acc: 0.4012
# Epoch 45: val_acc improved from 0.29661 to 0.29711, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 1.8178 - acc: 0.4010 - val_loss: 2.4580 - val_acc: 0.2971 - lr: 0.0010
# Epoch 46/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7634 - acc: 0.4070
# Epoch 46: val_acc did not improve from 0.29711
# 268/268 [==============================] - 15s 56ms/step - loss: 1.7635 - acc: 0.4068 - val_loss: 2.6183 - val_acc: 0.2881 - lr: 0.0010
# Epoch 47/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7249 - acc: 0.4126
# Epoch 47: val_acc improved from 0.29711 to 0.31007, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 1.7244 - acc: 0.4126 - val_loss: 2.4518 - val_acc: 0.3101 - lr: 0.0010
# Epoch 48/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7298 - acc: 0.4170
# Epoch 48: val_acc did not improve from 0.31007
# 268/268 [==============================] - 15s 56ms/step - loss: 1.7306 - acc: 0.4167 - val_loss: 2.4703 - val_acc: 0.3066 - lr: 0.0010
# Epoch 49/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7201 - acc: 0.4228
# Epoch 49: val_acc did not improve from 0.31007
# 268/268 [==============================] - 15s 57ms/step - loss: 1.7199 - acc: 0.4228 - val_loss: 2.5370 - val_acc: 0.2996 - lr: 0.0010
# Epoch 50/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7072 - acc: 0.4251
# Epoch 50: val_acc did not improve from 0.31007
# 268/268 [==============================] - 15s 57ms/step - loss: 1.7071 - acc: 0.4252 - val_loss: 2.4874 - val_acc: 0.3036 - lr: 0.0010
# Epoch 51/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6726 - acc: 0.4367
# Epoch 51: val_acc did not improve from 0.31007
# 268/268 [==============================] - 15s 57ms/step - loss: 1.6742 - acc: 0.4365 - val_loss: 2.4507 - val_acc: 0.2981 - lr: 0.0010
# Epoch 52/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6266 - acc: 0.4366
# Epoch 52: val_acc did not improve from 0.31007
# 268/268 [==============================] - 15s 57ms/step - loss: 1.6271 - acc: 0.4364 - val_loss: 2.4758 - val_acc: 0.3061 - lr: 0.0010
# Epoch 53/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6282 - acc: 0.4468
# Epoch 53: val_acc improved from 0.31007 to 0.31505, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 1.6288 - acc: 0.4465 - val_loss: 2.5142 - val_acc: 0.3151 - lr: 0.0010
# Epoch 54/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.5920 - acc: 0.4494
# Epoch 54: val_acc did not improve from 0.31505
# 268/268 [==============================] - 15s 57ms/step - loss: 1.5921 - acc: 0.4493 - val_loss: 2.5704 - val_acc: 0.3096 - lr: 0.0010
# Epoch 55/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6209 - acc: 0.4413
# Epoch 55: val_acc improved from 0.31505 to 0.31805, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 1.6207 - acc: 0.4418 - val_loss: 2.5495 - val_acc: 0.3180 - lr: 0.0010
# Epoch 56/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.5852 - acc: 0.4559
# Epoch 56: val_acc did not improve from 0.31805
# 268/268 [==============================] - 15s 57ms/step - loss: 1.5873 - acc: 0.4559 - val_loss: 2.4718 - val_acc: 0.3081 - lr: 0.0010
# Epoch 57/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.5452 - acc: 0.4643
# Epoch 57: val_acc did not improve from 0.31805
# 268/268 [==============================] - 15s 57ms/step - loss: 1.5450 - acc: 0.4641 - val_loss: 2.4857 - val_acc: 0.3146 - lr: 0.0010
# Epoch 58/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.5280 - acc: 0.4742
# Epoch 58: val_acc did not improve from 0.31805
# 268/268 [==============================] - 15s 57ms/step - loss: 1.5292 - acc: 0.4737 - val_loss: 2.5966 - val_acc: 0.3131 - lr: 0.0010
# Epoch 59/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.5342 - acc: 0.4680
# Epoch 59: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 59: val_acc did not improve from 0.31805
# 268/268 [==============================] - 15s 57ms/step - loss: 1.5343 - acc: 0.4677 - val_loss: 2.6317 - val_acc: 0.2971 - lr: 0.0010
# Epoch 60/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3336 - acc: 0.5230
# Epoch 60: val_acc improved from 0.31805 to 0.32901, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 58ms/step - loss: 1.3338 - acc: 0.5228 - val_loss: 2.4379 - val_acc: 0.3290 - lr: 1.0000e-04
# Epoch 61/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2242 - acc: 0.5573
# Epoch 61: val_acc improved from 0.32901 to 0.33350, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 1.2240 - acc: 0.5573 - val_loss: 2.4525 - val_acc: 0.3335 - lr: 1.0000e-04
# Epoch 62/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2041 - acc: 0.5615
# Epoch 62: val_acc improved from 0.33350 to 0.33699, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 1.2039 - acc: 0.5615 - val_loss: 2.4524 - val_acc: 0.3370 - lr: 1.0000e-04
# Epoch 63/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.1700 - acc: 0.5724
# Epoch 63: val_acc did not improve from 0.33699
# 268/268 [==============================] - 15s 57ms/step - loss: 1.1697 - acc: 0.5728 - val_loss: 2.4798 - val_acc: 0.3350 - lr: 1.0000e-04
# Epoch 64/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.1254 - acc: 0.5838
# Epoch 64: val_acc improved from 0.33699 to 0.33848, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 1.1260 - acc: 0.5835 - val_loss: 2.5041 - val_acc: 0.3385 - lr: 1.0000e-04
# Epoch 65/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.1291 - acc: 0.5770
# Epoch 65: val_acc improved from 0.33848 to 0.34197, saving model to chkp/L_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 1.1295 - acc: 0.5770 - val_loss: 2.5386 - val_acc: 0.3420 - lr: 1.0000e-04
# Epoch 66/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.1035 - acc: 0.5885
# Epoch 66: val_acc did not improve from 0.34197
# 268/268 [==============================] - 15s 56ms/step - loss: 1.1038 - acc: 0.5883 - val_loss: 2.5361 - val_acc: 0.3420 - lr: 1.0000e-04
# Epoch 67/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.0872 - acc: 0.6031
# ...
# Epoch 9/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.2512 - acc: 0.1443
# Epoch 9: val_acc did not improve from 0.13559
# 268/268 [==============================] - 15s 57ms/step - loss: 3.2512 - acc: 0.1445 - val_loss: 3.3355 - val_acc: 0.1291 - lr: 0.0010
# Epoch 10/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.1984 - acc: 0.1509
# Epoch 10: val_acc improved from 0.13559 to 0.14656, saving model to chkp/L_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 3.1981 - acc: 0.1511 - val_loss: 3.2341 - val_acc: 0.1466 - lr: 0.0010
# Epoch 11/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.1610 - acc: 0.1529
# Epoch 11: val_acc did not improve from 0.14656
# 268/268 [==============================] - 15s 57ms/step - loss: 3.1601 - acc: 0.1533 - val_loss: 3.2469 - val_acc: 0.1336 - lr: 0.0010
# Epoch 12/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.1088 - acc: 0.1642
# Epoch 12: val_acc did not improve from 0.14656
# 268/268 [==============================] - 15s 57ms/step - loss: 3.1080 - acc: 0.1645 - val_loss: 3.2463 - val_acc: 0.1441 - lr: 0.0010
# Epoch 13/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.0665 - acc: 0.1700
# Epoch 13: val_acc improved from 0.14656 to 0.15254, saving model to chkp/L_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 3.0663 - acc: 0.1699 - val_loss: 3.1082 - val_acc: 0.1525 - lr: 0.0010
# Epoch 14/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.9981 - acc: 0.1798
# Epoch 14: val_acc improved from 0.15254 to 0.15304, saving model to chkp/L_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 2.9986 - acc: 0.1796 - val_loss: 3.1980 - val_acc: 0.1530 - lr: 0.0010
# Epoch 15/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.9627 - acc: 0.1871
# Epoch 15: val_acc improved from 0.15304 to 0.16102, saving model to chkp/L_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 2.9629 - acc: 0.1871 - val_loss: 3.0652 - val_acc: 0.1610 - lr: 0.0010
# Epoch 16/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.9011 - acc: 0.1914
# Epoch 16: val_acc improved from 0.16102 to 0.18694, saving model to chkp/L_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 2.9011 - acc: 0.1912 - val_loss: 2.9838 - val_acc: 0.1869 - lr: 0.0010
# Epoch 17/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.8581 - acc: 0.2040
# Epoch 17: val_acc did not improve from 0.18694
# 268/268 [==============================] - 15s 57ms/step - loss: 2.8581 - acc: 0.2038 - val_loss: 3.0063 - val_acc: 0.1810 - lr: 0.0010
# Epoch 18/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.8110 - acc: 0.2099
# Epoch 18: val_acc did not improve from 0.18694
# 268/268 [==============================] - 15s 57ms/step - loss: 2.8112 - acc: 0.2098 - val_loss: 2.9489 - val_acc: 0.1834 - lr: 0.0010
# Epoch 19/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.7680 - acc: 0.2152
# Epoch 19: val_acc did not improve from 0.18694
# 268/268 [==============================] - 15s 57ms/step - loss: 2.7680 - acc: 0.2152 - val_loss: 2.9094 - val_acc: 0.1839 - lr: 0.0010
# Epoch 20/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.7138 - acc: 0.2260
# Epoch 20: val_acc did not improve from 0.18694
# 268/268 [==============================] - 15s 57ms/step - loss: 2.7141 - acc: 0.2258 - val_loss: 3.0234 - val_acc: 0.1725 - lr: 0.0010
# Epoch 21/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.6587 - acc: 0.2327
# Epoch 21: val_acc improved from 0.18694 to 0.20638, saving model to chkp/L_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 2.6585 - acc: 0.2329 - val_loss: 2.7835 - val_acc: 0.2064 - lr: 0.0010
# Epoch 22/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.5931 - acc: 0.2483
# Epoch 22: val_acc did not improve from 0.20638
# 268/268 [==============================] - 15s 57ms/step - loss: 2.5938 - acc: 0.2483 - val_loss: 2.9689 - val_acc: 0.1854 - lr: 0.0010
# Epoch 23/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.5547 - acc: 0.2577
# Epoch 23: val_acc improved from 0.20638 to 0.22383, saving model to chkp/L_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 2.5550 - acc: 0.2573 - val_loss: 2.7418 - val_acc: 0.2238 - lr: 0.0010
# Epoch 24/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.5157 - acc: 0.2531
# Epoch 24: val_acc did not improve from 0.22383
# 268/268 [==============================] - 15s 57ms/step - loss: 2.5160 - acc: 0.2532 - val_loss: 2.7971 - val_acc: 0.2084 - lr: 0.0010
# Epoch 25/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.4539 - acc: 0.2650
# Epoch 25: val_acc did not improve from 0.22383
# 268/268 [==============================] - 15s 57ms/step - loss: 2.4551 - acc: 0.2648 - val_loss: 2.7412 - val_acc: 0.2168 - lr: 0.0010
# Epoch 26/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.4045 - acc: 0.2725
# Epoch 26: val_acc improved from 0.22383 to 0.23280, saving model to chkp/L_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 58ms/step - loss: 2.4047 - acc: 0.2723 - val_loss: 2.8213 - val_acc: 0.2328 - lr: 0.0010
# Epoch 27/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.3875 - acc: 0.2764
# Epoch 27: val_acc did not improve from 0.23280
# 268/268 [==============================] - 15s 57ms/step - loss: 2.3877 - acc: 0.2764 - val_loss: 2.7236 - val_acc: 0.2313 - lr: 0.0010
# Epoch 28/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.3158 - acc: 0.2908
# Epoch 28: val_acc improved from 0.23280 to 0.23779, saving model to chkp/L_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 2.3167 - acc: 0.2903 - val_loss: 2.6347 - val_acc: 0.2378 - lr: 0.0010
# Epoch 29/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.2593 - acc: 0.3024
# Epoch 29: val_acc improved from 0.23779 to 0.24028, saving model to chkp/L_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 2.2598 - acc: 0.3023 - val_loss: 2.6440 - val_acc: 0.2403 - lr: 0.0010
# Epoch 30/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.2327 - acc: 0.3070
# Epoch 30: val_acc improved from 0.24028 to 0.27069, saving model to chkp/L_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 2.2330 - acc: 0.3067 - val_loss: 2.5574 - val_acc: 0.2707 - lr: 0.0010
# Epoch 31/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.2116 - acc: 0.3071
# Epoch 31: val_acc did not improve from 0.27069
# 268/268 [==============================] - 15s 57ms/step - loss: 2.2110 - acc: 0.3073 - val_loss: 2.5888 - val_acc: 0.2532 - lr: 0.0010
# Epoch 32/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1770 - acc: 0.3213
# Epoch 32: val_acc improved from 0.27069 to 0.27418, saving model to chkp/L_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 2.1784 - acc: 0.3212 - val_loss: 2.5163 - val_acc: 0.2742 - lr: 0.0010
# Epoch 33/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1059 - acc: 0.3317
# Epoch 33: val_acc did not improve from 0.27418
# 268/268 [==============================] - 15s 57ms/step - loss: 2.1064 - acc: 0.3315 - val_loss: 2.5577 - val_acc: 0.2722 - lr: 0.0010
# Epoch 34/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0987 - acc: 0.3335
# Epoch 34: val_acc did not improve from 0.27418
# 268/268 [==============================] - 15s 57ms/step - loss: 2.0989 - acc: 0.3332 - val_loss: 2.5172 - val_acc: 0.2667 - lr: 0.0010
# Epoch 35/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0343 - acc: 0.3454
# Epoch 35: val_acc improved from 0.27418 to 0.27866, saving model to chkp/L_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 2.0359 - acc: 0.3453 - val_loss: 2.5408 - val_acc: 0.2787 - lr: 0.0010
# Epoch 36/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0439 - acc: 0.3441
# Epoch 36: val_acc improved from 0.27866 to 0.29212, saving model to chkp/L_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 2.0447 - acc: 0.3437 - val_loss: 2.5589 - val_acc: 0.2921 - lr: 0.0010
# Epoch 37/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9965 - acc: 0.3539
# Epoch 37: val_acc did not improve from 0.29212
# 268/268 [==============================] - 15s 57ms/step - loss: 1.9971 - acc: 0.3539 - val_loss: 2.5572 - val_acc: 0.2861 - lr: 0.0010
# Epoch 38/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9678 - acc: 0.3548
# Epoch 38: val_acc improved from 0.29212 to 0.29312, saving model to chkp/L_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 1.9674 - acc: 0.3550 - val_loss: 2.4554 - val_acc: 0.2931 - lr: 0.0010
# Epoch 39/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9280 - acc: 0.3662
# Epoch 39: val_acc did not improve from 0.29312
# 268/268 [==============================] - 15s 56ms/step - loss: 1.9290 - acc: 0.3659 - val_loss: 2.5280 - val_acc: 0.2921 - lr: 0.0010
# Epoch 40/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9153 - acc: 0.3729
# Epoch 40: val_acc did not improve from 0.29312
# 268/268 [==============================] - 15s 57ms/step - loss: 1.9165 - acc: 0.3727 - val_loss: 2.5999 - val_acc: 0.2697 - lr: 0.0010
# Epoch 41/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8745 - acc: 0.3846
# Epoch 41: val_acc improved from 0.29312 to 0.30907, saving model to chkp/L_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 1.8751 - acc: 0.3846 - val_loss: 2.4398 - val_acc: 0.3091 - lr: 0.0010
# Epoch 42/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8500 - acc: 0.3787
# Epoch 42: val_acc did not improve from 0.30907
# 268/268 [==============================] - 15s 57ms/step - loss: 1.8504 - acc: 0.3785 - val_loss: 2.5302 - val_acc: 0.2812 - lr: 0.0010
# Epoch 43/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8621 - acc: 0.3848
# Epoch 43: val_acc did not improve from 0.30907
# 268/268 [==============================] - 15s 57ms/step - loss: 1.8642 - acc: 0.3847 - val_loss: 2.5419 - val_acc: 0.2846 - lr: 0.0010
# Epoch 44/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8118 - acc: 0.4001
# Epoch 44: val_acc did not improve from 0.30907
# 268/268 [==============================] - 15s 57ms/step - loss: 1.8116 - acc: 0.4001 - val_loss: 2.5831 - val_acc: 0.2822 - lr: 0.0010
# Epoch 45/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7814 - acc: 0.4034
# Epoch 45: val_acc did not improve from 0.30907
# 268/268 [==============================] - 15s 57ms/step - loss: 1.7813 - acc: 0.4033 - val_loss: 2.5179 - val_acc: 0.3026 - lr: 0.0010
# Epoch 46/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7426 - acc: 0.4039
# Epoch 46: val_acc did not improve from 0.30907
# 268/268 [==============================] - 15s 56ms/step - loss: 1.7428 - acc: 0.4036 - val_loss: 2.5041 - val_acc: 0.2956 - lr: 0.0010
# Epoch 47/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7456 - acc: 0.4119
# Epoch 47: val_acc improved from 0.30907 to 0.31256, saving model to chkp/L_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 1.7461 - acc: 0.4117 - val_loss: 2.4817 - val_acc: 0.3126 - lr: 0.0010
# Epoch 48/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7211 - acc: 0.4179
# Epoch 48: val_acc improved from 0.31256 to 0.31854, saving model to chkp/L_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 1.7203 - acc: 0.4182 - val_loss: 2.4226 - val_acc: 0.3185 - lr: 0.0010
# Epoch 49/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6734 - acc: 0.4231
# Epoch 49: val_acc did not improve from 0.31854
# 268/268 [==============================] - 15s 56ms/step - loss: 1.6741 - acc: 0.4227 - val_loss: 2.6010 - val_acc: 0.2916 - lr: 0.0010
# Epoch 50/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6961 - acc: 0.4241
# Epoch 50: val_acc did not improve from 0.31854
# 268/268 [==============================] - 15s 56ms/step - loss: 1.6957 - acc: 0.4240 - val_loss: 2.5308 - val_acc: 0.3086 - lr: 0.0010
# Epoch 51/300
# 268/268 [==============================] - ETA: 0s - loss: 1.6528 - acc: 0.4284
# Epoch 51: val_acc did not improve from 0.31854
# 268/268 [==============================] - 15s 56ms/step - loss: 1.6528 - acc: 0.4284 - val_loss: 2.5275 - val_acc: 0.3121 - lr: 0.0010
# Epoch 52/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6490 - acc: 0.4381
# Epoch 52: val_acc did not improve from 0.31854
# 268/268 [==============================] - 15s 57ms/step - loss: 1.6491 - acc: 0.4382 - val_loss: 2.5346 - val_acc: 0.3131 - lr: 0.0010
# Epoch 53/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6157 - acc: 0.4446
# Epoch 53: val_acc did not improve from 0.31854
# 268/268 [==============================] - 15s 57ms/step - loss: 1.6161 - acc: 0.4447 - val_loss: 2.5148 - val_acc: 0.3021 - lr: 0.0010
# Epoch 54/300
# 268/268 [==============================] - ETA: 0s - loss: 1.6229 - acc: 0.4455
# Epoch 54: val_acc did not improve from 0.31854
# 268/268 [==============================] - 15s 57ms/step - loss: 1.6229 - acc: 0.4455 - val_loss: 2.5312 - val_acc: 0.2956 - lr: 0.0010
# Epoch 55/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.5892 - acc: 0.4526
# Epoch 55: val_acc did not improve from 0.31854
# 268/268 [==============================] - 15s 56ms/step - loss: 1.5891 - acc: 0.4526 - val_loss: 2.6458 - val_acc: 0.2886 - lr: 0.0010
# Epoch 56/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.5654 - acc: 0.4582
# Epoch 56: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 56: val_acc did not improve from 0.31854
# 268/268 [==============================] - 15s 56ms/step - loss: 1.5662 - acc: 0.4581 - val_loss: 2.6691 - val_acc: 0.3051 - lr: 0.0010
# Epoch 57/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3696 - acc: 0.5126
# Epoch 57: val_acc improved from 0.31854 to 0.33699, saving model to chkp/L_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 1.3706 - acc: 0.5125 - val_loss: 2.4359 - val_acc: 0.3370 - lr: 1.0000e-04
# Epoch 58/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2838 - acc: 0.5312
# Epoch 58: val_acc improved from 0.33699 to 0.33799, saving model to chkp/L_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 1.2839 - acc: 0.5312 - val_loss: 2.4344 - val_acc: 0.3380 - lr: 1.0000e-04
# Epoch 59/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2293 - acc: 0.5478
# Epoch 59: val_acc did not improve from 0.33799
# 268/268 [==============================] - 15s 56ms/step - loss: 1.2294 - acc: 0.5480 - val_loss: 2.4643 - val_acc: 0.3340 - lr: 1.0000e-04
# Epoch 60/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.1968 - acc: 0.5640
# Epoch 60: val_acc improved from 0.33799 to 0.33848, saving model to chkp/L_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 1.1964 - acc: 0.5642 - val_loss: 2.4682 - val_acc: 0.3385 - lr: 1.0000e-04
# Epoch 60: early stopping

# %%
#%% Test on each scen separately
#%%Test on Train and Test data (top-1,2,3)
'''
df_train = pd.read_csv('./ml_challenge_dev_multi_modal_v3_all_scenarios_with_LoS_status.csv')

# Find LoS and NLoS samples in the train and test indices
train_los_indices = df_train[df_train['LoS_status'] == 'LoS'].index.intersection(train_indices)
train_nlos_indices = df_train[df_train['LoS_status'] == 'NLoS'].index.intersection(train_indices)
test_los_indices = df_train[df_train['LoS_status'] == 'LoS'].index.intersection(test_indices)
test_nlos_indices = df_train[df_train['LoS_status'] == 'NLoS'].index.intersection(test_indices)

# Verify that all train and test samples are classified
assert len(train_los_indices) + len(train_nlos_indices) == len(train_indices), "Mismatch in total train samples"
assert len(test_los_indices) + len(test_nlos_indices) == len(test_indices), "Mismatch in total test samples"

# Identify scenarios
scenario_path = df_train['unit2_loc_1']

gc.collect()

# Power analysis
N_CLASSES = 64
pwr_rel_paths = df_train['unit1_pwr_60ghz'].values
pwrs_array = np.zeros((pwr_rel_paths.shape[0], N_CLASSES))
for sample_idx in range(pwr_rel_paths.shape[0]):
    pwr_abs_path = pwr_rel_paths[sample_idx]
    pwrs_array[sample_idx] = np.loadtxt(pwr_abs_path)
print('pwrs_array.shape:', pwrs_array.shape)

nan_count = np.isnan(pwrs_array).sum()
print(f'pwrs_array has {nan_count} NaN values')
# Replace NaN values with zero
pwrs_array[np.isnan(pwrs_array)] = 0
# Check if replacement was successful
nan_count_after = np.isnan(pwrs_array).sum()
print(f'pwrs_array after replacement has {nan_count_after} NaN values')

pwrs_array_train, pwrs_array_test_los, pwrs_array_test_nlos = pwrs_array[train_indices], pwrs_array[test_los_indices], pwrs_array[test_nlos_indices]
print(f'pwrs_array_train.shape: {pwrs_array_train.shape}, pwrs_array_test_los.shape: {pwrs_array_test_los.shape}, pwrs_array_test_nlos.shape: {pwrs_array_test_nlos.shape}')

# Model evaluation and prediction
def evaluate_model(model, X_data, y_data, pwrs_array, data_type, scenario, result_list, sample_indices):
    predictions = model.predict(X_data)
    y_pred = np.argsort(predictions, axis=1)[:, ::-1]
    save_pred_to_csv(sample_indices, y_pred, top_k=[1,2,3], target_csv=f'preds_{model_name}_{data_type}{scenario}.csv')
    true = np.argmax(y_data, axis=1).reshape(-1, 1)
    acc = compute_acc(y_pred, true, top_k=[1, 3, 5])
    score = compute_DBA_score(y_pred, true, max_k=3, delta=5)
    recall = recall_score(true, y_pred[:, 0], average='weighted')
    precision = precision_score(true, y_pred[:, 0], average='weighted')
    PF_mean = compute_powerfactor(y_pred, pwrs_array, k=3)
   
    result_list.append({
        'scenario': scenario,
        'type': data_type,
        'acc': acc,
        'score': round(score, 2),
        'PF1_mean': PF_mean[0],
        'PF2_mean': PF_mean[1],
        'PF3_mean': PF_mean[2],
        'recall': round(recall, 2),
        'precision': round(precision, 2)
    })

# Load the model
model = load_model(f'chkp/{model_name}.hdf5')

# Initialize results list
results = []

# Evaluate on training data
evaluate_model(model, X_train, y_train, pwrs_array_train, 'Train', 'All', results, train_indices)

# Evaluate on test data for each scenario
for scenario_keyword in ['scenario32', 'scenario33', 'scenario34']:
    scenario_indices = df_train[scenario_path.str.contains(scenario_keyword)].index
    test_los_scenario_indices = np.intersect1d(test_los_indices, scenario_indices)
    test_nlos_scenario_indices = np.intersect1d(test_nlos_indices, scenario_indices)
    
    X_test_los_scenario = lidar[test_los_scenario_indices]
    X_test_nlos_scenario = lidar[test_nlos_scenario_indices]
    y_test_los_scenario = classes[test_los_scenario_indices]
    y_test_nlos_scenario = classes[test_nlos_scenario_indices]
    
    pwrs_array_test_los_scenario = pwrs_array[test_los_scenario_indices]
    pwrs_array_test_nlos_scenario = pwrs_array[test_nlos_scenario_indices]
    
    evaluate_model(model, X_test_los_scenario, y_test_los_scenario, pwrs_array_test_los_scenario, 'Test_LoS', scenario_keyword, results, test_los_scenario_indices)
    evaluate_model(model, X_test_nlos_scenario, y_test_nlos_scenario, pwrs_array_test_nlos_scenario, 'Test_NLoS', scenario_keyword, results, test_nlos_scenario_indices)

# Print all results
for res in results:
    print(f"Scenario: {res['scenario']} - Type: {res['type']} - Accuracies: {res['acc']}, Score: {res['score']}, PF1_mean: {res['PF1_mean']}, PF2_mean: {res['PF2_mean']}, PF3_mean: {res['PF3_mean']}, Recall: {res['recall']}, Precision: {res['precision']}")

gc.collect()
'''
# Out:
# pwrs_array.shape: (11143, 64)
# pwrs_array has 181 NaN values
# pwrs_array after replacement has 0 NaN values
# pwrs_array_train.shape: (10028, 64), pwrs_array_test_los.shape: (1074, 64), pwrs_array_test_nlos.shape: (41, 64)
# 314/314 [==============================] - 6s 19ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 10/10 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 44ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 12/12 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 44ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 13/13 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 45ms/step
# Scenario: All - Type: Train - Accuracies: [0.5768 0.8713 0.9377], Score: 0.9, PF1_mean: 0.97, PF2_mean: 0.98, PF3_mean: 0.99, Recall: 0.58, Precision: 0.58
# Scenario: scenario32 - Type: Test_LoS - Accuracies: [0.3215 0.6334 0.791 ], Score: 0.77, PF1_mean: 0.93, PF2_mean: 0.96, PF3_mean: 0.97, Recall: 0.32, Precision: 0.24
# Scenario: scenario32 - Type: Test_NLoS - Accuracies: [0.0909 0.1818 0.1818], Score: 0.14, PF1_mean: 0.96, PF2_mean: 0.97, PF3_mean: 0.97, Recall: 0.09, Precision: 0.09
# Scenario: scenario33 - Type: Test_LoS - Accuracies: [0.4059 0.6962 0.8199], Score: 0.79, PF1_mean: 0.93, PF2_mean: 0.96, PF3_mean: 0.97, Recall: 0.41, Precision: 0.37
# Scenario: scenario33 - Type: Test_NLoS - Accuracies: [0.     0.0625 0.125 ], Score: 0.05, PF1_mean: 0.9, PF2_mean: 0.91, PF3_mean: 0.91, Recall: 0.0, Precision: 0.0
# Scenario: scenario34 - Type: Test_LoS - Accuracies: [0.3299 0.7136 0.844 ], Score: 0.8, PF1_mean: 0.94, PF2_mean: 0.97, PF3_mean: 0.98, Recall: 0.33, Precision: 0.29
# Scenario: scenario34 - Type: Test_NLoS - Accuracies: [0.0714 0.2143 0.2857], Score: 0.25, PF1_mean: 0.85, PF2_mean: 0.86, PF3_mean: 0.88, Recall: 0.07, Precision: 0.05
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 3977

# %%
# Save results to CSV
df = pd.DataFrame(results)
df.to_csv(f'results_{model_name}.csv', index=False)

# %%
#%% Test on all scens together
#%%Test on Train and Test data (top-1,2,3)

# Model evaluation and prediction
def evaluate_model(model, X_data, y_data, pwrs_array, data_type, result_list, sample_indices):
    predictions = model.predict(X_data)
    y_pred = np.argsort(predictions, axis=1)[:, ::-1]
    save_pred_to_csv(sample_indices, y_pred, top_k=[1,2,3], target_csv=f'preds_{model_name}_{data_type}.csv')
    true = np.argmax(y_data, axis=1).reshape(-1, 1)
    acc = compute_acc(y_pred, true, top_k=[1, 3, 5])
    score = compute_DBA_score(y_pred, true, max_k=3, delta=5)
    recall = recall_score(true, y_pred[:, 0], average='weighted')
    precision = precision_score(true, y_pred[:, 0], average='weighted')
    PF_mean = compute_powerfactor(y_pred, pwrs_array, k=3)
    top_beams = calculate_top_beams(predictions, pwrs_array)
   
    result_list.append({
        'type': data_type,
        'acc': acc,
        'score': round(score, 2),
        'top31_beam': top_beams[0],
        'top33_beam': top_beams[1],
        'PF1_mean': PF_mean[0],
        'PF2_mean': PF_mean[1],
        'PF3_mean': PF_mean[2],
        'recall': round(recall, 2),
        'precision': round(precision, 2)
    })


# Define the seeds used for training
seeds = [42, 123, 456, 789, 101112]

# Placeholder for storing results from all seeds
all_results = []

for seed in seeds:
    print(f"\nEvaluating model with seed {seed}")

    # Train-Test Split with the current seed
    X_train, X_test, y_train, y_test, train_indices, test_indices = train_test_split(
        lidar, classes, np.arange(len(lidar)), test_size=0.1, stratify=classes, random_state=seed)

    gc.collect()

    # Reload the scenario data
    df_train = pd.read_csv('./ml_challenge_dev_multi_modal_v3_all_scenarios_with_LoS_status.csv')

    # Find LoS and NLoS samples in the train and test indices
    train_los_indices = df_train[df_train['LoS_status'] == 'LoS'].index.intersection(train_indices)
    train_nlos_indices = df_train[df_train['LoS_status'] == 'NLoS'].index.intersection(train_indices)
    test_los_indices = df_train[df_train['LoS_status'] == 'LoS'].index.intersection(test_indices)
    test_nlos_indices = df_train[df_train['LoS_status'] == 'NLoS'].index.intersection(test_indices)

    # Extract LoS and NLoS samples from the data and classes
    X_train_los = lidar[train_los_indices]
    X_train_nlos = lidar[train_nlos_indices]
    X_test_los = lidar[test_los_indices]
    X_test_nlos = lidar[test_nlos_indices]
    y_train_los = classes[train_los_indices]
    y_train_nlos = classes[train_nlos_indices]
    y_test_los = classes[test_los_indices]
    y_test_nlos = classes[test_nlos_indices]

    # Power analysis - make sure to get the correct power arrays for each seed
    N_CLASSES = 64
    pwrs_array = np.zeros((df_train.shape[0], N_CLASSES))
    for sample_idx in range(df_train.shape[0]):
        pwr_abs_path = df_train['unit1_pwr_60ghz'].values[sample_idx]
        pwrs_array[sample_idx] = np.loadtxt(pwr_abs_path)

    pwrs_array[np.isnan(pwrs_array)] = 0
    pwrs_array_train = pwrs_array[train_indices]
    pwrs_array_test_los = pwrs_array[test_los_indices]
    pwrs_array_test_nlos = pwrs_array[test_nlos_indices]

    # Load the model corresponding to the current seed
    model = load_model(f'chkp/{model_name}_seed_{seed}.hdf5')

    # Initialize results list for the current seed
    seed_results = []

    # Evaluate on training data
    evaluate_model(model, X_train, y_train, pwrs_array_train, 'Train', seed_results, train_indices)

    # Evaluate on test data
    evaluate_model(model, X_test_los, y_test_los, pwrs_array_test_los, 'Test_LoS', seed_results, test_los_indices)
    evaluate_model(model, X_test_nlos, y_test_nlos, pwrs_array_test_nlos, 'Test_NLoS', seed_results, test_nlos_indices)

    # Store the results of this seed in all_results
    all_results.append(seed_results)

# Function to average results across all seeds
def average_results(all_results, metric):
    averages = {}
    types = ['Train', 'Test_LoS', 'Test_NLoS']
    for data_type in types:
        type_results = [res for seed_res in all_results for res in seed_res if res['type'] == data_type]
        avg_metric = np.mean([res[metric] for res in type_results], axis=0)
        std_metric = np.std([res[metric] for res in type_results], axis=0)
        averages[data_type] = (avg_metric, std_metric)
    return averages

# Compute averages and standard deviations for each metric
avg_accuracies = average_results(all_results, 'acc')
avg_scores = average_results(all_results, 'score')
avg_top31_beams = average_results(all_results, 'top31_beam')
avg_top33_beams = average_results(all_results, 'top33_beam')
avg_PF1_means = average_results(all_results, 'PF1_mean')
avg_PF2_means = average_results(all_results, 'PF2_mean')
avg_PF3_means = average_results(all_results, 'PF3_mean')
avg_recalls = average_results(all_results, 'recall')
avg_precisions = average_results(all_results, 'precision')

# Print the average results across all seeds
print("\nAverage Results Across All Seeds:")
for data_type in avg_accuracies:
    print(f"Type: {data_type} - Avg Accuracies: {avg_accuracies[data_type][0]} ± {avg_accuracies[data_type][1]}, "
          f"Avg Score: {avg_scores[data_type][0]} ± {avg_scores[data_type][1]}, "
          f"top31_beam: {avg_top31_beams[data_type][0]} ± {avg_top31_beams[data_type][1]}, "
          f"top33_beam: {avg_top33_beams[data_type][0]} ± {avg_top33_beams[data_type][1]}, "
          f"PF1_mean: {avg_PF1_means[data_type][0]} ± {avg_PF1_means[data_type][1]}, "
          f"PF2_mean: {avg_PF2_means[data_type][0]} ± {avg_PF2_means[data_type][1]}, "
          f"PF3_mean: {avg_PF3_means[data_type][0]} ± {avg_PF3_means[data_type][1]}, "
          f"Recall: {avg_recalls[data_type][0]} ± {avg_recalls[data_type][1]}, "
          f"Precision: {avg_precisions[data_type][0]} ± {avg_precisions[data_type][1]}")

gc.collect()
# Out:
# Evaluating model with seed 42
# 2024-08-24 22:45:13.424402: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2024-08-24 22:45:13.424432: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: edison
# 2024-08-24 22:45:13.424436: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: edison
# 2024-08-24 22:45:13.424581: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 560.35.3
# 2024-08-24 22:45:13.424614: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: NOT_FOUND: could not find kernel module information in driver version file contents: "NVRM version: NVIDIA UNIX Open Kernel Module for x86_64  560.35.03  Release Build  (dvs-builder@U16-I1-N07-12-3)  Fri Aug 16 21:42:42 UTC 2024
# GCC version:  gcc version 11.4.0 (Ubuntu 11.4.0-1ubuntu1~22.04)
# "
# 2024-08-24 22:45:13.424909: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 314/314 [==============================] - 6s 18ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 34/34 [==============================] - 1s 18ms/step
# 2/2 [==============================] - 0s 27ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Evaluating model with seed 123
# 314/314 [==============================] - 6s 18ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 34/34 [==============================] - 1s 18ms/step
# 2/2 [==============================] - 0s 16ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Evaluating model with seed 456
# 314/314 [==============================] - 6s 18ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 34/34 [==============================] - 1s 19ms/step
# 2/2 [==============================] - 0s 27ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Evaluating model with seed 789
# 314/314 [==============================] - 6s 19ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 34/34 [==============================] - 1s 18ms/step
# 2/2 [==============================] - 0s 20ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Evaluating model with seed 101112
# 314/314 [==============================] - 6s 18ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 34/34 [==============================] - 1s 18ms/step
# 2/2 [==============================] - 0s 14ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Average Results Across All Seeds:
# Type: Train - Avg Accuracies: [0.59976 0.88986 0.94912] ± [0.02473642 0.01084299 0.00400719], Avg Score: 0.9099999999999999 ± 0.008944271909999166, top31_beam: 0.8400000000000001 ± 0.008944271909999166, top33_beam: 0.958 ± 0.0040000000000000036, PF1_mean: 0.97 ± 0.0, PF2_mean: 0.9880000000000001 ± 0.004000000000000004, PF3_mean: 0.99 ± 0.0, Recall: 0.6020000000000001 ± 0.02400000000000002, Precision: 0.6020000000000001 ± 0.02400000000000002
# Type: Test_LoS - Avg Accuracies: [0.3713  0.70958 0.84368] ± [0.0138291  0.01695068 0.01592914], Avg Score: 0.8099999999999999 ± 0.010954451150103291, top31_beam: 0.6979999999999998 ± 0.020396078054371117, top33_beam: 0.884 ± 0.013564659966250548, PF1_mean: 0.938 ± 0.0039999999999999584, PF2_mean: 0.9639999999999999 ± 0.00489897948556636, PF3_mean: 0.9739999999999999 ± 0.00489897948556636, Recall: 0.372 ± 0.013266499161421611, Precision: 0.332 ± 0.017204650534085257
# Type: Test_NLoS - Avg Accuracies: [0.03408 0.14044 0.18878] ± [0.01993463 0.02968802 0.03032197], Avg Score: 0.18 ± 0.03741657386773942, top31_beam: 0.248 ± 0.04019950248448356, top33_beam: 0.426 ± 0.04673328578219169, PF1_mean: 0.8859999999999999 ± 0.014966629547095779, PF2_mean: 0.9119999999999999 ± 0.015999999999999976, PF3_mean: 0.9259999999999999 ± 0.013564659966250508, Recall: 0.034 ± 0.020591260281974, Precision: 0.064 ± 0.06280127387243033
# 10735

# %%
# Define a function to format mean ± std
def format_mean_std(mean, std):
    return f"{mean:.2f} ± {std:.2f}"

# Initialize the final results list
formatted_results = []

# Process the results for saving
for data_type in avg_accuracies:
    acc_means, acc_stds = avg_accuracies[data_type]
    row = {
        'Type': data_type,
        'Acc': ', '.join([format_mean_std(m, s) for m, s in zip(acc_means, acc_stds)]),
        'Score': format_mean_std(*avg_scores[data_type]),
        'top31_beam': format_mean_std(*avg_top31_beams[data_type]),
        'top33_beam': format_mean_std(*avg_top33_beams[data_type]),
        'PF1_mean': format_mean_std(*avg_PF1_means[data_type]),
        'PF2_mean': format_mean_std(*avg_PF2_means[data_type]),
        'PF3_mean': format_mean_std(*avg_PF3_means[data_type]),
        'Recall': format_mean_std(*avg_recalls[data_type]),
        'Precision': format_mean_std(*avg_precisions[data_type])
    }
    formatted_results.append(row)

# Convert the list to a DataFrame
df = pd.DataFrame(formatted_results)

# Save to CSV
df.to_csv(f'results_{model_name}_AllScens.csv', index=False)

print("Results saved to CSV:")
print(df)
# Out:
# Results saved to CSV:
#         Type                                    Acc        Score   top31_beam  \
# 0      Train  0.60 ± 0.02, 0.89 ± 0.01, 0.95 ± 0.00  0.91 ± 0.01  0.84 ± 0.01
# 1   Test_LoS  0.37 ± 0.01, 0.71 ± 0.02, 0.84 ± 0.02  0.81 ± 0.01  0.70 ± 0.02
# 2  Test_NLoS  0.03 ± 0.02, 0.14 ± 0.03, 0.19 ± 0.03  0.18 ± 0.04  0.25 ± 0.04
#
#     top33_beam     PF1_mean     PF2_mean     PF3_mean       Recall  \
# 0  0.96 ± 0.00  0.97 ± 0.00  0.99 ± 0.00  0.99 ± 0.00  0.60 ± 0.02
# 1  0.88 ± 0.01  0.94 ± 0.00  0.96 ± 0.00  0.97 ± 0.00  0.37 ± 0.01
# 2  0.43 ± 0.05  0.89 ± 0.01  0.91 ± 0.02  0.93 ± 0.01  0.03 ± 0.02
#
#      Precision
# 0  0.60 ± 0.02
# 1  0.33 ± 0.02
# 2  0.06 ± 0.06
