# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Apr 19 13:55:28 2023

@author: Saba
"""

'''
To change at each run with different models:
    the name of the file in commands: 
        result.to_csv
    the name of ckpt in:
        callbacks      
        
This is Lidar_Transformed plus Vision data to be trained with CNN to make a multimodal network.
Image (Vision) is transformed from RGB to gray.
'''
import gc
import os
import numpy as np
import pandas as pd
from keras.layers import Conv1D, Conv2D, BatchNormalization, MaxPool1D, MaxPool2D, GlobalMaxPool1D, GlobalMaxPool2D
from keras.layers import TimeDistributed, GRU, Dense, Dropout
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow import keras
from sklearn.metrics import precision_score, recall_score
from keras.models import load_model
from keras.models import Sequential
from sklearn.model_selection import KFold
import matplotlib.lines as mlines
import utm
from collections import Counter
import random
import cv2
import seaborn as sns
import math
import pickle 

np.random.seed(42)
tf.random.set_seed(42)  # Set TensorFlow seed as well
random.seed = 42
     
#%% Main                
#Score function
def compute_acc(y_pred, y_true, top_k=[1,3,5]):
    """ Computes top-k accuracy given prediction and ground truth labels."""
    n_top_k = len(top_k)
    total_hits = np.zeros(n_top_k)
    
    n_test_samples = len(y_true)
    if len(y_pred) != n_test_samples:
        raise Exception('Number of predicted beams does not match number of labels.')
    
    # For each test sample, count times where true beam is in k top guesses
    for samp_idx in range(len(y_true)):
        for k_idx in range(n_top_k):
            hit = np.any(y_pred[samp_idx,:top_k[k_idx]] == y_true[samp_idx, -1])
            total_hits[k_idx] += 1 if hit else 0
    
    # Average the number of correct guesses (over the total samples)
    return np.round(total_hits / len(y_true), 4)

def save_pred_to_csv(sample_index, y_pred, top_k=[1,2,3], target_csv='beam_pred.csv'):
    """ 
    Saves the predicted beam results to a csv file. 
    Expects y_pred: n_samples x N_BEAMS, and saves the top_k columns only. 
    """
    
    cols = [f'top-{i} beam' for i in top_k]
    df = pd.DataFrame(data=y_pred[:, np.array(top_k)-1], columns=cols)
    df.index.name = 'index'
    df['sample_index'] = sample_index
    df.to_csv(target_csv)

def compute_DBA_score(y_pred, y_true, max_k=3, delta=5):
    """ 
    The top-k MBD (Minimum Beam Distance) as the minimum distance
    of any beam in the top-k set of predicted beams to the ground truth beam. 
    
    Then we take the average across all samples.
    
    Then we average that number over all the considered Ks.
    """
    n_samples = y_pred.shape[0]
    #n_beams = y_pred.shape[-1] 
    
    yk = np.zeros(max_k)
    for k in range(max_k):
        acc_avg_min_beam_dist = 0
        idxs_up_to_k = np.arange(k+1)
        for i in range(n_samples):
            aux1 = np.abs(y_pred[i, idxs_up_to_k] - y_true[i]) / delta
            # Compute min between beam diff and 1
            aux2 = np.min(np.stack((aux1, np.zeros_like(aux1)+1), axis=0), axis=0)
            acc_avg_min_beam_dist += np.min(aux2)
            
        yk[k] = 1 - acc_avg_min_beam_dist / n_samples
    
    return np.mean(yk)

#%% Power factor
def compute_powerfactor(y_pred, pwrs_array, k=3):
    '''
    Calculate the maximum power factor for top-1 to top-k predictions.
    
    Args:
    y_pred (numpy array): Sorted predictions (n_samples, 64), indices of beams sorted by probability.
    pwrs_array (numpy array): Power values for beams (n_samples, 64).
    k (int): The top-k predictions to consider.
    
    Returns:
    numpy array: Array of average max PFs from top-1 to top-k.
    '''
    max_Pr = np.max(pwrs_array, axis=1)  # Maximum power across all beams for each sample
    PF_max_k = np.zeros(k)  # Array to store the average of maximum PFs for each top-k
    #PF_max_k_stds = np.zeros(k)  # Array to store the standard deviation of maximum PFs for each top-k
    
    for i in range(1, k+1):
        max_PF = np.zeros(pwrs_array.shape[0])  # Array to hold the max PF for each sample for current top-i
        for j in range(pwrs_array.shape[0]):  # Iterate over each sample
            # Calculate PFs for the top-i predictions and find the maximum
            top_k_PFs = pwrs_array[j, y_pred[j, :i]] / max_Pr[j]
            max_PF[j] = np.max(top_k_PFs)  # Maximum PF for this sample among top-i
        PF_max_k[i-1] = np.round(np.mean(max_PF), 2)  # Average of maximum PFs across all samples for top-i
        #PF_max_k_stds[i-1] = np.round(np.std(max_PF), 2)  # Standard deviation of maximum PFs for top-i

    return PF_max_k #, PF_max_k_stds

def calculate_top_beams(predictions, truths):
    correct_top1_count = 0
    correct_top3_count = 0
    total_count = len(predictions)  # Assuming predictions and truths are lists of numpy arrays
    
    for pred, true in zip(predictions, truths):
        # Find the index of the highest value in the predicted array
        top_pred_index = np.argmax(pred)
        
        # Find the indices of the top 3 highest values in the true array
        top_true_indices = np.argsort(true)[-3:]
        
        # Check if the top predicted index is among the top 3 true indices for top-1 accuracy
        if top_pred_index in top_true_indices:
            correct_top1_count += 1
        
        # Find the indices of the top 3 highest values in the predicted array
        top_pred_indices = np.argsort(pred)[-3:]
        
        # Check if there is any intersection between the top 3 predicted indices and the top 3 true indices for top-3 accuracy
        if set(top_pred_indices) & set(top_true_indices):
            correct_top3_count += 1
    
    # Calculate the percentage of correct predictions for top-1 and top-3 accuracies
    top1_accuracy = (correct_top1_count / total_count)
    top3_accuracy = (correct_top3_count / total_count) 
    top1_accuracy  = round(top1_accuracy, 2)
    top3_accuracy  = round(top3_accuracy, 2)
    return [top1_accuracy,top3_accuracy]
# Out:
# 2024-08-24 23:32:47.523858: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-24 23:32:47.730540: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-24 23:32:48.917475: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/sa457043/miniconda3/envs/tf_jupyter/lib/:/home/sa457043/lib/python3.10/site-packages/nvidia/cudnn/lib:
# 2024-08-24 23:32:48.917566: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/sa457043/miniconda3/envs/tf_jupyter/lib/:/home/sa457043/lib/python3.10/site-packages/nvidia/cudnn/lib:
# 2024-08-24 23:32:48.917574: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
'''
#%% GPU optimization
#
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
        
#
os.environ["TF_GPU_ALLOCATOR"]="cuda_malloc_async" #to allow automatic assignment of operations to different GPUs to prevent OOM issue
'''   

# Set environment variables to disable GPU usage and use CPU instead
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'  # This line disables GPU

# %%
#%% some global params
model_name = "R1_remake_v1_multipleRuns"

# %%
#%%Load data
def add_noise(data, noise_level):
    noisy_data = data + np.random.normal(scale=noise_level, size=data.shape)
    return noisy_data

'''
def add_gps_noise(GPS, noise_level):
    GPS_noisy = np.zeros(GPS.shape)
    GPS_noisy[:,:,0] = GPS[:,:,0] + np.random.normal(scale=noise_level, size=GPS[:,:,0].shape)
    GPS_noisy[:,:,1] = GPS[:,:,1] + np.random.normal(scale=noise_level, size=GPS[:,:,1].shape)
    return GPS_noisy
'''

df_train =  pd.read_csv('./ml_challenge_dev_multi_modal_v2.csv')
index = df_train['unit1_beam'].values

imagex = 150
imagey = 150

import cv2
def rescale(data): #to rescale from 11143x5x210x360 to 11143,5,210,225
    resized_data= np.zeros((data.shape[0],5,imagex,imagey))
    for i in range(data.shape[0]):
        for j in range(data.shape[1]):
            resized_data[i, j] = cv2.resize(data[i, j], (imagey, imagex), interpolation=cv2.INTER_NEAREST)
    return resized_data
    
'''
data = np.load('radar_11143x5x210x360.npz') 
radar = rescale(data['radar'])
radar = add_noise(radar, 0.0025)
'''
os.chdir(r'/home/sa457043/Multimodal_beam_prediction/')
radar = np.load('radar_11143x5x256x64.npz')['radar'] 
print(round(np.min(radar), 2),round(np.max(radar), 2))
radar = rescale(radar)
print(round(np.min(radar), 2),round(np.max(radar), 2))

gc.collect()

classes = to_categorical(df_train['unit1_beam'].values - 1, num_classes = 64, dtype ="int32")
# Out:
# 0.34 190.18
# 0.34 145.74

# %%
#%%Model
def build_convnet(shape=(imagex,imagey)):
    momentum = .9

    model = keras.Sequential()
    model.add(Conv1D(4, 3, input_shape=shape,padding='same', activation='relu'))
    model.add(Conv1D(4, (3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    model.add(MaxPool1D(pool_size=3))
    model.add(MaxPool1D(pool_size=3))
    
    model.add(Conv1D(16, 3, padding='same', activation='relu'))
    model.add(Conv1D(16, (3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    model.add(MaxPool1D(pool_size=3))

    model.add(Conv1D(128, 3, padding='same', activation='relu'))
    model.add(Conv1D(128, (3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    model.add(MaxPool1D(pool_size=3))
    
    model.add(Conv1D(256, 3, padding='same', activation='relu'))
    model.add(Conv1D(256, (3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    
    model.add(GlobalMaxPool1D())
    return model

def GRU_model(input_shape=(5,imagex,imagey), nbout=64): 
    # Create our convnet with (112, 112, 3) input shape
    convnet = build_convnet(input_shape[1:])
    
    # then create our final model
    model = keras.Sequential()
    # add the convnet with (5, 128,125,4) shape
    model.add(TimeDistributed(convnet, input_shape=input_shape))
    # here, you can also use GRU or LSTM
    model.add(GRU(64))
    # and finally, we make a decision network
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(.5))
    
    model.add(Dense(nbout, activation='softmax'))
    return model

# %%
seeds = [42, 123, 456, 789, 101112]

results = []

for seed in seeds:
    print(f"\nRunning model with seed {seed}")

    # Train-Test Split with the current seed
    X_train, X_test, y_train, y_test, train_indices, test_indices = train_test_split(
        radar, classes, np.arange(len(radar)), test_size=0.1, stratify=classes, random_state=seed)

    #%% Scenarios and LoS NLoS analysis of train and test samples
    df_train = pd.read_csv('./ml_challenge_dev_multi_modal_v3_all_scenarios_with_LoS_status.csv')

    # Find LoS and NLoS samples in the train and test indices
    train_los_indices = df_train[df_train['LoS_status'] == 'LoS'].index.intersection(train_indices)
    train_nlos_indices = df_train[df_train['LoS_status'] == 'NLoS'].index.intersection(train_indices)
    test_los_indices = df_train[df_train['LoS_status'] == 'LoS'].index.intersection(test_indices)
    test_nlos_indices = df_train[df_train['LoS_status'] == 'NLoS'].index.intersection(test_indices)

    # Verify that all train and test samples are classified
    assert len(train_los_indices) + len(train_nlos_indices) == len(train_indices), "Mismatch in total train samples"
    assert len(test_los_indices) + len(test_nlos_indices) == len(test_indices), "Mismatch in total test samples"

    # Identify scenarios
    scenario_path = df_train['unit2_loc_1']

    # Function to count LoS and NLoS samples for a scenario
    def count_scenario_samples(scenario_keyword, los_indices, nlos_indices):
        scenario_indices = df_train[scenario_path.str.contains(scenario_keyword)].index
        los_count = len(np.intersect1d(los_indices, scenario_indices))
        nlos_count = len(np.intersect1d(nlos_indices, scenario_indices))
        return los_count, nlos_count

    # Count LoS and NLoS samples for each scenario in train and test sets
    scenario_los_nlos_counts_train = {}
    scenario_los_nlos_counts_test = {}
    for scenario_keyword in ['scenario32', 'scenario33', 'scenario34']:
        los_count_train, nlos_count_train = count_scenario_samples(scenario_keyword, train_los_indices, train_nlos_indices)
        los_count_test, nlos_count_test = count_scenario_samples(scenario_keyword, test_los_indices, test_nlos_indices)
        scenario_los_nlos_counts_train[scenario_keyword] = {'LoS': los_count_train, 'NLoS': nlos_count_train}
        scenario_los_nlos_counts_test[scenario_keyword] = {'LoS': los_count_test, 'NLoS': nlos_count_test}

    # Print the counts for each scenario in train and test sets
    print("Train Data Scenario Counts:")
    for scenario, counts in scenario_los_nlos_counts_train.items():
        print(f"{scenario} - LoS samples count: {counts['LoS']}, NLoS samples count: {counts['NLoS']}")

    print("\nTest Data Scenario Counts:")
    for scenario, counts in scenario_los_nlos_counts_test.items():
        print(f"{scenario} - LoS samples count: {counts['LoS']}, NLoS samples count: {counts['NLoS']}")

    # Extract LoS and NLoS samples from the modalities and classes
    X_train_los = radar[train_los_indices]
    X_train_nlos = radar[train_nlos_indices]
    X_test_los = radar[test_los_indices]
    X_test_nlos = radar[test_nlos_indices]
    y_train_los = classes[train_los_indices]
    y_train_nlos = classes[train_nlos_indices]
    y_test_los = classes[test_los_indices]
    y_test_nlos = classes[test_nlos_indices]

    # Print shapes of train and test datasets for each modality
    print(f'LoS Train Shape: {X_train_los.shape}, LoS Test Shape: {X_test_los.shape}')
    print(f'NLoS Train Shape: {X_train_nlos.shape}, NLoS Test Shape: {X_test_nlos.shape}')

    # Print shapes of train and test labels
    print(f'Train Labels Shape: {y_train.shape}')
    print(f'Test Labels Shape: {y_test.shape}')
    print(f'Train LoS Labels Shape: {y_train_los.shape}')
    print(f'Train NLoS Labels Shape: {y_train_nlos.shape}')
    print(f'Test LoS Labels Shape: {y_test_los.shape}')
    print(f'Test NLoS Labels Shape: {y_test_nlos.shape}')

    gc.collect()

    # some global params
    NBFRAME = 5
    N_CLASSES = 64
    INSHAPE = (5,imagex,imagey)
    model = GRU_model(INSHAPE, N_CLASSES)
    optimizer = keras.optimizers.Adam(0.001) 
    model.compile(optimizer, 'categorical_crossentropy', metrics=['acc'])
    print(model.summary())

    #Run the training
    EPOCHS=300
    BS = 30

    callbacks = [
        keras.callbacks.EarlyStopping(monitor='val_loss', patience=12, mode='min', verbose=1),
        keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=8, mode='min', verbose=1),
        keras.callbacks.ModelCheckpoint(
            f'chkp/{model_name}_seed_{seed}.hdf5', 
            monitor='val_acc',  # Monitor validation accuracy
            save_best_only  = True,
            mode='max',  # Maximize the monitored quantity
            verbose=1),
    ]

    history = model.fit(
        x=X_train,
        y=y_train,
        validation_split = 0.2, #0
        #validation_data=(X_val, y_val),
        verbose=1,
        #verbose='auto', #auto
        epochs=EPOCHS,
        batch_size =BS,
        callbacks=callbacks
    )

    gc.collect()
# Out:
# Running model with seed 42
# Train Data Scenario Counts:
# scenario32 - LoS samples count: 2683, NLoS samples count: 110
# scenario33 - LoS samples count: 3329, NLoS samples count: 120
# scenario34 - LoS samples count: 3691, NLoS samples count: 95
#
# Test Data Scenario Counts:
# scenario32 - LoS samples count: 311, NLoS samples count: 11
# scenario33 - LoS samples count: 372, NLoS samples count: 16
# scenario34 - LoS samples count: 391, NLoS samples count: 14
# LoS Train Shape: (9703, 5, 150, 150), LoS Test Shape: (1074, 5, 150, 150)
# NLoS Train Shape: (325, 5, 150, 150), NLoS Test Shape: (41, 5, 150, 150)
# Train Labels Shape: (10028, 64)
# Test Labels Shape: (1115, 64)
# Train LoS Labels Shape: (9703, 64)
# Train NLoS Labels Shape: (325, 64)
# Test LoS Labels Shape: (1074, 64)
# Test NLoS Labels Shape: (41, 64)
# 2024-08-21 02:07:53.282412: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2024-08-21 02:07:53.282439: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: edison
# 2024-08-21 02:07:53.282443: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: edison
# 2024-08-21 02:07:53.282577: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 560.28.3
# 2024-08-21 02:07:53.282596: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: NOT_FOUND: could not find kernel module information in driver version file contents: "NVRM version: NVIDIA UNIX Open Kernel Module for x86_64  560.28.03  Release Build  (dvs-builder@U16-A24-27-4)  Thu Jul 18 20:46:24 UTC 2024
# GCC version:  gcc version 11.4.0 (Ubuntu 11.4.0-1ubuntu1~22.04)
# "
# 2024-08-21 02:07:53.282844: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 5, 256)           355440
#  ibuted)
#
#  gru (GRU)                   (None, 64)                61824
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
# =================================================================
# Total params: 425,584
# Trainable params: 424,776
# Non-trainable params: 808
# _________________________________________________________________
# None
# Epoch 1/300
# 268/268 [==============================] - ETA: 0s - loss: 3.8744 - acc: 0.0694
# Epoch 1: val_acc improved from -inf to 0.08574, saving model to chkp/R1_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 22s 67ms/step - loss: 3.8744 - acc: 0.0694 - val_loss: 3.7563 - val_acc: 0.0857 - lr: 0.0010
# Epoch 2/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.6353 - acc: 0.0991
# Epoch 2: val_acc improved from 0.08574 to 0.12014, saving model to chkp/R1_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 3.6347 - acc: 0.0991 - val_loss: 3.5064 - val_acc: 0.1201 - lr: 0.0010
# Epoch 3/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.5236 - acc: 0.1187
# Epoch 3: val_acc did not improve from 0.12014
# 268/268 [==============================] - 15s 57ms/step - loss: 3.5235 - acc: 0.1187 - val_loss: 3.7503 - val_acc: 0.0753 - lr: 0.0010
# Epoch 4/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.4392 - acc: 0.1253
# Epoch 4: val_acc improved from 0.12014 to 0.14806, saving model to chkp/R1_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 3.4387 - acc: 0.1254 - val_loss: 3.3080 - val_acc: 0.1481 - lr: 0.0010
# Epoch 5/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.3170 - acc: 0.1439
# Epoch 5: val_acc improved from 0.14806 to 0.15603, saving model to chkp/R1_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 3.3166 - acc: 0.1441 - val_loss: 3.2586 - val_acc: 0.1560 - lr: 0.0010
# Epoch 6/300
# 268/268 [==============================] - ETA: 0s - loss: 3.2374 - acc: 0.1563
# Epoch 6: val_acc improved from 0.15603 to 0.16600, saving model to chkp/R1_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 3.2374 - acc: 0.1563 - val_loss: 3.1685 - val_acc: 0.1660 - lr: 0.0010
# Epoch 7/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.1683 - acc: 0.1653
# Epoch 7: val_acc did not improve from 0.16600
# 268/268 [==============================] - 15s 56ms/step - loss: 3.1680 - acc: 0.1652 - val_loss: 3.2100 - val_acc: 0.1655 - lr: 0.0010
# Epoch 8/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.0850 - acc: 0.1810
# Epoch 8: val_acc did not improve from 0.16600
# 268/268 [==============================] - 15s 55ms/step - loss: 3.0850 - acc: 0.1809 - val_loss: 3.9127 - val_acc: 0.0962 - lr: 0.0010
# Epoch 9/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.0183 - acc: 0.1929
# Epoch 9: val_acc improved from 0.16600 to 0.17996, saving model to chkp/R1_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 3.0176 - acc: 0.1930 - val_loss: 3.0101 - val_acc: 0.1800 - lr: 0.0010
# Epoch 10/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.9408 - acc: 0.2006
# Epoch 10: val_acc improved from 0.17996 to 0.20189, saving model to chkp/R1_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 55ms/step - loss: 2.9413 - acc: 0.2007 - val_loss: 2.9321 - val_acc: 0.2019 - lr: 0.0010
# Epoch 11/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.8827 - acc: 0.2021
# Epoch 11: val_acc did not improve from 0.20189
# 268/268 [==============================] - 15s 56ms/step - loss: 2.8826 - acc: 0.2021 - val_loss: 2.9598 - val_acc: 0.1934 - lr: 0.0010
# Epoch 12/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.7955 - acc: 0.2202
# Epoch 12: val_acc did not improve from 0.20189
# 268/268 [==============================] - 15s 55ms/step - loss: 2.7953 - acc: 0.2203 - val_loss: 3.3438 - val_acc: 0.1486 - lr: 0.0010
# Epoch 13/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.7204 - acc: 0.2282
# Epoch 13: val_acc improved from 0.20189 to 0.20538, saving model to chkp/R1_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 55ms/step - loss: 2.7211 - acc: 0.2279 - val_loss: 2.9456 - val_acc: 0.2054 - lr: 0.0010
# Epoch 14/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.6906 - acc: 0.2383
# Epoch 14: val_acc improved from 0.20538 to 0.24227, saving model to chkp/R1_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.6900 - acc: 0.2383 - val_loss: 2.6952 - val_acc: 0.2423 - lr: 0.0010
# Epoch 15/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.6195 - acc: 0.2578
# Epoch 15: val_acc did not improve from 0.24227
# 268/268 [==============================] - 15s 55ms/step - loss: 2.6194 - acc: 0.2582 - val_loss: 2.8321 - val_acc: 0.2059 - lr: 0.0010
# Epoch 16/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.5574 - acc: 0.2584
# Epoch 16: val_acc improved from 0.24227 to 0.26271, saving model to chkp/R1_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 55ms/step - loss: 2.5580 - acc: 0.2583 - val_loss: 2.5950 - val_acc: 0.2627 - lr: 0.0010
# Epoch 17/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.4955 - acc: 0.2869
# Epoch 17: val_acc did not improve from 0.26271
# 268/268 [==============================] - 15s 55ms/step - loss: 2.4955 - acc: 0.2868 - val_loss: 3.0853 - val_acc: 0.1999 - lr: 0.0010
# Epoch 18/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.4334 - acc: 0.2899
# Epoch 18: val_acc improved from 0.26271 to 0.27318, saving model to chkp/R1_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.4328 - acc: 0.2901 - val_loss: 2.5359 - val_acc: 0.2732 - lr: 0.0010
# Epoch 19/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.3711 - acc: 0.2974
# Epoch 19: val_acc did not improve from 0.27318
# 268/268 [==============================] - 15s 55ms/step - loss: 2.3717 - acc: 0.2973 - val_loss: 2.5889 - val_acc: 0.2622 - lr: 0.0010
# Epoch 20/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.3332 - acc: 0.3000
# Epoch 20: val_acc did not improve from 0.27318
# 268/268 [==============================] - 15s 55ms/step - loss: 2.3330 - acc: 0.3000 - val_loss: 2.5807 - val_acc: 0.2612 - lr: 0.0010
# Epoch 21/300
# 268/268 [==============================] - ETA: 0s - loss: 2.2852 - acc: 0.3130
# Epoch 21: val_acc improved from 0.27318 to 0.28614, saving model to chkp/R1_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.2852 - acc: 0.3130 - val_loss: 2.4292 - val_acc: 0.2861 - lr: 0.0010
# Epoch 22/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.2116 - acc: 0.3210
# Epoch 22: val_acc did not improve from 0.28614
# 268/268 [==============================] - 15s 55ms/step - loss: 2.2113 - acc: 0.3214 - val_loss: 2.4861 - val_acc: 0.2812 - lr: 0.0010
# Epoch 23/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1720 - acc: 0.3352
# Epoch 23: val_acc did not improve from 0.28614
# 268/268 [==============================] - 15s 55ms/step - loss: 2.1732 - acc: 0.3352 - val_loss: 2.4378 - val_acc: 0.2822 - lr: 0.0010
# Epoch 24/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1376 - acc: 0.3377
# Epoch 24: val_acc did not improve from 0.28614
# 268/268 [==============================] - 15s 55ms/step - loss: 2.1386 - acc: 0.3376 - val_loss: 2.9985 - val_acc: 0.2243 - lr: 0.0010
# Epoch 25/300
# 268/268 [==============================] - ETA: 0s - loss: 2.1010 - acc: 0.3427
# Epoch 25: val_acc did not improve from 0.28614
# 268/268 [==============================] - 15s 55ms/step - loss: 2.1010 - acc: 0.3427 - val_loss: 2.6126 - val_acc: 0.2607 - lr: 0.0010
# Epoch 26/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0391 - acc: 0.3546
# Epoch 26: val_acc did not improve from 0.28614
# 268/268 [==============================] - 15s 55ms/step - loss: 2.0386 - acc: 0.3546 - val_loss: 2.6346 - val_acc: 0.2657 - lr: 0.0010
# Epoch 27/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0361 - acc: 0.3566
# Epoch 27: val_acc improved from 0.28614 to 0.29063, saving model to chkp/R1_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.0362 - acc: 0.3566 - val_loss: 2.3701 - val_acc: 0.2906 - lr: 0.0010
# Epoch 28/300
# 268/268 [==============================] - ETA: 0s - loss: 1.9744 - acc: 0.3667
# Epoch 28: val_acc improved from 0.29063 to 0.32403, saving model to chkp/R1_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 55ms/step - loss: 1.9744 - acc: 0.3667 - val_loss: 2.2639 - val_acc: 0.3240 - lr: 0.0010
# Epoch 29/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9472 - acc: 0.3737
# Epoch 29: val_acc did not improve from 0.32403
# 268/268 [==============================] - 15s 55ms/step - loss: 1.9476 - acc: 0.3733 - val_loss: 2.2359 - val_acc: 0.3235 - lr: 0.0010
# Epoch 30/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9327 - acc: 0.3777
# Epoch 30: val_acc did not improve from 0.32403
# 268/268 [==============================] - 15s 55ms/step - loss: 1.9336 - acc: 0.3776 - val_loss: 2.2922 - val_acc: 0.3146 - lr: 0.0010
# Epoch 31/300
# 268/268 [==============================] - ETA: 0s - loss: 1.9163 - acc: 0.3788
# Epoch 31: val_acc did not improve from 0.32403
# 268/268 [==============================] - 15s 55ms/step - loss: 1.9163 - acc: 0.3788 - val_loss: 2.2579 - val_acc: 0.3116 - lr: 0.0010
# Epoch 32/300
# 268/268 [==============================] - ETA: 0s - loss: 1.8720 - acc: 0.3896
# Epoch 32: val_acc did not improve from 0.32403
# 268/268 [==============================] - 15s 55ms/step - loss: 1.8720 - acc: 0.3896 - val_loss: 2.2692 - val_acc: 0.3195 - lr: 0.0010
# Epoch 33/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8228 - acc: 0.4004
# Epoch 33: val_acc improved from 0.32403 to 0.32901, saving model to chkp/R1_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.8241 - acc: 0.4003 - val_loss: 2.2365 - val_acc: 0.3290 - lr: 0.0010
# Epoch 34/300
# 268/268 [==============================] - ETA: 0s - loss: 1.8093 - acc: 0.4048
# Epoch 34: val_acc did not improve from 0.32901
# 268/268 [==============================] - 15s 55ms/step - loss: 1.8093 - acc: 0.4048 - val_loss: 2.3455 - val_acc: 0.3096 - lr: 0.0010
# Epoch 35/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8247 - acc: 0.4050
# Epoch 35: val_acc did not improve from 0.32901
# 268/268 [==============================] - 15s 55ms/step - loss: 1.8251 - acc: 0.4050 - val_loss: 2.4013 - val_acc: 0.2976 - lr: 0.0010
# Epoch 36/300
# 268/268 [==============================] - ETA: 0s - loss: 1.7717 - acc: 0.4110
# Epoch 36: val_acc did not improve from 0.32901
# 268/268 [==============================] - 15s 55ms/step - loss: 1.7717 - acc: 0.4110 - val_loss: 2.3242 - val_acc: 0.3161 - lr: 0.0010
# Epoch 37/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7242 - acc: 0.4237
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 37: val_acc did not improve from 0.32901
# 268/268 [==============================] - 15s 55ms/step - loss: 1.7247 - acc: 0.4237 - val_loss: 2.3467 - val_acc: 0.3046 - lr: 0.0010
# Epoch 38/300
# 268/268 [==============================] - ETA: 0s - loss: 1.5768 - acc: 0.4596
# Epoch 38: val_acc improved from 0.32901 to 0.33998, saving model to chkp/R1_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 55ms/step - loss: 1.5768 - acc: 0.4596 - val_loss: 2.0902 - val_acc: 0.3400 - lr: 1.0000e-04
# Epoch 39/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.5098 - acc: 0.4734
# Epoch 39: val_acc improved from 0.33998 to 0.34696, saving model to chkp/R1_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 55ms/step - loss: 1.5101 - acc: 0.4732 - val_loss: 2.1331 - val_acc: 0.3470 - lr: 1.0000e-04
# Epoch 40/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.4813 - acc: 0.4789
# Epoch 40: val_acc improved from 0.34696 to 0.35194, saving model to chkp/R1_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 55ms/step - loss: 1.4814 - acc: 0.4788 - val_loss: 2.1072 - val_acc: 0.3519 - lr: 1.0000e-04
# Epoch 41/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.4614 - acc: 0.4904
# Epoch 41: val_acc improved from 0.35194 to 0.35942, saving model to chkp/R1_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.4616 - acc: 0.4903 - val_loss: 2.0784 - val_acc: 0.3594 - lr: 1.0000e-04
# Epoch 42/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.4325 - acc: 0.4928
# Epoch 42: val_acc did not improve from 0.35942
# 268/268 [==============================] - 15s 55ms/step - loss: 1.4325 - acc: 0.4930 - val_loss: 2.1226 - val_acc: 0.3584 - lr: 1.0000e-04
# Epoch 43/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.4166 - acc: 0.4906
# Epoch 43: val_acc did not improve from 0.35942
# 268/268 [==============================] - 15s 55ms/step - loss: 1.4160 - acc: 0.4911 - val_loss: 2.1474 - val_acc: 0.3524 - lr: 1.0000e-04
# Epoch 44/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3981 - acc: 0.5009
# Epoch 44: val_acc did not improve from 0.35942
# 268/268 [==============================] - 15s 55ms/step - loss: 1.3994 - acc: 0.5005 - val_loss: 2.1015 - val_acc: 0.3549 - lr: 1.0000e-04
# Epoch 45/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3780 - acc: 0.5069
# Epoch 45: val_acc did not improve from 0.35942
# 268/268 [==============================] - 15s 55ms/step - loss: 1.3783 - acc: 0.5066 - val_loss: 2.0899 - val_acc: 0.3594 - lr: 1.0000e-04
# Epoch 46/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3779 - acc: 0.5139
# Epoch 46: val_acc improved from 0.35942 to 0.36191, saving model to chkp/R1_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 55ms/step - loss: 1.3787 - acc: 0.5132 - val_loss: 2.1122 - val_acc: 0.3619 - lr: 1.0000e-04
# Epoch 47/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3690 - acc: 0.5142
# Epoch 47: val_acc did not improve from 0.36191
# 268/268 [==============================] - 15s 56ms/step - loss: 1.3690 - acc: 0.5141 - val_loss: 2.1327 - val_acc: 0.3500 - lr: 1.0000e-04
# Epoch 48/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3535 - acc: 0.5202
# Epoch 48: val_acc did not improve from 0.36191
# 268/268 [==============================] - 15s 56ms/step - loss: 1.3534 - acc: 0.5202 - val_loss: 2.1003 - val_acc: 0.3594 - lr: 1.0000e-04
# Epoch 49/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3473 - acc: 0.5200
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 49: val_acc improved from 0.36191 to 0.36540, saving model to chkp/R1_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 55ms/step - loss: 1.3481 - acc: 0.5197 - val_loss: 2.0999 - val_acc: 0.3654 - lr: 1.0000e-04
# Epoch 50/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3319 - acc: 0.5185
# Epoch 50: val_acc did not improve from 0.36540
# 268/268 [==============================] - 15s 55ms/step - loss: 1.3322 - acc: 0.5182 - val_loss: 2.1190 - val_acc: 0.3604 - lr: 1.0000e-05
# Epoch 51/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3266 - acc: 0.5270
# Epoch 51: val_acc improved from 0.36540 to 0.36740, saving model to chkp/R1_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 55ms/step - loss: 1.3263 - acc: 0.5269 - val_loss: 2.1083 - val_acc: 0.3674 - lr: 1.0000e-05
# Epoch 52/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3077 - acc: 0.5297
# Epoch 52: val_acc did not improve from 0.36740
# 268/268 [==============================] - 15s 55ms/step - loss: 1.3085 - acc: 0.5294 - val_loss: 2.1357 - val_acc: 0.3569 - lr: 1.0000e-05
# Epoch 53/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3174 - acc: 0.5246
# Epoch 53: val_acc improved from 0.36740 to 0.36889, saving model to chkp/R1_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.3192 - acc: 0.5243 - val_loss: 2.0990 - val_acc: 0.3689 - lr: 1.0000e-05
# Epoch 53: early stopping
#
# Running model with seed 123
# Train Data Scenario Counts:
# scenario32 - LoS samples count: 2729, NLoS samples count: 109
# scenario33 - LoS samples count: 3322, NLoS samples count: 119
# scenario34 - LoS samples count: 3652, NLoS samples count: 97
#
# Test Data Scenario Counts:
# scenario32 - LoS samples count: 265, NLoS samples count: 12
# scenario33 - LoS samples count: 379, NLoS samples count: 17
# scenario34 - LoS samples count: 430, NLoS samples count: 12
# LoS Train Shape: (9703, 5, 150, 150), LoS Test Shape: (1074, 5, 150, 150)
# NLoS Train Shape: (325, 5, 150, 150), NLoS Test Shape: (41, 5, 150, 150)
# Train Labels Shape: (10028, 64)
# Test Labels Shape: (1115, 64)
# Train LoS Labels Shape: (9703, 64)
# Train NLoS Labels Shape: (325, 64)
# Test LoS Labels Shape: (1074, 64)
# Test NLoS Labels Shape: (41, 64)
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_1 (TimeDis  (None, 5, 256)           355440
#  tributed)
#
#  gru_1 (GRU)                 (None, 64)                61824
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 64)                4160
#
# =================================================================
# Total params: 425,584
# Trainable params: 424,776
# Non-trainable params: 808
# _________________________________________________________________
# None
# Epoch 1/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.8683 - acc: 0.0699
# Epoch 1: val_acc improved from -inf to 0.07577, saving model to chkp/R1_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 22s 68ms/step - loss: 3.8681 - acc: 0.0699 - val_loss: 3.8158 - val_acc: 0.0758 - lr: 0.0010
# Epoch 2/300
# 268/268 [==============================] - ETA: 0s - loss: 3.5908 - acc: 0.1037
# Epoch 2: val_acc improved from 0.07577 to 0.13111, saving model to chkp/R1_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 3.5908 - acc: 0.1037 - val_loss: 3.4436 - val_acc: 0.1311 - lr: 0.0010
# Epoch 3/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.4510 - acc: 0.1223
# Epoch 3: val_acc improved from 0.13111 to 0.13709, saving model to chkp/R1_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 3.4510 - acc: 0.1227 - val_loss: 3.3375 - val_acc: 0.1371 - lr: 0.0010
# Epoch 4/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.3196 - acc: 0.1451
# Epoch 4: val_acc improved from 0.13709 to 0.14307, saving model to chkp/R1_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 3.3194 - acc: 0.1450 - val_loss: 3.2647 - val_acc: 0.1431 - lr: 0.0010
# Epoch 5/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.2093 - acc: 0.1608
# Epoch 5: val_acc improved from 0.14307 to 0.17049, saving model to chkp/R1_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 3.2094 - acc: 0.1607 - val_loss: 3.0975 - val_acc: 0.1705 - lr: 0.0010
# Epoch 6/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.1008 - acc: 0.1801
# Epoch 6: val_acc did not improve from 0.17049
# 268/268 [==============================] - 15s 56ms/step - loss: 3.1009 - acc: 0.1801 - val_loss: 3.4095 - val_acc: 0.1296 - lr: 0.0010
# Epoch 7/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.0104 - acc: 0.1890
# Epoch 7: val_acc did not improve from 0.17049
# 268/268 [==============================] - 15s 56ms/step - loss: 3.0100 - acc: 0.1890 - val_loss: 3.4409 - val_acc: 0.1341 - lr: 0.0010
# Epoch 8/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.9232 - acc: 0.2024
# Epoch 8: val_acc did not improve from 0.17049
# 268/268 [==============================] - 15s 56ms/step - loss: 2.9231 - acc: 0.2024 - val_loss: 3.9131 - val_acc: 0.0688 - lr: 0.0010
# Epoch 9/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.7978 - acc: 0.2238
# Epoch 9: val_acc did not improve from 0.17049
# 268/268 [==============================] - 15s 56ms/step - loss: 2.7981 - acc: 0.2238 - val_loss: 3.2932 - val_acc: 0.1421 - lr: 0.0010
# Epoch 10/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.7334 - acc: 0.2391
# Epoch 10: val_acc improved from 0.17049 to 0.21336, saving model to chkp/R1_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.7337 - acc: 0.2390 - val_loss: 2.7696 - val_acc: 0.2134 - lr: 0.0010
# Epoch 11/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.6556 - acc: 0.2438
# Epoch 11: val_acc improved from 0.21336 to 0.22931, saving model to chkp/R1_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.6565 - acc: 0.2437 - val_loss: 2.6262 - val_acc: 0.2293 - lr: 0.0010
# Epoch 12/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.5755 - acc: 0.2558
# Epoch 12: val_acc did not improve from 0.22931
# 268/268 [==============================] - 15s 56ms/step - loss: 2.5761 - acc: 0.2559 - val_loss: 2.7732 - val_acc: 0.2228 - lr: 0.0010
# Epoch 13/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.5059 - acc: 0.2719
# Epoch 13: val_acc did not improve from 0.22931
# 268/268 [==============================] - 15s 56ms/step - loss: 2.5061 - acc: 0.2720 - val_loss: 3.5224 - val_acc: 0.1560 - lr: 0.0010
# Epoch 14/300
# 268/268 [==============================] - ETA: 0s - loss: 2.4090 - acc: 0.2902
# Epoch 14: val_acc improved from 0.22931 to 0.27318, saving model to chkp/R1_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.4090 - acc: 0.2902 - val_loss: 2.4590 - val_acc: 0.2732 - lr: 0.0010
# Epoch 15/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.3628 - acc: 0.2928
# Epoch 15: val_acc improved from 0.27318 to 0.27567, saving model to chkp/R1_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.3645 - acc: 0.2928 - val_loss: 2.4545 - val_acc: 0.2757 - lr: 0.0010
# Epoch 16/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.3409 - acc: 0.3029
# Epoch 16: val_acc did not improve from 0.27567
# 268/268 [==============================] - 15s 56ms/step - loss: 2.3406 - acc: 0.3028 - val_loss: 2.6545 - val_acc: 0.2473 - lr: 0.0010
# Epoch 17/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.2449 - acc: 0.3199
# Epoch 17: val_acc did not improve from 0.27567
# 268/268 [==============================] - 15s 56ms/step - loss: 2.2452 - acc: 0.3200 - val_loss: 3.0803 - val_acc: 0.2064 - lr: 0.0010
# Epoch 18/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1929 - acc: 0.3286
# Epoch 18: val_acc did not improve from 0.27567
# 268/268 [==============================] - 15s 56ms/step - loss: 2.1934 - acc: 0.3285 - val_loss: 3.1401 - val_acc: 0.1630 - lr: 0.0010
# Epoch 19/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1300 - acc: 0.3382
# Epoch 19: val_acc did not improve from 0.27567
# 268/268 [==============================] - 15s 55ms/step - loss: 2.1300 - acc: 0.3383 - val_loss: 2.6484 - val_acc: 0.2458 - lr: 0.0010
# Epoch 20/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1132 - acc: 0.3433
# Epoch 20: val_acc improved from 0.27567 to 0.31057, saving model to chkp/R1_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.1135 - acc: 0.3434 - val_loss: 2.2688 - val_acc: 0.3106 - lr: 0.0010
# Epoch 21/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0620 - acc: 0.3433
# Epoch 21: val_acc did not improve from 0.31057
# 268/268 [==============================] - 15s 56ms/step - loss: 2.0623 - acc: 0.3434 - val_loss: 3.0114 - val_acc: 0.2348 - lr: 0.0010
# Epoch 22/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0474 - acc: 0.3487
# Epoch 22: val_acc did not improve from 0.31057
# 268/268 [==============================] - 15s 56ms/step - loss: 2.0478 - acc: 0.3487 - val_loss: 2.7335 - val_acc: 0.2567 - lr: 0.0010
# Epoch 23/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9944 - acc: 0.3620
# Epoch 23: val_acc improved from 0.31057 to 0.32253, saving model to chkp/R1_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.9941 - acc: 0.3621 - val_loss: 2.2883 - val_acc: 0.3225 - lr: 0.0010
# Epoch 24/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9806 - acc: 0.3684
# Epoch 24: val_acc did not improve from 0.32253
# 268/268 [==============================] - 15s 56ms/step - loss: 1.9809 - acc: 0.3681 - val_loss: 2.4840 - val_acc: 0.2981 - lr: 0.0010
# Epoch 25/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9345 - acc: 0.3733
# Epoch 25: val_acc improved from 0.32253 to 0.33450, saving model to chkp/R1_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 1.9357 - acc: 0.3732 - val_loss: 2.2285 - val_acc: 0.3345 - lr: 0.0010
# Epoch 26/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9285 - acc: 0.3770
# Epoch 26: val_acc did not improve from 0.33450
# 268/268 [==============================] - 15s 55ms/step - loss: 1.9289 - acc: 0.3767 - val_loss: 2.7036 - val_acc: 0.2527 - lr: 0.0010
# Epoch 27/300
# 268/268 [==============================] - ETA: 0s - loss: 1.8759 - acc: 0.3847
# Epoch 27: val_acc did not improve from 0.33450
# 268/268 [==============================] - 15s 56ms/step - loss: 1.8759 - acc: 0.3847 - val_loss: 2.4609 - val_acc: 0.3170 - lr: 0.0010
# Epoch 28/300
# 268/268 [==============================] - ETA: 0s - loss: 1.8528 - acc: 0.3925
# Epoch 28: val_acc did not improve from 0.33450
# 268/268 [==============================] - 15s 56ms/step - loss: 1.8528 - acc: 0.3925 - val_loss: 2.6600 - val_acc: 0.2827 - lr: 0.0010
# Epoch 29/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8346 - acc: 0.4009
# Epoch 29: val_acc did not improve from 0.33450
# 268/268 [==============================] - 15s 56ms/step - loss: 1.8340 - acc: 0.4010 - val_loss: 2.2735 - val_acc: 0.3180 - lr: 0.0010
# Epoch 30/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8002 - acc: 0.3986
# Epoch 30: val_acc did not improve from 0.33450
# 268/268 [==============================] - 15s 56ms/step - loss: 1.8002 - acc: 0.3985 - val_loss: 2.2689 - val_acc: 0.3175 - lr: 0.0010
# Epoch 31/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7630 - acc: 0.4070
# Epoch 31: val_acc did not improve from 0.33450
# 268/268 [==============================] - 15s 55ms/step - loss: 1.7630 - acc: 0.4069 - val_loss: 3.1378 - val_acc: 0.1929 - lr: 0.0010
# Epoch 32/300
# 268/268 [==============================] - ETA: 0s - loss: 1.7465 - acc: 0.4176
# Epoch 32: val_acc improved from 0.33450 to 0.34048, saving model to chkp/R1_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.7465 - acc: 0.4176 - val_loss: 2.2094 - val_acc: 0.3405 - lr: 0.0010
# Epoch 33/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7202 - acc: 0.4215
# Epoch 33: val_acc improved from 0.34048 to 0.36590, saving model to chkp/R1_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.7203 - acc: 0.4213 - val_loss: 2.0889 - val_acc: 0.3659 - lr: 0.0010
# Epoch 34/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7200 - acc: 0.4167
# Epoch 34: val_acc did not improve from 0.36590
# 268/268 [==============================] - 15s 55ms/step - loss: 1.7201 - acc: 0.4167 - val_loss: 3.4359 - val_acc: 0.2154 - lr: 0.0010
# Epoch 35/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6896 - acc: 0.4261
# Epoch 35: val_acc did not improve from 0.36590
# 268/268 [==============================] - 15s 56ms/step - loss: 1.6898 - acc: 0.4260 - val_loss: 2.7343 - val_acc: 0.2851 - lr: 0.0010
# Epoch 36/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6573 - acc: 0.4340
# Epoch 36: val_acc did not improve from 0.36590
# 268/268 [==============================] - 15s 55ms/step - loss: 1.6574 - acc: 0.4339 - val_loss: 2.2551 - val_acc: 0.3435 - lr: 0.0010
# Epoch 37/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6760 - acc: 0.4266
# Epoch 37: val_acc did not improve from 0.36590
# 268/268 [==============================] - 15s 56ms/step - loss: 1.6756 - acc: 0.4265 - val_loss: 2.2538 - val_acc: 0.3564 - lr: 0.0010
# Epoch 38/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6349 - acc: 0.4381
# Epoch 38: val_acc did not improve from 0.36590
# 268/268 [==============================] - 15s 56ms/step - loss: 1.6349 - acc: 0.4380 - val_loss: 2.8417 - val_acc: 0.2807 - lr: 0.0010
# Epoch 39/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.5764 - acc: 0.4519
# Epoch 39: val_acc did not improve from 0.36590
# 268/268 [==============================] - 15s 55ms/step - loss: 1.5762 - acc: 0.4520 - val_loss: 2.2090 - val_acc: 0.3639 - lr: 0.0010
# Epoch 40/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6258 - acc: 0.4417
# Epoch 40: val_acc did not improve from 0.36590
# 268/268 [==============================] - 15s 55ms/step - loss: 1.6255 - acc: 0.4420 - val_loss: 2.3450 - val_acc: 0.3096 - lr: 0.0010
# Epoch 41/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.5920 - acc: 0.4481
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 41: val_acc did not improve from 0.36590
# 268/268 [==============================] - 15s 55ms/step - loss: 1.5920 - acc: 0.4481 - val_loss: 2.1403 - val_acc: 0.3559 - lr: 0.0010
# Epoch 42/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.4683 - acc: 0.4792
# Epoch 42: val_acc improved from 0.36590 to 0.38534, saving model to chkp/R1_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.4673 - acc: 0.4794 - val_loss: 2.0504 - val_acc: 0.3853 - lr: 1.0000e-04
# Epoch 43/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3920 - acc: 0.5004
# Epoch 43: val_acc improved from 0.38534 to 0.38734, saving model to chkp/R1_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.3919 - acc: 0.5005 - val_loss: 2.0642 - val_acc: 0.3873 - lr: 1.0000e-04
# Epoch 44/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3670 - acc: 0.5056
# Epoch 44: val_acc improved from 0.38734 to 0.38983, saving model to chkp/R1_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.3671 - acc: 0.5054 - val_loss: 2.0563 - val_acc: 0.3898 - lr: 1.0000e-04
# Epoch 45/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3378 - acc: 0.5091
# Epoch 45: val_acc did not improve from 0.38983
# 268/268 [==============================] - 15s 56ms/step - loss: 1.3384 - acc: 0.5090 - val_loss: 2.0785 - val_acc: 0.3848 - lr: 1.0000e-04
# Epoch 46/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3151 - acc: 0.5260
# Epoch 46: val_acc did not improve from 0.38983
# 268/268 [==============================] - 15s 56ms/step - loss: 1.3149 - acc: 0.5262 - val_loss: 2.0798 - val_acc: 0.3873 - lr: 1.0000e-04
# Epoch 47/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2924 - acc: 0.5355
# Epoch 47: val_acc did not improve from 0.38983
# 268/268 [==============================] - 15s 55ms/step - loss: 1.2944 - acc: 0.5350 - val_loss: 2.1424 - val_acc: 0.3749 - lr: 1.0000e-04
# Epoch 48/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2732 - acc: 0.5362
# Epoch 48: val_acc did not improve from 0.38983
# 268/268 [==============================] - 15s 55ms/step - loss: 1.2735 - acc: 0.5360 - val_loss: 2.1102 - val_acc: 0.3898 - lr: 1.0000e-04
# Epoch 49/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2899 - acc: 0.5223
# Epoch 49: val_acc improved from 0.38983 to 0.39332, saving model to chkp/R1_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 1.2896 - acc: 0.5226 - val_loss: 2.0957 - val_acc: 0.3933 - lr: 1.0000e-04
# Epoch 50/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2677 - acc: 0.5331
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 50: val_acc improved from 0.39332 to 0.39432, saving model to chkp/R1_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.2677 - acc: 0.5332 - val_loss: 2.1388 - val_acc: 0.3943 - lr: 1.0000e-04
# Epoch 51/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2382 - acc: 0.5458
# Epoch 51: val_acc did not improve from 0.39432
# 268/268 [==============================] - 15s 56ms/step - loss: 1.2385 - acc: 0.5457 - val_loss: 2.1415 - val_acc: 0.3868 - lr: 1.0000e-05
# Epoch 52/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2375 - acc: 0.5464
# Epoch 52: val_acc did not improve from 0.39432
# 268/268 [==============================] - 15s 56ms/step - loss: 1.2379 - acc: 0.5465 - val_loss: 2.1243 - val_acc: 0.3938 - lr: 1.0000e-05
# Epoch 53/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2568 - acc: 0.5442
# Epoch 53: val_acc improved from 0.39432 to 0.39482, saving model to chkp/R1_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.2573 - acc: 0.5439 - val_loss: 2.0899 - val_acc: 0.3948 - lr: 1.0000e-05
# Epoch 54/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2397 - acc: 0.5443
# Epoch 54: val_acc did not improve from 0.39482
# 268/268 [==============================] - 15s 56ms/step - loss: 1.2395 - acc: 0.5440 - val_loss: 2.1158 - val_acc: 0.3938 - lr: 1.0000e-05
# Epoch 54: early stopping
#
# Running model with seed 456
# Train Data Scenario Counts:
# scenario32 - LoS samples count: 2711, NLoS samples count: 107
# scenario33 - LoS samples count: 3317, NLoS samples count: 121
# scenario34 - LoS samples count: 3676, NLoS samples count: 96
#
# Test Data Scenario Counts:
# scenario32 - LoS samples count: 283, NLoS samples count: 14
# scenario33 - LoS samples count: 384, NLoS samples count: 15
# scenario34 - LoS samples count: 406, NLoS samples count: 13
# LoS Train Shape: (9704, 5, 150, 150), LoS Test Shape: (1073, 5, 150, 150)
# NLoS Train Shape: (324, 5, 150, 150), NLoS Test Shape: (42, 5, 150, 150)
# Train Labels Shape: (10028, 64)
# Test Labels Shape: (1115, 64)
# Train LoS Labels Shape: (9704, 64)
# Train NLoS Labels Shape: (324, 64)
# Test LoS Labels Shape: (1073, 64)
# Test NLoS Labels Shape: (42, 64)
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_2 (TimeDis  (None, 5, 256)           355440
#  tributed)
#
#  gru_2 (GRU)                 (None, 64)                61824
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 64)                4160
#
# =================================================================
# Total params: 425,584
# Trainable params: 424,776
# Non-trainable params: 808
# _________________________________________________________________
# None
# Epoch 1/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.8693 - acc: 0.0769
# Epoch 1: val_acc improved from -inf to 0.08076, saving model to chkp/R1_remake_v1_multipleRuns_seed_456.hdf5
# 268/268 [==============================] - 20s 62ms/step - loss: 3.8685 - acc: 0.0772 - val_loss: 3.7684 - val_acc: 0.0808 - lr: 0.0010
# Epoch 2/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.6102 - acc: 0.1145
# Epoch 2: val_acc improved from 0.08076 to 0.12014, saving model to chkp/R1_remake_v1_multipleRuns_seed_456.hdf5
# 268/268 [==============================] - 15s 55ms/step - loss: 3.6100 - acc: 0.1143 - val_loss: 3.4636 - val_acc: 0.1201 - lr: 0.0010
# Epoch 3/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.4806 - acc: 0.1318
# Epoch 3: val_acc did not improve from 0.12014
# 268/268 [==============================] - 15s 55ms/step - loss: 3.4797 - acc: 0.1321 - val_loss: 3.7251 - val_acc: 0.1092 - lr: 0.0010
# Epoch 4/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.3484 - acc: 0.1431
# Epoch 4: val_acc improved from 0.12014 to 0.15254, saving model to chkp/R1_remake_v1_multipleRuns_seed_456.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 3.3487 - acc: 0.1429 - val_loss: 3.3096 - val_acc: 0.1525 - lr: 0.0010
# Epoch 5/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.2658 - acc: 0.1582
# Epoch 5: val_acc improved from 0.15254 to 0.17498, saving model to chkp/R1_remake_v1_multipleRuns_seed_456.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 3.2657 - acc: 0.1581 - val_loss: 3.0723 - val_acc: 0.1750 - lr: 0.0010
# Epoch 6/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.1564 - acc: 0.1688
# Epoch 6: val_acc improved from 0.17498 to 0.18644, saving model to chkp/R1_remake_v1_multipleRuns_seed_456.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 3.1557 - acc: 0.1689 - val_loss: 3.0627 - val_acc: 0.1864 - lr: 0.0010
# Epoch 7/300
# 268/268 [==============================] - ETA: 0s - loss: 3.0583 - acc: 0.1851
# Epoch 7: val_acc improved from 0.18644 to 0.19442, saving model to chkp/R1_remake_v1_multipleRuns_seed_456.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 3.0583 - acc: 0.1851 - val_loss: 2.9583 - val_acc: 0.1944 - lr: 0.0010
# Epoch 8/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.9575 - acc: 0.2034
# Epoch 8: val_acc did not improve from 0.19442
# 268/268 [==============================] - 15s 55ms/step - loss: 2.9569 - acc: 0.2036 - val_loss: 3.1225 - val_acc: 0.1540 - lr: 0.0010
# Epoch 9/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.8931 - acc: 0.2077
# Epoch 9: val_acc improved from 0.19442 to 0.19990, saving model to chkp/R1_remake_v1_multipleRuns_seed_456.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.8940 - acc: 0.2076 - val_loss: 2.8881 - val_acc: 0.1999 - lr: 0.0010
# Epoch 10/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.8162 - acc: 0.2242
# Epoch 10: val_acc did not improve from 0.19990
# 268/268 [==============================] - 15s 55ms/step - loss: 2.8167 - acc: 0.2243 - val_loss: 2.9098 - val_acc: 0.1964 - lr: 0.0010
# Epoch 11/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.7347 - acc: 0.2416
# Epoch 11: val_acc did not improve from 0.19990
# 268/268 [==============================] - 15s 55ms/step - loss: 2.7355 - acc: 0.2413 - val_loss: 3.6754 - val_acc: 0.1132 - lr: 0.0010
# Epoch 12/300
# 268/268 [==============================] - ETA: 0s - loss: 2.6435 - acc: 0.2508
# Epoch 12: val_acc improved from 0.19990 to 0.24925, saving model to chkp/R1_remake_v1_multipleRuns_seed_456.hdf5
# 268/268 [==============================] - 15s 55ms/step - loss: 2.6435 - acc: 0.2508 - val_loss: 2.5810 - val_acc: 0.2493 - lr: 0.0010
# Epoch 13/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.5751 - acc: 0.2528
# Epoch 13: val_acc did not improve from 0.24925
# 268/268 [==============================] - 15s 55ms/step - loss: 2.5755 - acc: 0.2527 - val_loss: 2.6961 - val_acc: 0.2338 - lr: 0.0010
# Epoch 14/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.5236 - acc: 0.2724
# Epoch 14: val_acc did not improve from 0.24925
# 268/268 [==============================] - 15s 56ms/step - loss: 2.5245 - acc: 0.2721 - val_loss: 2.8888 - val_acc: 0.1994 - lr: 0.0010
# Epoch 15/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.4564 - acc: 0.2764
# Epoch 15: val_acc did not improve from 0.24925
# 268/268 [==============================] - 15s 56ms/step - loss: 2.4566 - acc: 0.2762 - val_loss: 3.0343 - val_acc: 0.2069 - lr: 0.0010
# Epoch 16/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.3840 - acc: 0.2951
# Epoch 16: val_acc did not improve from 0.24925
# 268/268 [==============================] - 15s 56ms/step - loss: 2.3828 - acc: 0.2954 - val_loss: 3.0166 - val_acc: 0.1869 - lr: 0.0010
# Epoch 17/300
# 268/268 [==============================] - ETA: 0s - loss: 2.3194 - acc: 0.3079
# Epoch 17: val_acc improved from 0.24925 to 0.28016, saving model to chkp/R1_remake_v1_multipleRuns_seed_456.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.3194 - acc: 0.3079 - val_loss: 2.3519 - val_acc: 0.2802 - lr: 0.0010
# Epoch 18/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.2709 - acc: 0.3081
# Epoch 18: val_acc improved from 0.28016 to 0.28863, saving model to chkp/R1_remake_v1_multipleRuns_seed_456.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.2721 - acc: 0.3078 - val_loss: 2.3558 - val_acc: 0.2886 - lr: 0.0010
# Epoch 19/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.2056 - acc: 0.3189
# Epoch 19: val_acc improved from 0.28863 to 0.29113, saving model to chkp/R1_remake_v1_multipleRuns_seed_456.hdf5
# 268/268 [==============================] - 15s 55ms/step - loss: 2.2056 - acc: 0.3187 - val_loss: 2.3126 - val_acc: 0.2911 - lr: 0.0010
# Epoch 20/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1782 - acc: 0.3266
# Epoch 20: val_acc did not improve from 0.29113
# 268/268 [==============================] - 15s 56ms/step - loss: 2.1782 - acc: 0.3266 - val_loss: 2.6068 - val_acc: 0.2602 - lr: 0.0010
# Epoch 21/300
# 268/268 [==============================] - ETA: 0s - loss: 2.1276 - acc: 0.3396
# Epoch 21: val_acc improved from 0.29113 to 0.30708, saving model to chkp/R1_remake_v1_multipleRuns_seed_456.hdf5
# 268/268 [==============================] - 15s 55ms/step - loss: 2.1276 - acc: 0.3396 - val_loss: 2.2284 - val_acc: 0.3071 - lr: 0.0010
# Epoch 22/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0977 - acc: 0.3487
# Epoch 22: val_acc did not improve from 0.30708
# 268/268 [==============================] - 15s 55ms/step - loss: 2.0983 - acc: 0.3488 - val_loss: 2.7226 - val_acc: 0.2443 - lr: 0.0010
# Epoch 23/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0578 - acc: 0.3537
# Epoch 23: val_acc improved from 0.30708 to 0.31356, saving model to chkp/R1_remake_v1_multipleRuns_seed_456.hdf5
# 268/268 [==============================] - 15s 55ms/step - loss: 2.0580 - acc: 0.3537 - val_loss: 2.1606 - val_acc: 0.3136 - lr: 0.0010
# Epoch 24/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0313 - acc: 0.3552
# Epoch 24: val_acc improved from 0.31356 to 0.32453, saving model to chkp/R1_remake_v1_multipleRuns_seed_456.hdf5
# 268/268 [==============================] - 15s 55ms/step - loss: 2.0318 - acc: 0.3553 - val_loss: 2.1900 - val_acc: 0.3245 - lr: 0.0010
# Epoch 25/300
# 268/268 [==============================] - ETA: 0s - loss: 1.9837 - acc: 0.3595
# Epoch 25: val_acc did not improve from 0.32453
# 268/268 [==============================] - 15s 55ms/step - loss: 1.9837 - acc: 0.3595 - val_loss: 2.1955 - val_acc: 0.3086 - lr: 0.0010
# Epoch 26/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9317 - acc: 0.3782
# Epoch 26: val_acc did not improve from 0.32453
# ...
# Epoch 5/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.2947 - acc: 0.1527
# Epoch 5: val_acc improved from 0.10568 to 0.13111, saving model to chkp/R1_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 3.2948 - acc: 0.1526 - val_loss: 3.3574 - val_acc: 0.1311 - lr: 0.0010
# Epoch 6/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.2093 - acc: 0.1591
# Epoch 6: val_acc improved from 0.13111 to 0.15753, saving model to chkp/R1_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 3.2093 - acc: 0.1592 - val_loss: 3.1827 - val_acc: 0.1575 - lr: 0.0010
# Epoch 7/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.1173 - acc: 0.1748
# Epoch 7: val_acc did not improve from 0.15753
# 268/268 [==============================] - 15s 55ms/step - loss: 3.1179 - acc: 0.1748 - val_loss: 3.2539 - val_acc: 0.1261 - lr: 0.0010
# Epoch 8/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.0249 - acc: 0.1888
# Epoch 8: val_acc improved from 0.15753 to 0.17597, saving model to chkp/R1_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 3.0245 - acc: 0.1890 - val_loss: 3.0607 - val_acc: 0.1760 - lr: 0.0010
# Epoch 9/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.9489 - acc: 0.2006
# Epoch 9: val_acc improved from 0.17597 to 0.19492, saving model to chkp/R1_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 55ms/step - loss: 2.9486 - acc: 0.2008 - val_loss: 2.8996 - val_acc: 0.1949 - lr: 0.0010
# Epoch 10/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.8669 - acc: 0.2071
# Epoch 10: val_acc improved from 0.19492 to 0.20189, saving model to chkp/R1_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.8670 - acc: 0.2071 - val_loss: 2.8924 - val_acc: 0.2019 - lr: 0.0010
# Epoch 11/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.7723 - acc: 0.2230
# Epoch 11: val_acc did not improve from 0.20189
# 268/268 [==============================] - 15s 56ms/step - loss: 2.7722 - acc: 0.2230 - val_loss: 3.0183 - val_acc: 0.1760 - lr: 0.0010
# Epoch 12/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.6970 - acc: 0.2423
# Epoch 12: val_acc did not improve from 0.20189
# 268/268 [==============================] - 15s 55ms/step - loss: 2.6964 - acc: 0.2422 - val_loss: 2.9648 - val_acc: 0.1989 - lr: 0.0010
# Epoch 13/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.6151 - acc: 0.2561
# Epoch 13: val_acc improved from 0.20189 to 0.23380, saving model to chkp/R1_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.6156 - acc: 0.2563 - val_loss: 2.7738 - val_acc: 0.2338 - lr: 0.0010
# Epoch 14/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.5293 - acc: 0.2652
# Epoch 14: val_acc improved from 0.23380 to 0.24626, saving model to chkp/R1_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.5305 - acc: 0.2648 - val_loss: 2.5802 - val_acc: 0.2463 - lr: 0.0010
# Epoch 15/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.4672 - acc: 0.2739
# Epoch 15: val_acc did not improve from 0.24626
# 268/268 [==============================] - 15s 55ms/step - loss: 2.4671 - acc: 0.2739 - val_loss: 2.7308 - val_acc: 0.2283 - lr: 0.0010
# Epoch 16/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.4284 - acc: 0.2831
# Epoch 16: val_acc improved from 0.24626 to 0.26969, saving model to chkp/R1_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.4280 - acc: 0.2832 - val_loss: 2.5376 - val_acc: 0.2697 - lr: 0.0010
# Epoch 17/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.3407 - acc: 0.2989
# Epoch 17: val_acc improved from 0.26969 to 0.27168, saving model to chkp/R1_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.3401 - acc: 0.2989 - val_loss: 2.4764 - val_acc: 0.2717 - lr: 0.0010
# Epoch 18/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.3020 - acc: 0.3016
# Epoch 18: val_acc improved from 0.27168 to 0.27517, saving model to chkp/R1_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 2.3016 - acc: 0.3015 - val_loss: 2.4194 - val_acc: 0.2752 - lr: 0.0010
# Epoch 19/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.2268 - acc: 0.3149
# Epoch 19: val_acc improved from 0.27517 to 0.28863, saving model to chkp/R1_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 2.2273 - acc: 0.3150 - val_loss: 2.4575 - val_acc: 0.2886 - lr: 0.0010
# Epoch 20/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1671 - acc: 0.3345
# Epoch 20: val_acc did not improve from 0.28863
# 268/268 [==============================] - 15s 56ms/step - loss: 2.1681 - acc: 0.3341 - val_loss: 2.5602 - val_acc: 0.2632 - lr: 0.0010
# Epoch 21/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1019 - acc: 0.3439
# Epoch 21: val_acc did not improve from 0.28863
# 268/268 [==============================] - 15s 56ms/step - loss: 2.1030 - acc: 0.3439 - val_loss: 2.4751 - val_acc: 0.2807 - lr: 0.0010
# Epoch 22/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1009 - acc: 0.3422
# Epoch 22: val_acc did not improve from 0.28863
# 268/268 [==============================] - 15s 56ms/step - loss: 2.1007 - acc: 0.3422 - val_loss: 2.6075 - val_acc: 0.2637 - lr: 0.0010
# Epoch 23/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0654 - acc: 0.3613
# Epoch 23: val_acc improved from 0.28863 to 0.30209, saving model to chkp/R1_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 2.0656 - acc: 0.3614 - val_loss: 2.3251 - val_acc: 0.3021 - lr: 0.0010
# Epoch 24/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0081 - acc: 0.3596
# Epoch 24: val_acc did not improve from 0.30209
# 268/268 [==============================] - 15s 56ms/step - loss: 2.0093 - acc: 0.3594 - val_loss: 2.3975 - val_acc: 0.2991 - lr: 0.0010
# Epoch 25/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9591 - acc: 0.3674
# Epoch 25: val_acc improved from 0.30209 to 0.31406, saving model to chkp/R1_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.9611 - acc: 0.3670 - val_loss: 2.2446 - val_acc: 0.3141 - lr: 0.0010
# Epoch 26/300
# 268/268 [==============================] - ETA: 0s - loss: 1.9123 - acc: 0.3755
# Epoch 26: val_acc improved from 0.31406 to 0.33300, saving model to chkp/R1_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.9123 - acc: 0.3755 - val_loss: 2.2760 - val_acc: 0.3330 - lr: 0.0010
# Epoch 27/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9054 - acc: 0.3800
# Epoch 27: val_acc improved from 0.33300 to 0.33998, saving model to chkp/R1_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.9055 - acc: 0.3800 - val_loss: 2.1710 - val_acc: 0.3400 - lr: 0.0010
# Epoch 28/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8560 - acc: 0.3845
# Epoch 28: val_acc did not improve from 0.33998
# 268/268 [==============================] - 15s 56ms/step - loss: 1.8560 - acc: 0.3843 - val_loss: 2.2755 - val_acc: 0.3200 - lr: 0.0010
# Epoch 29/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8219 - acc: 0.4016
# Epoch 29: val_acc did not improve from 0.33998
# 268/268 [==============================] - 15s 55ms/step - loss: 1.8232 - acc: 0.4013 - val_loss: 2.4185 - val_acc: 0.3036 - lr: 0.0010
# Epoch 30/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8410 - acc: 0.3915
# Epoch 30: val_acc did not improve from 0.33998
# 268/268 [==============================] - 15s 55ms/step - loss: 1.8429 - acc: 0.3914 - val_loss: 3.6340 - val_acc: 0.2069 - lr: 0.0010
# Epoch 31/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8003 - acc: 0.4032
# Epoch 31: val_acc did not improve from 0.33998
# 268/268 [==============================] - 15s 56ms/step - loss: 1.8006 - acc: 0.4031 - val_loss: 2.2875 - val_acc: 0.3275 - lr: 0.0010
# Epoch 32/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7690 - acc: 0.4086
# Epoch 32: val_acc did not improve from 0.33998
# 268/268 [==============================] - 15s 56ms/step - loss: 1.7698 - acc: 0.4084 - val_loss: 2.3366 - val_acc: 0.3195 - lr: 0.0010
# Epoch 33/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7599 - acc: 0.4091
# Epoch 33: val_acc did not improve from 0.33998
# 268/268 [==============================] - 15s 56ms/step - loss: 1.7596 - acc: 0.4088 - val_loss: 2.3535 - val_acc: 0.3081 - lr: 0.0010
# Epoch 34/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7372 - acc: 0.4164
# Epoch 34: val_acc did not improve from 0.33998
# 268/268 [==============================] - 15s 56ms/step - loss: 1.7378 - acc: 0.4160 - val_loss: 2.4197 - val_acc: 0.3056 - lr: 0.0010
# Epoch 35/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6884 - acc: 0.4241
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 35: val_acc did not improve from 0.33998
# 268/268 [==============================] - 15s 56ms/step - loss: 1.6890 - acc: 0.4238 - val_loss: 2.3063 - val_acc: 0.3270 - lr: 0.0010
# Epoch 36/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.5337 - acc: 0.4618
# Epoch 36: val_acc improved from 0.33998 to 0.36690, saving model to chkp/R1_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.5334 - acc: 0.4617 - val_loss: 2.1217 - val_acc: 0.3669 - lr: 1.0000e-04
# Epoch 37/300
# 268/268 [==============================] - ETA: 0s - loss: 1.4828 - acc: 0.4756
# Epoch 37: val_acc improved from 0.36690 to 0.37188, saving model to chkp/R1_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.4828 - acc: 0.4756 - val_loss: 2.1238 - val_acc: 0.3719 - lr: 1.0000e-04
# Epoch 38/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.4521 - acc: 0.4874
# Epoch 38: val_acc improved from 0.37188 to 0.37338, saving model to chkp/R1_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.4518 - acc: 0.4874 - val_loss: 2.1298 - val_acc: 0.3734 - lr: 1.0000e-04
# Epoch 39/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.4226 - acc: 0.4909
# Epoch 39: val_acc did not improve from 0.37338
# 268/268 [==============================] - 15s 55ms/step - loss: 1.4233 - acc: 0.4907 - val_loss: 2.1413 - val_acc: 0.3719 - lr: 1.0000e-04
# Epoch 40/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.4140 - acc: 0.4948
# Epoch 40: val_acc improved from 0.37338 to 0.37537, saving model to chkp/R1_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 1.4151 - acc: 0.4945 - val_loss: 2.1244 - val_acc: 0.3754 - lr: 1.0000e-04
# Epoch 41/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3956 - acc: 0.4950
# Epoch 41: val_acc did not improve from 0.37537
# 268/268 [==============================] - 15s 56ms/step - loss: 1.3962 - acc: 0.4954 - val_loss: 2.1704 - val_acc: 0.3664 - lr: 1.0000e-04
# Epoch 42/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3670 - acc: 0.5080
# Epoch 42: val_acc did not improve from 0.37537
# 268/268 [==============================] - 15s 56ms/step - loss: 1.3688 - acc: 0.5075 - val_loss: 2.1845 - val_acc: 0.3634 - lr: 1.0000e-04
# Epoch 43/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3755 - acc: 0.5026
# Epoch 43: val_acc did not improve from 0.37537
# 268/268 [==============================] - 15s 56ms/step - loss: 1.3767 - acc: 0.5021 - val_loss: 2.1148 - val_acc: 0.3729 - lr: 1.0000e-04
# Epoch 44/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3417 - acc: 0.5184
# Epoch 44: val_acc did not improve from 0.37537
# 268/268 [==============================] - 15s 56ms/step - loss: 1.3422 - acc: 0.5181 - val_loss: 2.1409 - val_acc: 0.3739 - lr: 1.0000e-04
# Epoch 45/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3350 - acc: 0.5211
# Epoch 45: val_acc improved from 0.37537 to 0.37787, saving model to chkp/R1_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 1.3355 - acc: 0.5206 - val_loss: 2.1454 - val_acc: 0.3779 - lr: 1.0000e-04
# Epoch 46/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3216 - acc: 0.5180
# Epoch 46: val_acc improved from 0.37787 to 0.38584, saving model to chkp/R1_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.3216 - acc: 0.5180 - val_loss: 2.1575 - val_acc: 0.3858 - lr: 1.0000e-04
# Epoch 47/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3075 - acc: 0.5231
# Epoch 47: val_acc did not improve from 0.38584
# 268/268 [==============================] - 15s 56ms/step - loss: 1.3077 - acc: 0.5229 - val_loss: 2.1587 - val_acc: 0.3824 - lr: 1.0000e-04
# Epoch 48/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2856 - acc: 0.5357
# Epoch 48: val_acc improved from 0.38584 to 0.38634, saving model to chkp/R1_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 57ms/step - loss: 1.2851 - acc: 0.5359 - val_loss: 2.1673 - val_acc: 0.3863 - lr: 1.0000e-04
# Epoch 49/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2934 - acc: 0.5330
# Epoch 49: val_acc did not improve from 0.38634
# 268/268 [==============================] - 15s 56ms/step - loss: 1.2938 - acc: 0.5329 - val_loss: 2.1917 - val_acc: 0.3814 - lr: 1.0000e-04
# Epoch 50/300
# 268/268 [==============================] - ETA: 0s - loss: 1.2779 - acc: 0.5405
# Epoch 50: val_acc did not improve from 0.38634
# 268/268 [==============================] - 15s 56ms/step - loss: 1.2779 - acc: 0.5405 - val_loss: 2.1795 - val_acc: 0.3843 - lr: 1.0000e-04
# Epoch 51/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2939 - acc: 0.5246
# Epoch 51: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 51: val_acc did not improve from 0.38634
# 268/268 [==============================] - 15s 56ms/step - loss: 1.2943 - acc: 0.5247 - val_loss: 2.2173 - val_acc: 0.3729 - lr: 1.0000e-04
# Epoch 52/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2544 - acc: 0.5397
# Epoch 52: val_acc did not improve from 0.38634
# 268/268 [==============================] - 15s 56ms/step - loss: 1.2578 - acc: 0.5394 - val_loss: 2.2525 - val_acc: 0.3634 - lr: 1.0000e-05
# Epoch 53/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2467 - acc: 0.5476
# Epoch 53: val_acc did not improve from 0.38634
# 268/268 [==============================] - 15s 56ms/step - loss: 1.2472 - acc: 0.5475 - val_loss: 2.1862 - val_acc: 0.3833 - lr: 1.0000e-05
# Epoch 54/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2563 - acc: 0.5417
# Epoch 54: val_acc improved from 0.38634 to 0.39033, saving model to chkp/R1_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 15s 56ms/step - loss: 1.2566 - acc: 0.5418 - val_loss: 2.1994 - val_acc: 0.3903 - lr: 1.0000e-05
# Epoch 55/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2389 - acc: 0.5448
# Epoch 55: val_acc did not improve from 0.39033
# 268/268 [==============================] - 15s 56ms/step - loss: 1.2398 - acc: 0.5446 - val_loss: 2.4342 - val_acc: 0.3395 - lr: 1.0000e-05
# Epoch 55: early stopping

# %%
#%% Test on all scens together
#%%Test on Train and Test data (top-1,2,3)

# Model evaluation and prediction
def evaluate_model(model, X_data, y_data, pwrs_array, data_type, result_list, sample_indices):
    predictions = model.predict(X_data)
    y_pred = np.argsort(predictions, axis=1)[:, ::-1]
    save_pred_to_csv(sample_indices, y_pred, top_k=[1,2,3], target_csv=f'preds_{model_name}_{data_type}.csv')
    true = np.argmax(y_data, axis=1).reshape(-1, 1)
    acc = compute_acc(y_pred, true, top_k=[1, 3, 5])
    score = compute_DBA_score(y_pred, true, max_k=3, delta=5)
    recall = recall_score(true, y_pred[:, 0], average='weighted')
    precision = precision_score(true, y_pred[:, 0], average='weighted')
    PF_mean = compute_powerfactor(y_pred, pwrs_array, k=3)
    top_beams = calculate_top_beams(predictions, pwrs_array)
   
    result_list.append({
        'type': data_type,
        'acc': acc,
        'score': round(score, 2),
        'top31_beam': top_beams[0],
        'top33_beam': top_beams[1],
        'PF1_mean': PF_mean[0],
        'PF2_mean': PF_mean[1],
        'PF3_mean': PF_mean[2],
        'recall': round(recall, 2),
        'precision': round(precision, 2)
    })


# Define the seeds used for training
seeds = [42, 123, 456, 789, 101112]

# Placeholder for storing results from all seeds
all_results = []

for seed in seeds:
    print(f"\nEvaluating model with seed {seed}")

    # Train-Test Split with the current seed
    X_train, X_test, y_train, y_test, train_indices, test_indices = train_test_split(
        radar, classes, np.arange(len(radar)), test_size=0.1, stratify=classes, random_state=seed)

    gc.collect()

    # Reload the scenario data
    df_train = pd.read_csv('./ml_challenge_dev_multi_modal_v3_all_scenarios_with_LoS_status.csv')

    # Find LoS and NLoS samples in the train and test indices
    train_los_indices = df_train[df_train['LoS_status'] == 'LoS'].index.intersection(train_indices)
    train_nlos_indices = df_train[df_train['LoS_status'] == 'NLoS'].index.intersection(train_indices)
    test_los_indices = df_train[df_train['LoS_status'] == 'LoS'].index.intersection(test_indices)
    test_nlos_indices = df_train[df_train['LoS_status'] == 'NLoS'].index.intersection(test_indices)

    # Extract LoS and NLoS samples from the data and classes
    X_test_los = radar[test_los_indices]
    X_test_nlos = radar[test_nlos_indices]
    y_test_los = classes[test_los_indices]
    y_test_nlos = classes[test_nlos_indices]

    # Power analysis - make sure to get the correct power arrays for each seed
    N_CLASSES = 64
    pwrs_array = np.zeros((df_train.shape[0], N_CLASSES))
    for sample_idx in range(df_train.shape[0]):
        pwr_abs_path = df_train['unit1_pwr_60ghz'].values[sample_idx]
        pwrs_array[sample_idx] = np.loadtxt(pwr_abs_path)

    pwrs_array[np.isnan(pwrs_array)] = 0
    pwrs_array_train = pwrs_array[train_indices]
    pwrs_array_test_los = pwrs_array[test_los_indices]
    pwrs_array_test_nlos = pwrs_array[test_nlos_indices]

    # Load the model corresponding to the current seed
    model = load_model(f'chkp/{model_name}_seed_{seed}.hdf5')

    # Initialize results list for the current seed
    seed_results = []

    # Evaluate on training data
    evaluate_model(model, X_train, y_train, pwrs_array_train, 'Train', seed_results, train_indices)

    # Evaluate on test data
    evaluate_model(model, X_test_los, y_test_los, pwrs_array_test_los, 'Test_LoS', seed_results, test_los_indices)
    evaluate_model(model, X_test_nlos, y_test_nlos, pwrs_array_test_nlos, 'Test_NLoS', seed_results, test_nlos_indices)

    # Store the results of this seed in all_results
    all_results.append(seed_results)

# Function to average results across all seeds
def average_results(all_results, metric):
    averages = {}
    types = ['Train', 'Test_LoS', 'Test_NLoS']
    for data_type in types:
        type_results = [res for seed_res in all_results for res in seed_res if res['type'] == data_type]
        avg_metric = np.mean([res[metric] for res in type_results], axis=0)
        std_metric = np.std([res[metric] for res in type_results], axis=0)
        averages[data_type] = (avg_metric, std_metric)
    return averages

# Compute averages and standard deviations for each metric
avg_accuracies = average_results(all_results, 'acc')
avg_scores = average_results(all_results, 'score')
avg_top31_beams = average_results(all_results, 'top31_beam')
avg_top33_beams = average_results(all_results, 'top33_beam')
avg_PF1_means = average_results(all_results, 'PF1_mean')
avg_PF2_means = average_results(all_results, 'PF2_mean')
avg_PF3_means = average_results(all_results, 'PF3_mean')
avg_recalls = average_results(all_results, 'recall')
avg_precisions = average_results(all_results, 'precision')

# Print the average results across all seeds
print("\nAverage Results Across All Seeds:")
for data_type in avg_accuracies:
    print(f"Type: {data_type} - Avg Accuracies: {avg_accuracies[data_type][0]} ± {avg_accuracies[data_type][1]}, "
          f"Avg Score: {avg_scores[data_type][0]} ± {avg_scores[data_type][1]}, "
          f"top31_beam: {avg_top31_beams[data_type][0]} ± {avg_top31_beams[data_type][1]}, "
          f"top33_beam: {avg_top33_beams[data_type][0]} ± {avg_top33_beams[data_type][1]}, "
          f"PF1_mean: {avg_PF1_means[data_type][0]} ± {avg_PF1_means[data_type][1]}, "
          f"PF2_mean: {avg_PF2_means[data_type][0]} ± {avg_PF2_means[data_type][1]}, "
          f"PF3_mean: {avg_PF3_means[data_type][0]} ± {avg_PF3_means[data_type][1]}, "
          f"Recall: {avg_recalls[data_type][0]} ± {avg_recalls[data_type][1]}, "
          f"Precision: {avg_precisions[data_type][0]} ± {avg_precisions[data_type][1]}")

gc.collect()
# Out:
# Evaluating model with seed 42
# 2024-08-24 23:41:29.972019: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2024-08-24 23:41:29.972050: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: edison
# 2024-08-24 23:41:29.972054: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: edison
# 2024-08-24 23:41:29.972198: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 560.35.3
# 2024-08-24 23:41:29.972217: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: NOT_FOUND: could not find kernel module information in driver version file contents: "NVRM version: NVIDIA UNIX Open Kernel Module for x86_64  560.35.03  Release Build  (dvs-builder@U16-I1-N07-12-3)  Fri Aug 16 21:42:42 UTC 2024
# GCC version:  gcc version 11.4.0 (Ubuntu 11.4.0-1ubuntu1~22.04)
# "
# 2024-08-24 23:41:29.972490: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 314/314 [==============================] - 6s 17ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 34/34 [==============================] - 1s 17ms/step
# 2/2 [==============================] - 0s 27ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Evaluating model with seed 123
# 314/314 [==============================] - 6s 18ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 34/34 [==============================] - 1s 17ms/step
# 2/2 [==============================] - 0s 14ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Evaluating model with seed 456
# 314/314 [==============================] - 6s 17ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 34/34 [==============================] - 1s 17ms/step
# 2/2 [==============================] - 0s 23ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Evaluating model with seed 789
# 314/314 [==============================] - 6s 17ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 34/34 [==============================] - 1s 19ms/step
# 2/2 [==============================] - 0s 28ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Evaluating model with seed 101112
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 314/314 [==============================] - 6s 17ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 34/34 [==============================] - 1s 17ms/step
# 2/2 [==============================] - 0s 14ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Average Results Across All Seeds:
# Type: Train - Avg Accuracies: [0.5925  0.89278 0.95368] ± [0.02171295 0.01049636 0.00592871], Avg Score: 0.914 ± 0.01019803902718558, top31_beam: 0.8539999999999999 ± 0.010198039027185577, top33_beam: 0.9659999999999999 ± 0.004898979485566361, PF1_mean: 0.978 ± 0.0040000000000000036, PF2_mean: 0.99 ± 0.0, PF3_mean: 0.99 ± 0.0, Recall: 0.594 ± 0.023323807579381222, Precision: 0.5839999999999999 ± 0.026532998322843195
# Type: Test_LoS - Avg Accuracies: [0.38452 0.75148 0.87782] ± [0.01050912 0.01572125 0.01218957], Avg Score: 0.836 ± 0.01019803902718558, top31_beam: 0.752 ± 0.011661903789690611, top33_beam: 0.9179999999999999 ± 0.00748331477354789, PF1_mean: 0.952 ± 0.0040000000000000036, PF2_mean: 0.9719999999999999 ± 0.004000000000000004, PF3_mean: 0.982 ± 0.0040000000000000036, Recall: 0.384 ± 0.01019803902718558, Precision: 0.338 ± 0.009797958971132706
# Type: Test_NLoS - Avg Accuracies: [0.05884 0.09798 0.16626] ± [0.03022784 0.05630202 0.0605683 ], Avg Score: 0.162 ± 0.051536394906900505, top31_beam: 0.248 ± 0.05706137047074842, top33_beam: 0.404 ± 0.09436100889668358, PF1_mean: 0.8939999999999999 ± 0.008000000000000007, PF2_mean: 0.9119999999999999 ± 0.00979795897113272, PF3_mean: 0.924 ± 0.010198039027185543, Recall: 0.05800000000000001 ± 0.03249615361854384, Precision: 0.082 ± 0.0515363949069005
# 10735

# %%
# Define a function to format mean ± std
def format_mean_std(mean, std):
    return f"{mean:.2f} ± {std:.2f}"

# Initialize the final results list
formatted_results = []

# Process the results for saving
for data_type in avg_accuracies:
    acc_means, acc_stds = avg_accuracies[data_type]
    row = {
        'Type': data_type,
        'Acc': ', '.join([format_mean_std(m, s) for m, s in zip(acc_means, acc_stds)]),
        'Score': format_mean_std(*avg_scores[data_type]),
        'top31_beam': format_mean_std(*avg_top31_beams[data_type]),
        'top33_beam': format_mean_std(*avg_top33_beams[data_type]),
        'PF1_mean': format_mean_std(*avg_PF1_means[data_type]),
        'PF2_mean': format_mean_std(*avg_PF2_means[data_type]),
        'PF3_mean': format_mean_std(*avg_PF3_means[data_type]),
        'Recall': format_mean_std(*avg_recalls[data_type]),
        'Precision': format_mean_std(*avg_precisions[data_type])
    }
    formatted_results.append(row)

# Convert the list to a DataFrame
df = pd.DataFrame(formatted_results)

# Save to CSV
df.to_csv(f'results_{model_name}_AllScens.csv', index=False)

print("Results saved to CSV:")
print(df)
# Out:
# Results saved to CSV:
#         Type                                    Acc        Score   top31_beam  \
# 0      Train  0.59 ± 0.02, 0.89 ± 0.01, 0.95 ± 0.01  0.91 ± 0.01  0.85 ± 0.01
# 1   Test_LoS  0.38 ± 0.01, 0.75 ± 0.02, 0.88 ± 0.01  0.84 ± 0.01  0.75 ± 0.01
# 2  Test_NLoS  0.06 ± 0.03, 0.10 ± 0.06, 0.17 ± 0.06  0.16 ± 0.05  0.25 ± 0.06
#
#     top33_beam     PF1_mean     PF2_mean     PF3_mean       Recall  \
# 0  0.97 ± 0.00  0.98 ± 0.00  0.99 ± 0.00  0.99 ± 0.00  0.59 ± 0.02
# 1  0.92 ± 0.01  0.95 ± 0.00  0.97 ± 0.00  0.98 ± 0.00  0.38 ± 0.01
# 2  0.40 ± 0.09  0.89 ± 0.01  0.91 ± 0.01  0.92 ± 0.01  0.06 ± 0.03
#
#      Precision
# 0  0.58 ± 0.03
# 1  0.34 ± 0.01
# 2  0.08 ± 0.05
