# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Apr 19 13:55:28 2023

@author: Saba
"""

'''
To change at each run with different models:
    the name of the file in commands: 
        result.to_csv
    the name of ckpt in:
        callbacks      
        
This is Lidar_Transformed plus Vision data to be trained with CNN to make a multimodal network.
Image (Vision) is transformed from RGB to gray.
'''
import gc
import os
import numpy as np
import pandas as pd
from keras.layers import Conv1D, Conv2D, BatchNormalization, MaxPool1D, MaxPool2D, GlobalMaxPool1D, GlobalMaxPool2D
from keras.layers import TimeDistributed, GRU, Dense, Dropout
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow import keras
from sklearn.metrics import precision_score, recall_score
from keras.models import load_model

np.random.seed(42)
tf.random.set_seed(42) 

#%% Main                
#Score function
def compute_acc(y_pred, y_true, top_k=[1,3,5]):
    """ Computes top-k accuracy given prediction and ground truth labels."""
    n_top_k = len(top_k)
    total_hits = np.zeros(n_top_k)
    
    n_test_samples = len(y_true)
    if len(y_pred) != n_test_samples:
        raise Exception('Number of predicted beams does not match number of labels.')
    
    # For each test sample, count times where true beam is in k top guesses
    for samp_idx in range(len(y_true)):
        for k_idx in range(n_top_k):
            hit = np.any(y_pred[samp_idx,:top_k[k_idx]] == y_true[samp_idx, -1])
            total_hits[k_idx] += 1 if hit else 0
    
    # Average the number of correct guesses (over the total samples)
    return np.round(total_hits / len(y_true), 4)

def save_pred_to_csv(sample_index, y_pred, top_k=[1,2,3], target_csv='beam_pred.csv'):
    """ 
    Saves the predicted beam results to a csv file. 
    Expects y_pred: n_samples x N_BEAMS, and saves the top_k columns only. 
    """
    
    cols = [f'top-{i} beam' for i in top_k]
    df = pd.DataFrame(data=y_pred[:, np.array(top_k)-1], columns=cols)
    df.index.name = 'index'
    df['sample_index'] = sample_index
    df.to_csv(target_csv)

def compute_DBA_score(y_pred, y_true, max_k=3, delta=5):
    """ 
    The top-k MBD (Minimum Beam Distance) as the minimum distance
    of any beam in the top-k set of predicted beams to the ground truth beam. 
    
    Then we take the average across all samples.
    
    Then we average that number over all the considered Ks.
    """
    n_samples = y_pred.shape[0]
    #n_beams = y_pred.shape[-1] 
    
    yk = np.zeros(max_k)
    for k in range(max_k):
        acc_avg_min_beam_dist = 0
        idxs_up_to_k = np.arange(k+1)
        for i in range(n_samples):
            aux1 = np.abs(y_pred[i, idxs_up_to_k] - y_true[i]) / delta
            # Compute min between beam diff and 1
            aux2 = np.min(np.stack((aux1, np.zeros_like(aux1)+1), axis=0), axis=0)
            acc_avg_min_beam_dist += np.min(aux2)
            
        yk[k] = 1 - acc_avg_min_beam_dist / n_samples
    
    return np.mean(yk)

#%% Power factor
def compute_powerfactor(y_pred, pwrs_array, k=3):
    '''
    Calculate the maximum power factor for top-1 to top-k predictions.
    
    Args:
    y_pred (numpy array): Sorted predictions (n_samples, 64), indices of beams sorted by probability.
    pwrs_array (numpy array): Power values for beams (n_samples, 64).
    k (int): The top-k predictions to consider.
    
    Returns:
    numpy array: Array of average max PFs from top-1 to top-k.
    '''
    max_Pr = np.max(pwrs_array, axis=1)  # Maximum power across all beams for each sample
    PF_max_k = np.zeros(k)  # Array to store the average of maximum PFs for each top-k
    #PF_max_k_stds = np.zeros(k)  # Array to store the standard deviation of maximum PFs for each top-k
    
    for i in range(1, k+1):
        max_PF = np.zeros(pwrs_array.shape[0])  # Array to hold the max PF for each sample for current top-i
        for j in range(pwrs_array.shape[0]):  # Iterate over each sample
            # Calculate PFs for the top-i predictions and find the maximum
            top_k_PFs = pwrs_array[j, y_pred[j, :i]] / max_Pr[j]
            max_PF[j] = np.max(top_k_PFs)  # Maximum PF for this sample among top-i
        PF_max_k[i-1] = np.round(np.mean(max_PF), 2)  # Average of maximum PFs across all samples for top-i
        #PF_max_k_stds[i-1] = np.round(np.std(max_PF), 2)  # Standard deviation of maximum PFs for top-i

    return PF_max_k #, PF_max_k_stds

def calculate_top_beams(predictions, truths):
    correct_top1_count = 0
    correct_top3_count = 0
    total_count = len(predictions)  # Assuming predictions and truths are lists of numpy arrays
    
    for pred, true in zip(predictions, truths):
        # Find the index of the highest value in the predicted array
        top_pred_index = np.argmax(pred)
        
        # Find the indices of the top 3 highest values in the true array
        top_true_indices = np.argsort(true)[-3:]
        
        # Check if the top predicted index is among the top 3 true indices for top-1 accuracy
        if top_pred_index in top_true_indices:
            correct_top1_count += 1
        
        # Find the indices of the top 3 highest values in the predicted array
        top_pred_indices = np.argsort(pred)[-3:]
        
        # Check if there is any intersection between the top 3 predicted indices and the top 3 true indices for top-3 accuracy
        if set(top_pred_indices) & set(top_true_indices):
            correct_top3_count += 1
    
    # Calculate the percentage of correct predictions for top-1 and top-3 accuracies
    top1_accuracy = (correct_top1_count / total_count)
    top3_accuracy = (correct_top3_count / total_count) 
    top1_accuracy  = round(top1_accuracy, 2)
    top3_accuracy  = round(top3_accuracy, 2)
    return [top1_accuracy,top3_accuracy]
# Out:
# 2024-08-20 23:13:49.420401: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-20 23:13:49.584575: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-20 23:13:50.411368: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/sa457043/miniconda3/envs/tf_jupyter/lib/:/home/sa457043/lib/python3.10/site-packages/nvidia/cudnn/lib:
# 2024-08-20 23:13:50.411472: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/sa457043/miniconda3/envs/tf_jupyter/lib/:/home/sa457043/lib/python3.10/site-packages/nvidia/cudnn/lib:
# 2024-08-20 23:13:50.411480: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
'''
#%% GPU optimization
#
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
        
#
os.environ["TF_GPU_ALLOCATOR"]="cuda_malloc_async" #to allow automatic assignment of operations to different GPUs to prevent OOM issue
'''   

# Set environment variables to disable GPU usage and use CPU instead
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'  # This line disables GPU

# %%
#%% some global params
model_name = "V_remake_v1_multipleRuns"

# %%
#%%Load data
def add_noise(data, noise_level):
    noisy_data = data + np.random.normal(scale=noise_level, size=data.shape)
    return noisy_data

'''
def add_gps_noise(GPS, noise_level):
    GPS_noisy = np.zeros(GPS.shape)
    GPS_noisy[:,:,0] = GPS[:,:,0] + np.random.normal(scale=noise_level, size=GPS[:,:,0].shape)
    GPS_noisy[:,:,1] = GPS[:,:,1] + np.random.normal(scale=noise_level, size=GPS[:,:,1].shape)
    return GPS_noisy
'''

df_train =  pd.read_csv('./ml_challenge_dev_multi_modal_v2.csv')
index = df_train['unit1_beam'].values

imagex = 150
imagey = 150

import cv2
def rescale(data): #to rescale from 11143x5x210x360 to 11143,5,210,225
    resized_data= np.zeros((data.shape[0],5,imagex,imagey))
    for i in range(data.shape[0]):
        for j in range(data.shape[1]):
            resized_data[i, j] = cv2.resize(data[i, j], (imagey, imagex), interpolation=cv2.INTER_NEAREST)
    return resized_data
    
data = np.load('vision_gray_11143x5x210x360.npz')
vision = rescale(data['vision'])
vision = add_noise(vision, 0.001)
print(np.min(vision), np.max(vision))
vision = vision / 255.0
print(np.min(vision), np.max(vision))
gc.collect()

classes = to_categorical(df_train['unit1_beam'].values - 1, num_classes = 64, dtype ="int32")
# Out:
# -0.004326230904609564 255.00513514743432
# -1.696561139062574e-05 1.0000201378330758

# %%
#%%Model
def build_convnet(shape=(imagex,imagey)):
    momentum = .9

    model = keras.Sequential()
    model.add(Conv1D(4, 7, input_shape=shape,padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    model.add(Conv1D(4, (7), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    model.add(MaxPool1D(pool_size=2))
    model.add(MaxPool1D(pool_size=2))

    model.add(Conv1D(16, 3, input_shape=shape,padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    model.add(Conv1D(16, (3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    model.add(MaxPool1D(pool_size=2))
    
    model.add(Conv1D(16, 3, padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    model.add(Conv1D(16, (3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    model.add(MaxPool1D(pool_size=3))

    #model.add(Conv1D(128, 3, padding='same', activation='relu'))
    #model.add(BatchNormalization(momentum=momentum))
    model.add(Conv1D(128, (3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    model.add(MaxPool1D(pool_size=3))
    
    #model.add(Conv1D(256, 3, padding='same', activation='relu'))
    #model.add(BatchNormalization(momentum=momentum))
    model.add(Conv1D(256, (3), padding='same', activation='relu'))
    model.add(BatchNormalization(momentum=momentum))
    
    model.add(GlobalMaxPool1D())
    return model

def GRU_model(input_shape=(5,imagex,imagey), nbout=64): 
    # Create our convnet with (112, 112, 3) input shape
    convnet = build_convnet(input_shape[1:]) #all elements after shape[0] (not shape[0])
    
    # then create our final model
    model = keras.Sequential()
    # add the convnet with (5, 128,125,4) shape
    model.add(TimeDistributed(convnet, input_shape=input_shape))
    # here, you can also use GRU or LSTM
    model.add(GRU(64))
    # and finally, we make a decision network
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(.5))
    #model.add(Dense(64, activation='relu'))
    model.add(Dense(nbout, activation='softmax'))
    return model

# %%
seeds = [42, 123, 456, 789, 101112]

results = []

for seed in seeds:
    print(f"\nRunning model with seed {seed}")

    # Train-Test Split with the current seed
    X_train, X_test, y_train, y_test, train_indices, test_indices = train_test_split(
        vision, classes, np.arange(len(vision)), test_size=0.1, stratify=classes, random_state=seed)

    #%% Scenarios and LoS NLoS analysis of train and test samples
    df_train = pd.read_csv('./ml_challenge_dev_multi_modal_v3_all_scenarios_with_LoS_status.csv')

    # Find LoS and NLoS samples in the train and test indices
    train_los_indices = df_train[df_train['LoS_status'] == 'LoS'].index.intersection(train_indices)
    train_nlos_indices = df_train[df_train['LoS_status'] == 'NLoS'].index.intersection(train_indices)
    test_los_indices = df_train[df_train['LoS_status'] == 'LoS'].index.intersection(test_indices)
    test_nlos_indices = df_train[df_train['LoS_status'] == 'NLoS'].index.intersection(test_indices)

    # Verify that all train and test samples are classified
    assert len(train_los_indices) + len(train_nlos_indices) == len(train_indices), "Mismatch in total train samples"
    assert len(test_los_indices) + len(test_nlos_indices) == len(test_indices), "Mismatch in total test samples"

    # Identify scenarios
    scenario_path = df_train['unit2_loc_1']

    # Function to count LoS and NLoS samples for a scenario
    def count_scenario_samples(scenario_keyword, los_indices, nlos_indices):
        scenario_indices = df_train[scenario_path.str.contains(scenario_keyword)].index
        los_count = len(np.intersect1d(los_indices, scenario_indices))
        nlos_count = len(np.intersect1d(nlos_indices, scenario_indices))
        return los_count, nlos_count

    # Count LoS and NLoS samples for each scenario in train and test sets
    scenario_los_nlos_counts_train = {}
    scenario_los_nlos_counts_test = {}
    for scenario_keyword in ['scenario32', 'scenario33', 'scenario34']:
        los_count_train, nlos_count_train = count_scenario_samples(scenario_keyword, train_los_indices, train_nlos_indices)
        los_count_test, nlos_count_test = count_scenario_samples(scenario_keyword, test_los_indices, test_nlos_indices)
        scenario_los_nlos_counts_train[scenario_keyword] = {'LoS': los_count_train, 'NLoS': nlos_count_train}
        scenario_los_nlos_counts_test[scenario_keyword] = {'LoS': los_count_test, 'NLoS': nlos_count_test}

    # Print the counts for each scenario in train and test sets
    print("Train Data Scenario Counts:")
    for scenario, counts in scenario_los_nlos_counts_train.items():
        print(f"{scenario} - LoS samples count: {counts['LoS']}, NLoS samples count: {counts['NLoS']}")

    print("\nTest Data Scenario Counts:")
    for scenario, counts in scenario_los_nlos_counts_test.items():
        print(f"{scenario} - LoS samples count: {counts['LoS']}, NLoS samples count: {counts['NLoS']}")

    # Extract LoS and NLoS samples from the modalities and classes
    X_train_los = vision[train_los_indices]
    X_train_nlos = vision[train_nlos_indices]
    X_test_los = vision[test_los_indices]
    X_test_nlos = vision[test_nlos_indices]
    y_train_los = classes[train_los_indices]
    y_train_nlos = classes[train_nlos_indices]
    y_test_los = classes[test_los_indices]
    y_test_nlos = classes[test_nlos_indices]

    # Print shapes of train and test datasets for each modality
    print(f'LoS Train Shape: {X_train_los.shape}, LoS Test Shape: {X_test_los.shape}')
    print(f'NLoS Train Shape: {X_train_nlos.shape}, NLoS Test Shape: {X_test_nlos.shape}')

    # Print shapes of train and test labels
    print(f'Train Labels Shape: {y_train.shape}')
    print(f'Test Labels Shape: {y_test.shape}')
    print(f'Train LoS Labels Shape: {y_train_los.shape}')
    print(f'Train NLoS Labels Shape: {y_train_nlos.shape}')
    print(f'Test LoS Labels Shape: {y_test_los.shape}')
    print(f'Test NLoS Labels Shape: {y_test_nlos.shape}')

    gc.collect()

    # some global params
    NBFRAME = 5
    N_CLASSES = 64
    INSHAPE = (5,imagex,imagey)
    model = GRU_model(INSHAPE, N_CLASSES)
    optimizer = keras.optimizers.Adam(0.001) 
    model.compile(optimizer, 'categorical_crossentropy', metrics=['acc'])
    print(model.summary())

    #Run the training
    EPOCHS=300
    BS = 30

    callbacks = [
        keras.callbacks.EarlyStopping(monitor='val_loss', patience=12, mode='min', verbose=1),
        keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=8, mode='min', verbose=1),
        keras.callbacks.ModelCheckpoint(
            f'chkp/{model_name}_seed_{seed}.hdf5', 
            monitor='val_acc',  # Monitor validation accuracy
            save_best_only  = True,
            mode='max',  # Maximize the monitored quantity
            verbose=1),
    ]

    history = model.fit(
        x=X_train,
        y=y_train,
        validation_split = 0.2, #0
        #validation_data=(X_val, y_val),
        verbose=1,
        #verbose='auto', #auto
        epochs=EPOCHS,
        batch_size =BS,
        callbacks=callbacks
    )

    gc.collect()
# Out:
# Running model with seed 42
# Train Data Scenario Counts:
# scenario32 - LoS samples count: 2683, NLoS samples count: 110
# scenario33 - LoS samples count: 3329, NLoS samples count: 120
# scenario34 - LoS samples count: 3691, NLoS samples count: 95
#
# Test Data Scenario Counts:
# scenario32 - LoS samples count: 311, NLoS samples count: 11
# scenario33 - LoS samples count: 372, NLoS samples count: 16
# scenario34 - LoS samples count: 391, NLoS samples count: 14
# LoS Train Shape: (9703, 5, 150, 150), LoS Test Shape: (1074, 5, 150, 150)
# NLoS Train Shape: (325, 5, 150, 150), NLoS Test Shape: (41, 5, 150, 150)
# Train Labels Shape: (10028, 64)
# Test Labels Shape: (1115, 64)
# Train LoS Labels Shape: (9703, 64)
# Train NLoS Labels Shape: (325, 64)
# Test LoS Labels Shape: (1074, 64)
# Test NLoS Labels Shape: (41, 64)
# 2024-08-20 23:19:22.553853: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2024-08-20 23:19:22.553879: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: edison
# 2024-08-20 23:19:22.553883: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: edison
# 2024-08-20 23:19:22.554019: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 560.28.3
# 2024-08-20 23:19:22.554042: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: NOT_FOUND: could not find kernel module information in driver version file contents: "NVRM version: NVIDIA UNIX Open Kernel Module for x86_64  560.28.03  Release Build  (dvs-builder@U16-A24-27-4)  Thu Jul 18 20:46:24 UTC 2024
# GCC version:  gcc version 11.4.0 (Ubuntu 11.4.0-1ubuntu1~22.04)
# "
# 2024-08-20 23:19:22.554286: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 5, 256)           113536
#  ibuted)
#
#  gru (GRU)                   (None, 64)                61824
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
# =================================================================
# Total params: 183,680
# Trainable params: 182,768
# Non-trainable params: 912
# _________________________________________________________________
# None
# Epoch 1/300
# 268/268 [==============================] - ETA: 0s - loss: 3.8228 - acc: 0.1017
# Epoch 1: val_acc improved from -inf to 0.13559, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 27s 86ms/step - loss: 3.8228 - acc: 0.1017 - val_loss: 3.5339 - val_acc: 0.1356 - lr: 0.0010
# Epoch 2/300
# 268/268 [==============================] - ETA: 0s - loss: 3.5261 - acc: 0.1295
# Epoch 2: val_acc improved from 0.13559 to 0.14806, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 3.5261 - acc: 0.1295 - val_loss: 3.3153 - val_acc: 0.1481 - lr: 0.0010
# Epoch 3/300
# 268/268 [==============================] - ETA: 0s - loss: 3.3265 - acc: 0.1495
# Epoch 3: val_acc improved from 0.14806 to 0.17896, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 3.3265 - acc: 0.1495 - val_loss: 3.1195 - val_acc: 0.1790 - lr: 0.0010
# Epoch 4/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.1300 - acc: 0.1752
# Epoch 4: val_acc improved from 0.17896 to 0.20289, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 3.1299 - acc: 0.1751 - val_loss: 2.9588 - val_acc: 0.2029 - lr: 0.0010
# Epoch 5/300
# 268/268 [==============================] - ETA: 0s - loss: 2.9710 - acc: 0.1925
# Epoch 5: val_acc improved from 0.20289 to 0.21585, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 2.9710 - acc: 0.1925 - val_loss: 2.8145 - val_acc: 0.2159 - lr: 0.0010
# Epoch 6/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.8376 - acc: 0.2140
# Epoch 6: val_acc improved from 0.21585 to 0.24526, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 2.8377 - acc: 0.2139 - val_loss: 2.6672 - val_acc: 0.2453 - lr: 0.0010
# Epoch 7/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.7065 - acc: 0.2350
# Epoch 7: val_acc improved from 0.24526 to 0.24726, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 2.7067 - acc: 0.2349 - val_loss: 2.5759 - val_acc: 0.2473 - lr: 0.0010
# Epoch 8/300
# 268/268 [==============================] - ETA: 0s - loss: 2.6066 - acc: 0.2441
# Epoch 8: val_acc improved from 0.24726 to 0.25573, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 2.6066 - acc: 0.2441 - val_loss: 2.5281 - val_acc: 0.2557 - lr: 0.0010
# Epoch 9/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.4937 - acc: 0.2680
# Epoch 9: val_acc improved from 0.25573 to 0.29511, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 2.4933 - acc: 0.2681 - val_loss: 2.3919 - val_acc: 0.2951 - lr: 0.0010
# Epoch 10/300
# 268/268 [==============================] - ETA: 0s - loss: 2.4493 - acc: 0.2741
# Epoch 10: val_acc improved from 0.29511 to 0.30608, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 2.4493 - acc: 0.2741 - val_loss: 2.3074 - val_acc: 0.3061 - lr: 0.0010
# Epoch 11/300
# 268/268 [==============================] - ETA: 0s - loss: 2.3404 - acc: 0.2845
# Epoch 11: val_acc did not improve from 0.30608
# 268/268 [==============================] - 20s 75ms/step - loss: 2.3404 - acc: 0.2845 - val_loss: 2.2748 - val_acc: 0.2911 - lr: 0.0010
# Epoch 12/300
# 268/268 [==============================] - ETA: 0s - loss: 2.2829 - acc: 0.3003
# Epoch 12: val_acc improved from 0.30608 to 0.31356, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 2.2829 - acc: 0.3003 - val_loss: 2.2360 - val_acc: 0.3136 - lr: 0.0010
# Epoch 13/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.2182 - acc: 0.3172
# Epoch 13: val_acc did not improve from 0.31356
# 268/268 [==============================] - 20s 75ms/step - loss: 2.2201 - acc: 0.3169 - val_loss: 2.3068 - val_acc: 0.2807 - lr: 0.0010
# Epoch 14/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1723 - acc: 0.3212
# Epoch 14: val_acc improved from 0.31356 to 0.33500, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 2.1720 - acc: 0.3211 - val_loss: 2.1104 - val_acc: 0.3350 - lr: 0.0010
# Epoch 15/300
# 268/268 [==============================] - ETA: 0s - loss: 2.1272 - acc: 0.3367
# Epoch 15: val_acc did not improve from 0.33500
# 268/268 [==============================] - 20s 76ms/step - loss: 2.1272 - acc: 0.3367 - val_loss: 2.0896 - val_acc: 0.3220 - lr: 0.0010
# Epoch 16/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0975 - acc: 0.3432
# Epoch 16: val_acc did not improve from 0.33500
# 268/268 [==============================] - 20s 76ms/step - loss: 2.0973 - acc: 0.3432 - val_loss: 2.0902 - val_acc: 0.3335 - lr: 0.0010
# Epoch 17/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0759 - acc: 0.3478
# Epoch 17: val_acc improved from 0.33500 to 0.34596, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 2.0758 - acc: 0.3475 - val_loss: 2.0540 - val_acc: 0.3460 - lr: 0.0010
# Epoch 18/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9941 - acc: 0.3630
# Epoch 18: val_acc improved from 0.34596 to 0.34895, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 1.9938 - acc: 0.3631 - val_loss: 1.9914 - val_acc: 0.3490 - lr: 0.0010
# Epoch 19/300
# 268/268 [==============================] - ETA: 0s - loss: 1.9733 - acc: 0.3626
# Epoch 19: val_acc did not improve from 0.34895
# 268/268 [==============================] - 20s 75ms/step - loss: 1.9733 - acc: 0.3626 - val_loss: 1.9693 - val_acc: 0.3490 - lr: 0.0010
# Epoch 20/300
# 268/268 [==============================] - ETA: 0s - loss: 1.9536 - acc: 0.3681
# Epoch 20: val_acc improved from 0.34895 to 0.35394, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 1.9536 - acc: 0.3681 - val_loss: 1.9694 - val_acc: 0.3539 - lr: 0.0010
# Epoch 21/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9280 - acc: 0.3743
# Epoch 21: val_acc improved from 0.35394 to 0.37238, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 20s 75ms/step - loss: 1.9283 - acc: 0.3741 - val_loss: 1.9596 - val_acc: 0.3724 - lr: 0.0010
# Epoch 22/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8838 - acc: 0.3821
# Epoch 22: val_acc did not improve from 0.37238
# 268/268 [==============================] - 20s 76ms/step - loss: 1.8841 - acc: 0.3821 - val_loss: 2.0196 - val_acc: 0.3549 - lr: 0.0010
# Epoch 23/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8569 - acc: 0.3871
# Epoch 23: val_acc did not improve from 0.37238
# 268/268 [==============================] - 20s 75ms/step - loss: 1.8580 - acc: 0.3869 - val_loss: 1.8975 - val_acc: 0.3684 - lr: 0.0010
# Epoch 24/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8691 - acc: 0.3908
# Epoch 24: val_acc improved from 0.37238 to 0.37587, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 1.8703 - acc: 0.3904 - val_loss: 1.9264 - val_acc: 0.3759 - lr: 0.0010
# Epoch 25/300
# 268/268 [==============================] - ETA: 0s - loss: 1.8277 - acc: 0.3899
# Epoch 25: val_acc improved from 0.37587 to 0.39382, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 1.8277 - acc: 0.3899 - val_loss: 1.8863 - val_acc: 0.3938 - lr: 0.0010
# Epoch 26/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7939 - acc: 0.4040
# Epoch 26: val_acc did not improve from 0.39382
# 268/268 [==============================] - 20s 76ms/step - loss: 1.7935 - acc: 0.4039 - val_loss: 1.9753 - val_acc: 0.3634 - lr: 0.0010
# Epoch 27/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7966 - acc: 0.4027
# Epoch 27: val_acc did not improve from 0.39382
# 268/268 [==============================] - 20s 76ms/step - loss: 1.7969 - acc: 0.4030 - val_loss: 1.8768 - val_acc: 0.3858 - lr: 0.0010
# Epoch 28/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7920 - acc: 0.4001
# Epoch 28: val_acc did not improve from 0.39382
# 268/268 [==============================] - 20s 75ms/step - loss: 1.7923 - acc: 0.4000 - val_loss: 1.8594 - val_acc: 0.3873 - lr: 0.0010
# Epoch 29/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7482 - acc: 0.4067
# Epoch 29: val_acc did not improve from 0.39382
# 268/268 [==============================] - 20s 75ms/step - loss: 1.7479 - acc: 0.4070 - val_loss: 1.8562 - val_acc: 0.3868 - lr: 0.0010
# Epoch 30/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7287 - acc: 0.4146
# Epoch 30: val_acc did not improve from 0.39382
# 268/268 [==============================] - 20s 76ms/step - loss: 1.7289 - acc: 0.4147 - val_loss: 1.8571 - val_acc: 0.3863 - lr: 0.0010
# Epoch 31/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7348 - acc: 0.4201
# Epoch 31: val_acc improved from 0.39382 to 0.40379, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 1.7346 - acc: 0.4200 - val_loss: 1.8093 - val_acc: 0.4038 - lr: 0.0010
# Epoch 32/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6870 - acc: 0.4232
# Epoch 32: val_acc did not improve from 0.40379
# 268/268 [==============================] - 20s 76ms/step - loss: 1.6868 - acc: 0.4231 - val_loss: 1.8455 - val_acc: 0.3923 - lr: 0.0010
# Epoch 33/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6973 - acc: 0.4261
# Epoch 33: val_acc did not improve from 0.40379
# 268/268 [==============================] - 20s 76ms/step - loss: 1.6991 - acc: 0.4257 - val_loss: 1.8160 - val_acc: 0.4033 - lr: 0.0010
# Epoch 34/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6615 - acc: 0.4300
# Epoch 34: val_acc did not improve from 0.40379
# 268/268 [==============================] - 20s 75ms/step - loss: 1.6620 - acc: 0.4299 - val_loss: 1.9663 - val_acc: 0.3689 - lr: 0.0010
# Epoch 35/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6607 - acc: 0.4296
# Epoch 35: val_acc did not improve from 0.40379
# 268/268 [==============================] - 20s 76ms/step - loss: 1.6598 - acc: 0.4298 - val_loss: 1.8148 - val_acc: 0.3968 - lr: 0.0010
# Epoch 36/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6355 - acc: 0.4376
# Epoch 36: val_acc did not improve from 0.40379
# 268/268 [==============================] - 20s 76ms/step - loss: 1.6358 - acc: 0.4374 - val_loss: 1.9099 - val_acc: 0.4018 - lr: 0.0010
# Epoch 37/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6316 - acc: 0.4443
# Epoch 37: val_acc did not improve from 0.40379
# 268/268 [==============================] - 20s 75ms/step - loss: 1.6326 - acc: 0.4439 - val_loss: 1.9061 - val_acc: 0.3923 - lr: 0.0010
# Epoch 38/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6131 - acc: 0.4386
# Epoch 38: val_acc did not improve from 0.40379
# 268/268 [==============================] - 20s 76ms/step - loss: 1.6136 - acc: 0.4385 - val_loss: 1.8415 - val_acc: 0.4013 - lr: 0.0010
# Epoch 39/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6117 - acc: 0.4516
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 39: val_acc did not improve from 0.40379
# 268/268 [==============================] - 20s 75ms/step - loss: 1.6117 - acc: 0.4514 - val_loss: 1.8611 - val_acc: 0.3963 - lr: 0.0010
# Epoch 40/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.5114 - acc: 0.4690
# Epoch 40: val_acc improved from 0.40379 to 0.40778, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 1.5119 - acc: 0.4690 - val_loss: 1.7785 - val_acc: 0.4078 - lr: 1.0000e-04
# Epoch 41/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.4539 - acc: 0.4749
# Epoch 41: val_acc improved from 0.40778 to 0.40877, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 1.4541 - acc: 0.4751 - val_loss: 1.7897 - val_acc: 0.4088 - lr: 1.0000e-04
# Epoch 42/300
# 268/268 [==============================] - ETA: 0s - loss: 1.4146 - acc: 0.4944
# Epoch 42: val_acc improved from 0.40877 to 0.42323, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 1.4146 - acc: 0.4944 - val_loss: 1.7659 - val_acc: 0.4232 - lr: 1.0000e-04
# Epoch 43/300
# 268/268 [==============================] - ETA: 0s - loss: 1.4041 - acc: 0.4973
# Epoch 43: val_acc did not improve from 0.42323
# 268/268 [==============================] - 20s 76ms/step - loss: 1.4041 - acc: 0.4973 - val_loss: 1.7737 - val_acc: 0.4222 - lr: 1.0000e-04
# Epoch 44/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3908 - acc: 0.4951
# Epoch 44: val_acc did not improve from 0.42323
# 268/268 [==============================] - 20s 75ms/step - loss: 1.3905 - acc: 0.4951 - val_loss: 1.7720 - val_acc: 0.4212 - lr: 1.0000e-04
# Epoch 45/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3777 - acc: 0.5112
# Epoch 45: val_acc did not improve from 0.42323
# 268/268 [==============================] - 20s 75ms/step - loss: 1.3780 - acc: 0.5111 - val_loss: 1.7883 - val_acc: 0.4172 - lr: 1.0000e-04
# Epoch 46/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3786 - acc: 0.5066
# Epoch 46: val_acc did not improve from 0.42323
# 268/268 [==============================] - 20s 75ms/step - loss: 1.3785 - acc: 0.5066 - val_loss: 1.7808 - val_acc: 0.4128 - lr: 1.0000e-04
# Epoch 47/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3597 - acc: 0.5170
# Epoch 47: val_acc did not improve from 0.42323
# 268/268 [==============================] - 20s 75ms/step - loss: 1.3604 - acc: 0.5173 - val_loss: 1.8096 - val_acc: 0.4167 - lr: 1.0000e-04
# Epoch 48/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3489 - acc: 0.5186
# Epoch 48: val_acc did not improve from 0.42323
# 268/268 [==============================] - 20s 75ms/step - loss: 1.3494 - acc: 0.5183 - val_loss: 1.7751 - val_acc: 0.4207 - lr: 1.0000e-04
# Epoch 49/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3370 - acc: 0.5172
# Epoch 49: val_acc did not improve from 0.42323
# 268/268 [==============================] - 20s 75ms/step - loss: 1.3372 - acc: 0.5173 - val_loss: 1.7794 - val_acc: 0.4232 - lr: 1.0000e-04
# Epoch 50/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3376 - acc: 0.5225
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 50: val_acc improved from 0.42323 to 0.42871, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 1.3380 - acc: 0.5223 - val_loss: 1.7782 - val_acc: 0.4287 - lr: 1.0000e-04
# Epoch 51/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3153 - acc: 0.5223
# Epoch 51: val_acc improved from 0.42871 to 0.43320, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 20s 75ms/step - loss: 1.3155 - acc: 0.5223 - val_loss: 1.7857 - val_acc: 0.4332 - lr: 1.0000e-05
# Epoch 52/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3167 - acc: 0.5150
# Epoch 52: val_acc did not improve from 0.43320
# 268/268 [==============================] - 20s 75ms/step - loss: 1.3173 - acc: 0.5150 - val_loss: 1.7770 - val_acc: 0.4257 - lr: 1.0000e-05
# Epoch 53/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3117 - acc: 0.5215
# Epoch 53: val_acc did not improve from 0.43320
# 268/268 [==============================] - 20s 75ms/step - loss: 1.3127 - acc: 0.5211 - val_loss: 1.7827 - val_acc: 0.4207 - lr: 1.0000e-05
# Epoch 54/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3146 - acc: 0.5271
# Epoch 54: val_acc did not improve from 0.43320
# 268/268 [==============================] - 20s 75ms/step - loss: 1.3140 - acc: 0.5272 - val_loss: 1.7649 - val_acc: 0.4257 - lr: 1.0000e-05
# Epoch 55/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3084 - acc: 0.5218
# Epoch 55: val_acc did not improve from 0.43320
# 268/268 [==============================] - 20s 75ms/step - loss: 1.3086 - acc: 0.5217 - val_loss: 1.7753 - val_acc: 0.4158 - lr: 1.0000e-05
# Epoch 56/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3162 - acc: 0.5231
# Epoch 56: val_acc did not improve from 0.43320
# 268/268 [==============================] - 20s 75ms/step - loss: 1.3163 - acc: 0.5232 - val_loss: 1.7687 - val_acc: 0.4118 - lr: 1.0000e-05
# Epoch 57/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3037 - acc: 0.5238
# Epoch 57: val_acc did not improve from 0.43320
# 268/268 [==============================] - 20s 75ms/step - loss: 1.3044 - acc: 0.5236 - val_loss: 1.7702 - val_acc: 0.4282 - lr: 1.0000e-05
# Epoch 58/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2961 - acc: 0.5370
# Epoch 58: val_acc did not improve from 0.43320
# 268/268 [==============================] - 20s 76ms/step - loss: 1.2974 - acc: 0.5364 - val_loss: 1.7927 - val_acc: 0.4222 - lr: 1.0000e-05
# Epoch 59/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3046 - acc: 0.5262
# Epoch 59: val_acc did not improve from 0.43320
# 268/268 [==============================] - 20s 75ms/step - loss: 1.3040 - acc: 0.5266 - val_loss: 1.7762 - val_acc: 0.4282 - lr: 1.0000e-05
# Epoch 60/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2992 - acc: 0.5292
# Epoch 60: val_acc did not improve from 0.43320
# 268/268 [==============================] - 20s 76ms/step - loss: 1.2999 - acc: 0.5290 - val_loss: 1.7793 - val_acc: 0.4267 - lr: 1.0000e-05
# Epoch 61/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2961 - acc: 0.5281
# Epoch 61: val_acc did not improve from 0.43320
# 268/268 [==============================] - 20s 75ms/step - loss: 1.2960 - acc: 0.5283 - val_loss: 1.7739 - val_acc: 0.4172 - lr: 1.0000e-05
# Epoch 62/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3003 - acc: 0.5276
# Epoch 62: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 62: val_acc did not improve from 0.43320
# 268/268 [==============================] - 20s 75ms/step - loss: 1.3015 - acc: 0.5271 - val_loss: 1.7648 - val_acc: 0.4257 - lr: 1.0000e-05
# Epoch 63/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3047 - acc: 0.5293
# Epoch 63: val_acc did not improve from 0.43320
# 268/268 [==============================] - 20s 75ms/step - loss: 1.3051 - acc: 0.5295 - val_loss: 1.7762 - val_acc: 0.4292 - lr: 1.0000e-06
# Epoch 64/300
# 268/268 [==============================] - ETA: 0s - loss: 1.3044 - acc: 0.5300
# Epoch 64: val_acc did not improve from 0.43320
# 268/268 [==============================] - 20s 75ms/step - loss: 1.3044 - acc: 0.5300 - val_loss: 1.7751 - val_acc: 0.4247 - lr: 1.0000e-06
# Epoch 65/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2819 - acc: 0.5401
# Epoch 65: val_acc did not improve from 0.43320
# 268/268 [==============================] - 20s 75ms/step - loss: 1.2815 - acc: 0.5400 - val_loss: 1.7928 - val_acc: 0.4267 - lr: 1.0000e-06
# Epoch 66/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3143 - acc: 0.5260
# Epoch 66: val_acc did not improve from 0.43320
# 268/268 [==============================] - 20s 75ms/step - loss: 1.3139 - acc: 0.5262 - val_loss: 1.7792 - val_acc: 0.4317 - lr: 1.0000e-06
# Epoch 67/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3061 - acc: 0.5243
# Epoch 67: val_acc did not improve from 0.43320
# 268/268 [==============================] - 20s 76ms/step - loss: 1.3058 - acc: 0.5241 - val_loss: 1.7643 - val_acc: 0.4227 - lr: 1.0000e-06
# Epoch 68/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2863 - acc: 0.5382
# Epoch 68: val_acc improved from 0.43320 to 0.43519, saving model to chkp/V_remake_v1_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 1.2869 - acc: 0.5381 - val_loss: 1.7805 - val_acc: 0.4352 - lr: 1.0000e-06
# Epoch 69/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3075 - acc: 0.5341
# Epoch 69: val_acc did not improve from 0.43519
# 268/268 [==============================] - 20s 76ms/step - loss: 1.3081 - acc: 0.5338 - val_loss: 1.7701 - val_acc: 0.4252 - lr: 1.0000e-06
# Epoch 70/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3011 - acc: 0.5300
# Epoch 70: val_acc did not improve from 0.43519
# 268/268 [==============================] - 20s 76ms/step - loss: 1.3021 - acc: 0.5298 - val_loss: 1.7840 - val_acc: 0.4242 - lr: 1.0000e-06
# Epoch 71/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3003 - acc: 0.5297
# Epoch 71: val_acc did not improve from 0.43519
# 268/268 [==============================] - 20s 75ms/step - loss: 1.3009 - acc: 0.5295 - val_loss: 1.7822 - val_acc: 0.4202 - lr: 1.0000e-06
# Epoch 72/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3008 - acc: 0.5322
# Epoch 72: val_acc did not improve from 0.43519
# 268/268 [==============================] - 20s 75ms/step - loss: 1.3010 - acc: 0.5323 - val_loss: 1.7727 - val_acc: 0.4307 - lr: 1.0000e-06
# Epoch 73/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2961 - acc: 0.5306
# Epoch 73: val_acc did not improve from 0.43519
# 268/268 [==============================] - 20s 75ms/step - loss: 1.2961 - acc: 0.5305 - val_loss: 1.7814 - val_acc: 0.4282 - lr: 1.0000e-06
# Epoch 74/300
# 268/268 [==============================] - ETA: 0s - loss: 1.3012 - acc: 0.5277
# Epoch 74: val_acc did not improve from 0.43519
# 268/268 [==============================] - 20s 76ms/step - loss: 1.3012 - acc: 0.5277 - val_loss: 1.7756 - val_acc: 0.4197 - lr: 1.0000e-06
# Epoch 75/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2920 - acc: 0.5343
# Epoch 75: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
#
# Epoch 75: val_acc did not improve from 0.43519
# 268/268 [==============================] - 20s 76ms/step - loss: 1.2925 - acc: 0.5342 - val_loss: 1.7644 - val_acc: 0.4212 - lr: 1.0000e-06
# Epoch 76/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2977 - acc: 0.5312
# Epoch 76: val_acc did not improve from 0.43519
# 268/268 [==============================] - 20s 75ms/step - loss: 1.2983 - acc: 0.5310 - val_loss: 1.7681 - val_acc: 0.4207 - lr: 1.0000e-07
# Epoch 77/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3033 - acc: 0.5252
# Epoch 77: val_acc did not improve from 0.43519
# 268/268 [==============================] - 20s 75ms/step - loss: 1.3036 - acc: 0.5251 - val_loss: 1.7732 - val_acc: 0.4267 - lr: 1.0000e-07
# Epoch 78/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3121 - acc: 0.5257
# Epoch 78: val_acc did not improve from 0.43519
# 268/268 [==============================] - 20s 75ms/step - loss: 1.3126 - acc: 0.5258 - val_loss: 1.7923 - val_acc: 0.4282 - lr: 1.0000e-07
# Epoch 79/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2937 - acc: 0.5355
# Epoch 79: val_acc did not improve from 0.43519
# 268/268 [==============================] - 20s 75ms/step - loss: 1.2939 - acc: 0.5353 - val_loss: 1.7798 - val_acc: 0.4297 - lr: 1.0000e-07
# Epoch 79: early stopping
#
# Running model with seed 123
# Train Data Scenario Counts:
# scenario32 - LoS samples count: 2729, NLoS samples count: 109
# scenario33 - LoS samples count: 3322, NLoS samples count: 119
# scenario34 - LoS samples count: 3652, NLoS samples count: 97
#
# Test Data Scenario Counts:
# scenario32 - LoS samples count: 265, NLoS samples count: 12
# scenario33 - LoS samples count: 379, NLoS samples count: 17
# scenario34 - LoS samples count: 430, NLoS samples count: 12
# LoS Train Shape: (9703, 5, 150, 150), LoS Test Shape: (1074, 5, 150, 150)
# NLoS Train Shape: (325, 5, 150, 150), NLoS Test Shape: (41, 5, 150, 150)
# Train Labels Shape: (10028, 64)
# Test Labels Shape: (1115, 64)
# Train LoS Labels Shape: (9703, 64)
# Train NLoS Labels Shape: (325, 64)
# Test LoS Labels Shape: (1074, 64)
# Test NLoS Labels Shape: (41, 64)
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_1 (TimeDis  (None, 5, 256)           113536
#  tributed)
#
#  gru_1 (GRU)                 (None, 64)                61824
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 64)                4160
#
# =================================================================
# Total params: 183,680
# Trainable params: 182,768
# Non-trainable params: 912
# _________________________________________________________________
# None
# Epoch 1/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.7795 - acc: 0.0984
# Epoch 1: val_acc improved from -inf to 0.13609, saving model to chkp/V_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 26s 83ms/step - loss: 3.7791 - acc: 0.0985 - val_loss: 3.5677 - val_acc: 0.1361 - lr: 0.0010
# Epoch 2/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.4937 - acc: 0.1333
# Epoch 2: val_acc improved from 0.13609 to 0.16600, saving model to chkp/V_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 3.4937 - acc: 0.1334 - val_loss: 3.3889 - val_acc: 0.1660 - lr: 0.0010
# Epoch 3/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.2903 - acc: 0.1644
# Epoch 3: val_acc improved from 0.16600 to 0.16899, saving model to chkp/V_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 3.2908 - acc: 0.1642 - val_loss: 3.2480 - val_acc: 0.1690 - lr: 0.0010
# Epoch 4/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.1047 - acc: 0.1833
# Epoch 4: val_acc improved from 0.16899 to 0.22034, saving model to chkp/V_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 3.1047 - acc: 0.1835 - val_loss: 2.9602 - val_acc: 0.2203 - lr: 0.0010
# Epoch 5/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.9378 - acc: 0.2084
# Epoch 5: val_acc did not improve from 0.22034
# 268/268 [==============================] - 20s 76ms/step - loss: 2.9380 - acc: 0.2082 - val_loss: 2.8477 - val_acc: 0.2119 - lr: 0.0010
# Epoch 6/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.8232 - acc: 0.2323
# Epoch 6: val_acc improved from 0.22034 to 0.24427, saving model to chkp/V_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 2.8231 - acc: 0.2324 - val_loss: 2.6803 - val_acc: 0.2443 - lr: 0.0010
# Epoch 7/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.6937 - acc: 0.2477
# Epoch 7: val_acc improved from 0.24427 to 0.25224, saving model to chkp/V_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 2.6925 - acc: 0.2482 - val_loss: 2.6188 - val_acc: 0.2522 - lr: 0.0010
# Epoch 8/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.5592 - acc: 0.2639
# Epoch 8: val_acc improved from 0.25224 to 0.26471, saving model to chkp/V_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 2.5597 - acc: 0.2641 - val_loss: 2.4775 - val_acc: 0.2647 - lr: 0.0010
# Epoch 9/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.4986 - acc: 0.2801
# Epoch 9: val_acc improved from 0.26471 to 0.28265, saving model to chkp/V_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 2.4989 - acc: 0.2801 - val_loss: 2.4437 - val_acc: 0.2827 - lr: 0.0010
# Epoch 10/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.3797 - acc: 0.3006
# Epoch 10: val_acc improved from 0.28265 to 0.30259, saving model to chkp/V_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 2.3800 - acc: 0.3004 - val_loss: 2.3003 - val_acc: 0.3026 - lr: 0.0010
# Epoch 11/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.3003 - acc: 0.3090
# Epoch 11: val_acc improved from 0.30259 to 0.31306, saving model to chkp/V_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 2.3021 - acc: 0.3088 - val_loss: 2.2733 - val_acc: 0.3131 - lr: 0.0010
# Epoch 12/300
# 268/268 [==============================] - ETA: 0s - loss: 2.2412 - acc: 0.3178
# Epoch 12: val_acc improved from 0.31306 to 0.32054, saving model to chkp/V_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 2.2412 - acc: 0.3178 - val_loss: 2.2203 - val_acc: 0.3205 - lr: 0.0010
# Epoch 13/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1844 - acc: 0.3312
# Epoch 13: val_acc improved from 0.32054 to 0.33799, saving model to chkp/V_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 2.1846 - acc: 0.3311 - val_loss: 2.1357 - val_acc: 0.3380 - lr: 0.0010
# Epoch 14/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1358 - acc: 0.3392
# Epoch 14: val_acc did not improve from 0.33799
# 268/268 [==============================] - 20s 76ms/step - loss: 2.1353 - acc: 0.3393 - val_loss: 2.1004 - val_acc: 0.3355 - lr: 0.0010
# Epoch 15/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0744 - acc: 0.3494
# Epoch 15: val_acc did not improve from 0.33799
# 268/268 [==============================] - 20s 76ms/step - loss: 2.0750 - acc: 0.3492 - val_loss: 2.0929 - val_acc: 0.3355 - lr: 0.0010
# Epoch 16/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0500 - acc: 0.3572
# Epoch 16: val_acc improved from 0.33799 to 0.36341, saving model to chkp/V_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 2.0500 - acc: 0.3571 - val_loss: 2.0130 - val_acc: 0.3634 - lr: 0.0010
# Epoch 17/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9967 - acc: 0.3702
# Epoch 17: val_acc did not improve from 0.36341
# 268/268 [==============================] - 20s 76ms/step - loss: 1.9972 - acc: 0.3700 - val_loss: 1.9950 - val_acc: 0.3609 - lr: 0.0010
# Epoch 18/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9768 - acc: 0.3697
# Epoch 18: val_acc did not improve from 0.36341
# 268/268 [==============================] - 20s 76ms/step - loss: 1.9766 - acc: 0.3700 - val_loss: 2.0398 - val_acc: 0.3500 - lr: 0.0010
# Epoch 19/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9220 - acc: 0.3690
# Epoch 19: val_acc improved from 0.36341 to 0.38385, saving model to chkp/V_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 1.9220 - acc: 0.3690 - val_loss: 1.9541 - val_acc: 0.3838 - lr: 0.0010
# Epoch 20/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8920 - acc: 0.3788
# Epoch 20: val_acc improved from 0.38385 to 0.39133, saving model to chkp/V_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 1.8923 - acc: 0.3790 - val_loss: 1.9321 - val_acc: 0.3913 - lr: 0.0010
# Epoch 21/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8295 - acc: 0.3908
# Epoch 21: val_acc did not improve from 0.39133
# 268/268 [==============================] - 20s 76ms/step - loss: 1.8294 - acc: 0.3906 - val_loss: 1.9999 - val_acc: 0.3779 - lr: 0.0010
# Epoch 22/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8694 - acc: 0.3875
# Epoch 22: val_acc did not improve from 0.39133
# 268/268 [==============================] - 20s 76ms/step - loss: 1.8695 - acc: 0.3874 - val_loss: 1.9227 - val_acc: 0.3739 - lr: 0.0010
# Epoch 23/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8225 - acc: 0.3946
# Epoch 23: val_acc did not improve from 0.39133
# 268/268 [==============================] - 20s 76ms/step - loss: 1.8219 - acc: 0.3947 - val_loss: 1.9253 - val_acc: 0.3774 - lr: 0.0010
# Epoch 24/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8007 - acc: 0.4060
# Epoch 24: val_acc did not improve from 0.39133
# 268/268 [==============================] - 20s 76ms/step - loss: 1.8028 - acc: 0.4058 - val_loss: 2.0367 - val_acc: 0.3704 - lr: 0.0010
# Epoch 25/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7967 - acc: 0.4069
# Epoch 25: val_acc did not improve from 0.39133
# 268/268 [==============================] - 20s 76ms/step - loss: 1.7964 - acc: 0.4073 - val_loss: 1.9484 - val_acc: 0.3779 - lr: 0.0010
# Epoch 26/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7598 - acc: 0.4104
# Epoch 26: val_acc did not improve from 0.39133
# 268/268 [==============================] - 20s 76ms/step - loss: 1.7603 - acc: 0.4102 - val_loss: 1.9152 - val_acc: 0.3848 - lr: 0.0010
# Epoch 27/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7297 - acc: 0.4137
# Epoch 27: val_acc improved from 0.39133 to 0.39731, saving model to chkp/V_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 1.7303 - acc: 0.4137 - val_loss: 1.8790 - val_acc: 0.3973 - lr: 0.0010
# Epoch 28/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7109 - acc: 0.4187
# Epoch 28: val_acc improved from 0.39731 to 0.41675, saving model to chkp/V_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 1.7117 - acc: 0.4183 - val_loss: 1.8378 - val_acc: 0.4167 - lr: 0.0010
# Epoch 29/300
# 268/268 [==============================] - ETA: 0s - loss: 1.6972 - acc: 0.4257
# Epoch 29: val_acc did not improve from 0.41675
# 268/268 [==============================] - 20s 76ms/step - loss: 1.6972 - acc: 0.4257 - val_loss: 1.8804 - val_acc: 0.4008 - lr: 0.0010
# Epoch 30/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6723 - acc: 0.4267
# Epoch 30: val_acc did not improve from 0.41675
# 268/268 [==============================] - 20s 76ms/step - loss: 1.6726 - acc: 0.4267 - val_loss: 1.9495 - val_acc: 0.3679 - lr: 0.0010
# Epoch 31/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6755 - acc: 0.4331
# Epoch 31: val_acc did not improve from 0.41675
# 268/268 [==============================] - 20s 76ms/step - loss: 1.6756 - acc: 0.4332 - val_loss: 1.9450 - val_acc: 0.3928 - lr: 0.0010
# Epoch 32/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6637 - acc: 0.4261
# Epoch 32: val_acc did not improve from 0.41675
# 268/268 [==============================] - 20s 76ms/step - loss: 1.6632 - acc: 0.4262 - val_loss: 1.8972 - val_acc: 0.4018 - lr: 0.0010
# Epoch 33/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6511 - acc: 0.4388
# Epoch 33: val_acc did not improve from 0.41675
# 268/268 [==============================] - 20s 76ms/step - loss: 1.6512 - acc: 0.4387 - val_loss: 1.8919 - val_acc: 0.4058 - lr: 0.0010
# Epoch 34/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6141 - acc: 0.4449
# Epoch 34: val_acc did not improve from 0.41675
# 268/268 [==============================] - 20s 76ms/step - loss: 1.6147 - acc: 0.4448 - val_loss: 1.8778 - val_acc: 0.4113 - lr: 0.0010
# Epoch 35/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6047 - acc: 0.4439
# Epoch 35: val_acc did not improve from 0.41675
# 268/268 [==============================] - 20s 76ms/step - loss: 1.6052 - acc: 0.4442 - val_loss: 1.9022 - val_acc: 0.3968 - lr: 0.0010
# Epoch 36/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.6252 - acc: 0.4342
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 36: val_acc did not improve from 0.41675
# 268/268 [==============================] - 20s 76ms/step - loss: 1.6250 - acc: 0.4341 - val_loss: 1.8676 - val_acc: 0.3983 - lr: 0.0010
# Epoch 37/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.4858 - acc: 0.4773
# Epoch 37: val_acc did not improve from 0.41675
# 268/268 [==============================] - 20s 76ms/step - loss: 1.4861 - acc: 0.4771 - val_loss: 1.8199 - val_acc: 0.4158 - lr: 1.0000e-04
# Epoch 38/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.4195 - acc: 0.4869
# Epoch 38: val_acc improved from 0.41675 to 0.42871, saving model to chkp/V_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 1.4191 - acc: 0.4873 - val_loss: 1.8081 - val_acc: 0.4287 - lr: 1.0000e-04
# Epoch 39/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3939 - acc: 0.5041
# Epoch 39: val_acc did not improve from 0.42871
# 268/268 [==============================] - 20s 76ms/step - loss: 1.3952 - acc: 0.5040 - val_loss: 1.8336 - val_acc: 0.4227 - lr: 1.0000e-04
# Epoch 40/300
# 268/268 [==============================] - ETA: 0s - loss: 1.3837 - acc: 0.5084
# Epoch 40: val_acc improved from 0.42871 to 0.43519, saving model to chkp/V_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 1.3837 - acc: 0.5084 - val_loss: 1.8113 - val_acc: 0.4352 - lr: 1.0000e-04
# Epoch 41/300
# 268/268 [==============================] - ETA: 0s - loss: 1.3556 - acc: 0.5121
# Epoch 41: val_acc improved from 0.43519 to 0.44118, saving model to chkp/V_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 1.3556 - acc: 0.5121 - val_loss: 1.8116 - val_acc: 0.4412 - lr: 1.0000e-04
# Epoch 42/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3559 - acc: 0.5106
# Epoch 42: val_acc did not improve from 0.44118
# 268/268 [==============================] - 20s 76ms/step - loss: 1.3550 - acc: 0.5111 - val_loss: 1.8069 - val_acc: 0.4352 - lr: 1.0000e-04
# Epoch 43/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3448 - acc: 0.5130
# Epoch 43: val_acc did not improve from 0.44118
# 268/268 [==============================] - 20s 76ms/step - loss: 1.3441 - acc: 0.5135 - val_loss: 1.8211 - val_acc: 0.4277 - lr: 1.0000e-04
# Epoch 44/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3179 - acc: 0.5162
# Epoch 44: val_acc did not improve from 0.44118
# 268/268 [==============================] - 20s 76ms/step - loss: 1.3182 - acc: 0.5163 - val_loss: 1.8220 - val_acc: 0.4377 - lr: 1.0000e-04
# Epoch 45/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3118 - acc: 0.5210
# Epoch 45: val_acc improved from 0.44118 to 0.44167, saving model to chkp/V_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 1.3126 - acc: 0.5207 - val_loss: 1.8272 - val_acc: 0.4417 - lr: 1.0000e-04
# Epoch 46/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2999 - acc: 0.5270
# Epoch 46: val_acc improved from 0.44167 to 0.44217, saving model to chkp/V_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 20s 76ms/step - loss: 1.2998 - acc: 0.5272 - val_loss: 1.8349 - val_acc: 0.4422 - lr: 1.0000e-04
# Epoch 47/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2887 - acc: 0.5240
# Epoch 47: val_acc did not improve from 0.44217
# 268/268 [==============================] - 20s 76ms/step - loss: 1.2890 - acc: 0.5239 - val_loss: 1.8579 - val_acc: 0.4287 - lr: 1.0000e-04
# Epoch 48/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2812 - acc: 0.5268
# Epoch 48: val_acc did not improve from 0.44217
# 268/268 [==============================] - 20s 76ms/step - loss: 1.2813 - acc: 0.5267 - val_loss: 1.8450 - val_acc: 0.4407 - lr: 1.0000e-04
# Epoch 49/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2788 - acc: 0.5330
# Epoch 49: val_acc did not improve from 0.44217
# 268/268 [==============================] - 20s 76ms/step - loss: 1.2786 - acc: 0.5332 - val_loss: 1.8454 - val_acc: 0.4387 - lr: 1.0000e-04
# Epoch 50/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2804 - acc: 0.5361
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 50: val_acc did not improve from 0.44217
# 268/268 [==============================] - 20s 76ms/step - loss: 1.2813 - acc: 0.5359 - val_loss: 1.8559 - val_acc: 0.4352 - lr: 1.0000e-04
# Epoch 51/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2658 - acc: 0.5386
# Epoch 51: val_acc improved from 0.44217 to 0.44516, saving model to chkp/V_remake_v1_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 20s 77ms/step - loss: 1.2667 - acc: 0.5379 - val_loss: 1.8506 - val_acc: 0.4452 - lr: 1.0000e-05
# Epoch 52/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2554 - acc: 0.5414
# Epoch 52: val_acc did not improve from 0.44516
# 268/268 [==============================] - 20s 76ms/step - loss: 1.2553 - acc: 0.5413 - val_loss: 1.8475 - val_acc: 0.4377 - lr: 1.0000e-05
# Epoch 53/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2519 - acc: 0.5433
# Epoch 53: val_acc did not improve from 0.44516
# 268/268 [==============================] - 20s 76ms/step - loss: 1.2528 - acc: 0.5433 - val_loss: 1.8566 - val_acc: 0.4387 - lr: 1.0000e-05
# Epoch 54/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.2535 - acc: 0.5449
# Epoch 54: val_acc did not improve from 0.44516
# 268/268 [==============================] - 20s 76ms/step - loss: 1.2534 - acc: 0.5451 - val_loss: 1.8547 - val_acc: 0.4447 - lr: 1.0000e-05
# Epoch 54: early stopping
#
# Running model with seed 456
# Train Data Scenario Counts:
# scenario32 - LoS samples count: 2711, NLoS samples count: 107
# scenario33 - LoS samples count: 3317, NLoS samples count: 121
# scenario34 - LoS samples count: 3676, NLoS samples count: 96
#
# Test Data Scenario Counts:
# scenario32 - LoS samples count: 283, NLoS samples count: 14
# scenario33 - LoS samples count: 384, NLoS samples count: 15
# scenario34 - LoS samples count: 406, NLoS samples count: 13
# LoS Train Shape: (9704, 5, 150, 150), LoS Test Shape: (1073, 5, 150, 150)
# NLoS Train Shape: (324, 5, 150, 150), NLoS Test Shape: (42, 5, 150, 150)
# Train Labels Shape: (10028, 64)
# Test Labels Shape: (1115, 64)
# Train LoS Labels Shape: (9704, 64)
# Train NLoS Labels Shape: (324, 64)
# Test LoS Labels Shape: (1073, 64)
# Test NLoS Labels Shape: (42, 64)
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_2 (TimeDis  (None, 5, 256)           113536
#  tributed)
#
#  gru_2 (GRU)                 (None, 64)                61824
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 64)                4160
#
# =================================================================
# Total params: 183,680
# Trainable params: 182,768
# Non-trainable params: 912
# _________________________________________________________________
# None
# Epoch 1/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.7911 - acc: 0.0979
# Epoch 1: val_acc improved from -inf to 0.13559, saving model to chkp/V_remake_v1_multipleRuns_seed_456.hdf5
# ...
# Epoch 10/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.5443 - acc: 0.2610
# Epoch 10: val_acc improved from 0.25773 to 0.26022, saving model to chkp/V_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 2.5447 - acc: 0.2612 - val_loss: 2.4636 - val_acc: 0.2602 - lr: 0.0010
# Epoch 11/300
# 268/268 [==============================] - ETA: 0s - loss: 2.4875 - acc: 0.2755
# Epoch 11: val_acc improved from 0.26022 to 0.28265, saving model to chkp/V_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 2.4875 - acc: 0.2755 - val_loss: 2.4041 - val_acc: 0.2827 - lr: 0.0010
# Epoch 12/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.4040 - acc: 0.2879
# Epoch 12: val_acc did not improve from 0.28265
# 268/268 [==============================] - 21s 77ms/step - loss: 2.4040 - acc: 0.2881 - val_loss: 2.3838 - val_acc: 0.2802 - lr: 0.0010
# Epoch 13/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.3598 - acc: 0.2945
# Epoch 13: val_acc improved from 0.28265 to 0.29262, saving model to chkp/V_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 2.3594 - acc: 0.2948 - val_loss: 2.3787 - val_acc: 0.2926 - lr: 0.0010
# Epoch 14/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.3267 - acc: 0.2969
# Epoch 14: val_acc improved from 0.29262 to 0.30259, saving model to chkp/V_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 2.3267 - acc: 0.2969 - val_loss: 2.2675 - val_acc: 0.3026 - lr: 0.0010
# Epoch 15/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.2796 - acc: 0.3049
# Epoch 15: val_acc improved from 0.30259 to 0.32602, saving model to chkp/V_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 2.2793 - acc: 0.3048 - val_loss: 2.2438 - val_acc: 0.3260 - lr: 0.0010
# Epoch 16/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.2178 - acc: 0.3160
# Epoch 16: val_acc did not improve from 0.32602
# 268/268 [==============================] - 20s 76ms/step - loss: 2.2179 - acc: 0.3160 - val_loss: 2.2631 - val_acc: 0.3185 - lr: 0.0010
# Epoch 17/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1899 - acc: 0.3267
# Epoch 17: val_acc improved from 0.32602 to 0.33998, saving model to chkp/V_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 2.1891 - acc: 0.3269 - val_loss: 2.1509 - val_acc: 0.3400 - lr: 0.0010
# Epoch 18/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1306 - acc: 0.3442
# Epoch 18: val_acc did not improve from 0.33998
# 268/268 [==============================] - 20s 76ms/step - loss: 2.1306 - acc: 0.3441 - val_loss: 2.1974 - val_acc: 0.3185 - lr: 0.0010
# Epoch 19/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1296 - acc: 0.3401
# Epoch 19: val_acc improved from 0.33998 to 0.34447, saving model to chkp/V_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 2.1303 - acc: 0.3399 - val_loss: 2.1230 - val_acc: 0.3445 - lr: 0.0010
# Epoch 20/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1057 - acc: 0.3422
# Epoch 20: val_acc did not improve from 0.34447
# 268/268 [==============================] - 20s 77ms/step - loss: 2.1065 - acc: 0.3418 - val_loss: 2.1271 - val_acc: 0.3300 - lr: 0.0010
# Epoch 21/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0255 - acc: 0.3534
# Epoch 21: val_acc did not improve from 0.34447
# 268/268 [==============================] - 21s 77ms/step - loss: 2.0254 - acc: 0.3535 - val_loss: 2.0791 - val_acc: 0.3445 - lr: 0.0010
# Epoch 22/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0491 - acc: 0.3489
# Epoch 22: val_acc did not improve from 0.34447
# 268/268 [==============================] - 20s 76ms/step - loss: 2.0489 - acc: 0.3490 - val_loss: 2.1186 - val_acc: 0.3335 - lr: 0.0010
# Epoch 23/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9964 - acc: 0.3633
# Epoch 23: val_acc improved from 0.34447 to 0.34546, saving model to chkp/V_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 1.9974 - acc: 0.3630 - val_loss: 2.1042 - val_acc: 0.3455 - lr: 0.0010
# Epoch 24/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9549 - acc: 0.3654
# Epoch 24: val_acc improved from 0.34546 to 0.36142, saving model to chkp/V_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 1.9552 - acc: 0.3654 - val_loss: 2.0392 - val_acc: 0.3614 - lr: 0.0010
# Epoch 25/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9297 - acc: 0.3784
# Epoch 25: val_acc did not improve from 0.36142
# 268/268 [==============================] - 20s 76ms/step - loss: 1.9313 - acc: 0.3781 - val_loss: 2.0692 - val_acc: 0.3445 - lr: 0.0010
# Epoch 26/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9193 - acc: 0.3748
# Epoch 26: val_acc did not improve from 0.36142
# 268/268 [==============================] - 20s 76ms/step - loss: 1.9201 - acc: 0.3745 - val_loss: 2.0852 - val_acc: 0.3500 - lr: 0.0010
# Epoch 27/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9133 - acc: 0.3805
# Epoch 27: val_acc did not improve from 0.36142
# 268/268 [==============================] - 20s 76ms/step - loss: 1.9135 - acc: 0.3806 - val_loss: 2.1059 - val_acc: 0.3599 - lr: 0.0010
# Epoch 28/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8971 - acc: 0.3840
# Epoch 28: val_acc did not improve from 0.36142
# 268/268 [==============================] - 20s 76ms/step - loss: 1.8989 - acc: 0.3837 - val_loss: 2.0784 - val_acc: 0.3534 - lr: 0.0010
# Epoch 29/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8674 - acc: 0.3826
# Epoch 29: val_acc improved from 0.36142 to 0.36291, saving model to chkp/V_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 1.8675 - acc: 0.3824 - val_loss: 2.0062 - val_acc: 0.3629 - lr: 0.0010
# Epoch 30/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8477 - acc: 0.3929
# Epoch 30: val_acc did not improve from 0.36291
# 268/268 [==============================] - 21s 77ms/step - loss: 1.8489 - acc: 0.3929 - val_loss: 2.0161 - val_acc: 0.3609 - lr: 0.0010
# Epoch 31/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8263 - acc: 0.3878
# Epoch 31: val_acc improved from 0.36291 to 0.37039, saving model to chkp/V_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 1.8270 - acc: 0.3877 - val_loss: 2.0620 - val_acc: 0.3704 - lr: 0.0010
# Epoch 32/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7973 - acc: 0.4016
# Epoch 32: val_acc improved from 0.37039 to 0.37886, saving model to chkp/V_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 1.7984 - acc: 0.4011 - val_loss: 2.0575 - val_acc: 0.3789 - lr: 0.0010
# Epoch 33/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.8048 - acc: 0.4080
# Epoch 33: val_acc did not improve from 0.37886
# 268/268 [==============================] - 21s 77ms/step - loss: 1.8065 - acc: 0.4081 - val_loss: 2.0412 - val_acc: 0.3624 - lr: 0.0010
# Epoch 34/300
# 268/268 [==============================] - ETA: 0s - loss: 1.7974 - acc: 0.4023
# Epoch 34: val_acc did not improve from 0.37886
# 268/268 [==============================] - 21s 77ms/step - loss: 1.7974 - acc: 0.4023 - val_loss: 2.0094 - val_acc: 0.3759 - lr: 0.0010
# Epoch 35/300
# 268/268 [==============================] - ETA: 0s - loss: 1.7923 - acc: 0.4008
# Epoch 35: val_acc did not improve from 0.37886
# 268/268 [==============================] - 20s 76ms/step - loss: 1.7923 - acc: 0.4008 - val_loss: 2.0731 - val_acc: 0.3574 - lr: 0.0010
# Epoch 36/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7604 - acc: 0.4056
# Epoch 36: val_acc did not improve from 0.37886
# 268/268 [==============================] - 20s 76ms/step - loss: 1.7598 - acc: 0.4055 - val_loss: 2.0114 - val_acc: 0.3714 - lr: 0.0010
# Epoch 37/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.7310 - acc: 0.4139
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 37: val_acc did not improve from 0.37886
# 268/268 [==============================] - 20s 76ms/step - loss: 1.7315 - acc: 0.4134 - val_loss: 2.0371 - val_acc: 0.3579 - lr: 0.0010
# Epoch 38/300
# 268/268 [==============================] - ETA: 0s - loss: 1.6242 - acc: 0.4398
# Epoch 38: val_acc improved from 0.37886 to 0.37936, saving model to chkp/V_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 1.6242 - acc: 0.4398 - val_loss: 1.9532 - val_acc: 0.3794 - lr: 1.0000e-04
# Epoch 39/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.5631 - acc: 0.4596
# Epoch 39: val_acc improved from 0.37936 to 0.39083, saving model to chkp/V_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 1.5644 - acc: 0.4592 - val_loss: 1.9397 - val_acc: 0.3908 - lr: 1.0000e-04
# Epoch 40/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.5459 - acc: 0.4594
# Epoch 40: val_acc improved from 0.39083 to 0.39133, saving model to chkp/V_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 1.5469 - acc: 0.4591 - val_loss: 1.9469 - val_acc: 0.3913 - lr: 1.0000e-04
# Epoch 41/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.5348 - acc: 0.4659
# Epoch 41: val_acc improved from 0.39133 to 0.39731, saving model to chkp/V_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 1.5368 - acc: 0.4658 - val_loss: 1.9412 - val_acc: 0.3973 - lr: 1.0000e-04
# Epoch 42/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.5188 - acc: 0.4674
# Epoch 42: val_acc improved from 0.39731 to 0.39980, saving model to chkp/V_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 1.5199 - acc: 0.4671 - val_loss: 1.9319 - val_acc: 0.3998 - lr: 1.0000e-04
# Epoch 43/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.5024 - acc: 0.4744
# Epoch 43: val_acc did not improve from 0.39980
# 268/268 [==============================] - 20s 77ms/step - loss: 1.5036 - acc: 0.4742 - val_loss: 1.9376 - val_acc: 0.3943 - lr: 1.0000e-04
# Epoch 44/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.5092 - acc: 0.4638
# Epoch 44: val_acc improved from 0.39980 to 0.40778, saving model to chkp/V_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 1.5099 - acc: 0.4636 - val_loss: 1.9382 - val_acc: 0.4078 - lr: 1.0000e-04
# Epoch 45/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.4893 - acc: 0.4777
# Epoch 45: val_acc did not improve from 0.40778
# 268/268 [==============================] - 20s 76ms/step - loss: 1.4895 - acc: 0.4776 - val_loss: 1.9277 - val_acc: 0.4013 - lr: 1.0000e-04
# Epoch 46/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.4918 - acc: 0.4754
# Epoch 46: val_acc did not improve from 0.40778
# 268/268 [==============================] - 20s 76ms/step - loss: 1.4915 - acc: 0.4752 - val_loss: 1.9340 - val_acc: 0.3978 - lr: 1.0000e-04
# Epoch 47/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.4692 - acc: 0.4800
# Epoch 47: val_acc did not improve from 0.40778
# 268/268 [==============================] - 20s 76ms/step - loss: 1.4693 - acc: 0.4799 - val_loss: 1.9268 - val_acc: 0.4028 - lr: 1.0000e-04
# Epoch 48/300
# 268/268 [==============================] - ETA: 0s - loss: 1.4608 - acc: 0.4878
# Epoch 48: val_acc did not improve from 0.40778
# 268/268 [==============================] - 21s 77ms/step - loss: 1.4608 - acc: 0.4878 - val_loss: 1.9452 - val_acc: 0.4043 - lr: 1.0000e-04
# Epoch 49/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.4698 - acc: 0.4797
# Epoch 49: val_acc did not improve from 0.40778
# 268/268 [==============================] - 20s 76ms/step - loss: 1.4697 - acc: 0.4798 - val_loss: 1.9215 - val_acc: 0.4033 - lr: 1.0000e-04
# Epoch 50/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.4531 - acc: 0.4888
# Epoch 50: val_acc did not improve from 0.40778
# 268/268 [==============================] - 20s 76ms/step - loss: 1.4538 - acc: 0.4885 - val_loss: 1.9334 - val_acc: 0.4013 - lr: 1.0000e-04
# Epoch 51/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.4586 - acc: 0.4782
# Epoch 51: val_acc did not improve from 0.40778
# 268/268 [==============================] - 20s 76ms/step - loss: 1.4591 - acc: 0.4781 - val_loss: 1.9283 - val_acc: 0.4078 - lr: 1.0000e-04
# Epoch 52/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.4307 - acc: 0.4903
# Epoch 52: val_acc did not improve from 0.40778
# 268/268 [==============================] - 20s 76ms/step - loss: 1.4309 - acc: 0.4898 - val_loss: 1.9302 - val_acc: 0.4013 - lr: 1.0000e-04
# Epoch 53/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.4377 - acc: 0.4964
# Epoch 53: val_acc did not improve from 0.40778
# 268/268 [==============================] - 20s 76ms/step - loss: 1.4376 - acc: 0.4964 - val_loss: 1.9343 - val_acc: 0.4033 - lr: 1.0000e-04
# Epoch 54/300
# 268/268 [==============================] - ETA: 0s - loss: 1.4240 - acc: 0.4934
# Epoch 54: val_acc did not improve from 0.40778
# 268/268 [==============================] - 20s 76ms/step - loss: 1.4240 - acc: 0.4934 - val_loss: 1.9367 - val_acc: 0.3978 - lr: 1.0000e-04
# Epoch 55/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.4227 - acc: 0.4944
# Epoch 55: val_acc did not improve from 0.40778
# 268/268 [==============================] - 20s 76ms/step - loss: 1.4225 - acc: 0.4943 - val_loss: 1.9286 - val_acc: 0.4023 - lr: 1.0000e-04
# Epoch 56/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.4052 - acc: 0.5004
# Epoch 56: val_acc did not improve from 0.40778
# 268/268 [==============================] - 20s 76ms/step - loss: 1.4058 - acc: 0.5005 - val_loss: 1.9503 - val_acc: 0.4063 - lr: 1.0000e-04
# Epoch 57/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.4083 - acc: 0.5039
# Epoch 57: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 57: val_acc improved from 0.40778 to 0.40828, saving model to chkp/V_remake_v1_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 21s 77ms/step - loss: 1.4110 - acc: 0.5034 - val_loss: 1.9463 - val_acc: 0.4083 - lr: 1.0000e-04
# Epoch 58/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3850 - acc: 0.5066
# Epoch 58: val_acc did not improve from 0.40828
# 268/268 [==============================] - 20s 76ms/step - loss: 1.3851 - acc: 0.5065 - val_loss: 1.9451 - val_acc: 0.4053 - lr: 1.0000e-05
# Epoch 59/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3832 - acc: 0.5051
# Epoch 59: val_acc did not improve from 0.40828
# 268/268 [==============================] - 20s 76ms/step - loss: 1.3827 - acc: 0.5055 - val_loss: 1.9314 - val_acc: 0.3983 - lr: 1.0000e-05
# Epoch 60/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3775 - acc: 0.5047
# Epoch 60: val_acc did not improve from 0.40828
# 268/268 [==============================] - 20s 76ms/step - loss: 1.3771 - acc: 0.5049 - val_loss: 1.9401 - val_acc: 0.4048 - lr: 1.0000e-05
# Epoch 61/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.3789 - acc: 0.5051
# Epoch 61: val_acc did not improve from 0.40828
# 268/268 [==============================] - 20s 76ms/step - loss: 1.3782 - acc: 0.5057 - val_loss: 1.9395 - val_acc: 0.4083 - lr: 1.0000e-05
# Epoch 61: early stopping

# %%
#%% Test on each scen separately
#%%Test on Train and Test data (top-1,2,3)
'''
df_train = pd.read_csv('./ml_challenge_dev_multi_modal_v3_all_scenarios_with_LoS_status.csv')

# Find LoS and NLoS samples in the train and test indices
train_los_indices = df_train[df_train['LoS_status'] == 'LoS'].index.intersection(train_indices)
train_nlos_indices = df_train[df_train['LoS_status'] == 'NLoS'].index.intersection(train_indices)
test_los_indices = df_train[df_train['LoS_status'] == 'LoS'].index.intersection(test_indices)
test_nlos_indices = df_train[df_train['LoS_status'] == 'NLoS'].index.intersection(test_indices)

# Verify that all train and test samples are classified
assert len(train_los_indices) + len(train_nlos_indices) == len(train_indices), "Mismatch in total train samples"
assert len(test_los_indices) + len(test_nlos_indices) == len(test_indices), "Mismatch in total test samples"

# Identify scenarios
scenario_path = df_train['unit2_loc_1']

# Function to count LoS and NLoS samples for a scenario
def count_scenario_samples(scenario_keyword, los_indices, nlos_indices):
    scenario_indices = df_train[scenario_path.str.contains(scenario_keyword)].index
    los_count = len(np.intersect1d(los_indices, scenario_indices))
    nlos_count = len(np.intersect1d(nlos_indices, scenario_indices))
    return los_count, nlos_count

# Count LoS and NLoS samples for each scenario in train and test sets
scenario_los_nlos_counts_train = {}
scenario_los_nlos_counts_test = {}
for scenario_keyword in ['scenario32', 'scenario33', 'scenario34']:
    los_count_train, nlos_count_train = count_scenario_samples(scenario_keyword, train_los_indices, train_nlos_indices)
    los_count_test, nlos_count_test = count_scenario_samples(scenario_keyword, test_los_indices, test_nlos_indices)
    scenario_los_nlos_counts_train[scenario_keyword] = {'LoS': los_count_train, 'NLoS': nlos_count_train}
    scenario_los_nlos_counts_test[scenario_keyword] = {'LoS': los_count_test, 'NLoS': nlos_count_test}

# Print the counts for each scenario in train and test sets
print("Train Data Scenario Counts:")
for scenario, counts in scenario_los_nlos_counts_train.items():
    print(f"{scenario} - LoS samples count: {counts['LoS']}, NLoS samples count: {counts['NLoS']}")

print("\nTest Data Scenario Counts:")
for scenario, counts in scenario_los_nlos_counts_test.items():
    print(f"{scenario} - LoS samples count: {counts['LoS']}, NLoS samples count: {counts['NLoS']}")

# Extract LoS and NLoS samples from the GPS data and classes
X_train_los = vision[train_los_indices]
X_train_nlos = vision[train_nlos_indices]
X_test_los = vision[test_los_indices]
X_test_nlos = vision[test_nlos_indices]
y_train_los = classes[train_los_indices]
y_train_nlos = classes[train_nlos_indices]
y_test_los = classes[test_los_indices]
y_test_nlos = classes[test_nlos_indices]

# Print shapes of train and test datasets
print(f'LoS Train Shape: {X_train_los.shape}, LoS Test Shape: {X_test_los.shape}')
print(f'NLoS Train Shape: {X_train_nlos.shape}, NLoS Test Shape: {X_test_nlos.shape}')

# Print shapes of train and test labels
print(f'Train Labels Shape: {y_train.shape}')
print(f'Test Labels Shape: {y_test.shape}')
print(f'Train LoS Labels Shape: {y_train_los.shape}')
print(f'Train NLoS Labels Shape: {y_train_nlos.shape}')
print(f'Test LoS Labels Shape: {y_test_los.shape}')
print(f'Test NLoS Labels Shape: {y_test_nlos.shape}')

gc.collect()

# Power analysis
N_CLASSES = 64
pwr_rel_paths = df_train['unit1_pwr_60ghz'].values
pwrs_array = np.zeros((pwr_rel_paths.shape[0], N_CLASSES))
for sample_idx in range(pwr_rel_paths.shape[0]):
    pwr_abs_path = pwr_rel_paths[sample_idx]
    pwrs_array[sample_idx] = np.loadtxt(pwr_abs_path)
print('pwrs_array.shape:', pwrs_array.shape)

nan_count = np.isnan(pwrs_array).sum()
print(f'pwrs_array has {nan_count} NaN values')
# Replace NaN values with zero
pwrs_array[np.isnan(pwrs_array)] = 0
# Check if replacement was successful
nan_count_after = np.isnan(pwrs_array).sum()
print(f'pwrs_array after replacement has {nan_count_after} NaN values')

pwrs_array_train, pwrs_array_test_los, pwrs_array_test_nlos = pwrs_array[train_indices], pwrs_array[test_los_indices], pwrs_array[test_nlos_indices]
print(f'pwrs_array_train.shape: {pwrs_array_train.shape}, pwrs_array_test_los.shape: {pwrs_array_test_los.shape}, pwrs_array_test_nlos.shape: {pwrs_array_test_nlos.shape}')

# Model evaluation and prediction
def evaluate_model(model, X_data, y_data, pwrs_array, data_type, scenario, result_list, sample_indices):
    predictions = model.predict(X_data)
    y_pred = np.argsort(predictions, axis=1)[:, ::-1]
    save_pred_to_csv(sample_indices, y_pred, top_k=[1,2,3], target_csv=f'preds_{model_name}_{data_type}{scenario}.csv')
    true = np.argmax(y_data, axis=1).reshape(-1, 1)
    acc = compute_acc(y_pred, true, top_k=[1, 3, 5])
    score = compute_DBA_score(y_pred, true, max_k=3, delta=5)
    recall = recall_score(true, y_pred[:, 0], average='weighted')
    precision = precision_score(true, y_pred[:, 0], average='weighted')
    PF_mean = compute_powerfactor(y_pred, pwrs_array, k=3)
   
    result_list.append({
        'scenario': scenario,
        'type': data_type,
        'acc': acc,
        'score': round(score, 2),
        'PF1_mean': PF_mean[0],
        'PF2_mean': PF_mean[1],
        'PF3_mean': PF_mean[2],
        'recall': round(recall, 2),
        'precision': round(precision, 2)
    })

# Load the model
model = load_model(f'chkp/{model_name}.hdf5')

# Initialize results list
results = []

# Evaluate on training data
evaluate_model(model, X_train, y_train, pwrs_array_train, 'Train', 'All', results, train_indices)

# Evaluate on test data for each scenario
for scenario_keyword in ['scenario32', 'scenario33', 'scenario34']:
    scenario_indices = df_train[scenario_path.str.contains(scenario_keyword)].index
    test_los_scenario_indices = np.intersect1d(test_los_indices, scenario_indices)
    test_nlos_scenario_indices = np.intersect1d(test_nlos_indices, scenario_indices)
    
    X_test_los_scenario = vision[test_los_scenario_indices]
    X_test_nlos_scenario = vision[test_nlos_scenario_indices]
    y_test_los_scenario = classes[test_los_scenario_indices]
    y_test_nlos_scenario = classes[test_nlos_scenario_indices]
    
    pwrs_array_test_los_scenario = pwrs_array[test_los_scenario_indices]
    pwrs_array_test_nlos_scenario = pwrs_array[test_nlos_scenario_indices]
    
    evaluate_model(model, X_test_los_scenario, y_test_los_scenario, pwrs_array_test_los_scenario, 'Test_LoS', scenario_keyword, results, test_los_scenario_indices)
    evaluate_model(model, X_test_nlos_scenario, y_test_nlos_scenario, pwrs_array_test_nlos_scenario, 'Test_NLoS', scenario_keyword, results, test_nlos_scenario_indices)

# Print all results
for res in results:
    print(f"Scenario: {res['scenario']} - Type: {res['type']} - Accuracies: {res['acc']}, Score: {res['score']}, PF1_mean: {res['PF1_mean']}, PF2_mean: {res['PF2_mean']}, PF3_mean: {res['PF3_mean']}, Recall: {res['recall']}, Precision: {res['precision']}")

gc.collect()
'''
# Out:
# Train Data Scenario Counts:
# scenario32 - LoS samples count: 2683, NLoS samples count: 110
# scenario33 - LoS samples count: 3329, NLoS samples count: 120
# scenario34 - LoS samples count: 3691, NLoS samples count: 95
#
# Test Data Scenario Counts:
# scenario32 - LoS samples count: 311, NLoS samples count: 11
# scenario33 - LoS samples count: 372, NLoS samples count: 16
# scenario34 - LoS samples count: 391, NLoS samples count: 14
# LoS Train Shape: (9703, 5, 150, 150), LoS Test Shape: (1074, 5, 150, 150)
# NLoS Train Shape: (325, 5, 150, 150), NLoS Test Shape: (41, 5, 150, 150)
# Train Labels Shape: (10028, 64)
# Test Labels Shape: (1115, 64)
# Train LoS Labels Shape: (9703, 64)
# Train NLoS Labels Shape: (325, 64)
# Test LoS Labels Shape: (1074, 64)
# Test NLoS Labels Shape: (41, 64)
# pwrs_array.shape: (11143, 64)
# pwrs_array has 181 NaN values
# pwrs_array after replacement has 0 NaN values
# pwrs_array_train.shape: (10028, 64), pwrs_array_test_los.shape: (1074, 64), pwrs_array_test_nlos.shape: (41, 64)
# 314/314 [==============================] - 8s 24ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 10/10 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 55ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 12/12 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 58ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 13/13 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 56ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Scenario: All - Type: Train - Accuracies: [0.5643 0.8883 0.9581], Score: 0.91, PF1_mean: 0.98, PF2_mean: 0.99, PF3_mean: 1.0, Recall: 0.56, Precision: 0.56
# Scenario: scenario32 - Type: Test_LoS - Accuracies: [0.3698 0.7653 0.9132], Score: 0.85, PF1_mean: 0.97, PF2_mean: 0.98, PF3_mean: 0.99, Recall: 0.37, Precision: 0.29
# Scenario: scenario32 - Type: Test_NLoS - Accuracies: [0.     0.     0.2727], Score: 0.12, PF1_mean: 0.91, PF2_mean: 0.92, PF3_mean: 0.92, Recall: 0.0, Precision: 0.0
# Scenario: scenario33 - Type: Test_LoS - Accuracies: [0.422  0.7849 0.9113], Score: 0.86, PF1_mean: 0.97, PF2_mean: 0.99, PF3_mean: 0.99, Recall: 0.42, Precision: 0.38
# Scenario: scenario33 - Type: Test_NLoS - Accuracies: [0.    0.125 0.125], Score: 0.13, PF1_mean: 0.91, PF2_mean: 0.92, PF3_mean: 0.94, Recall: 0.0, Precision: 0.0
# Scenario: scenario34 - Type: Test_LoS - Accuracies: [0.4476 0.8286 0.9514], Score: 0.89, PF1_mean: 0.98, PF2_mean: 0.99, PF3_mean: 0.99, Recall: 0.45, Precision: 0.4
# Scenario: scenario34 - Type: Test_NLoS - Accuracies: [0.1429 0.2857 0.3571], Score: 0.25, PF1_mean: 0.9, PF2_mean: 0.91, PF3_mean: 0.93, Recall: 0.14, Precision: 0.14
# 7898

# %%
# Save results to CSV
df = pd.DataFrame(results)
df.to_csv(f'results_{model_name}.csv', index=False)

# %%
#%% Test on all scens together
#%%Test on Train and Test data (top-1,2,3)

# Model evaluation and prediction
def evaluate_model(model, X_data, y_data, pwrs_array, data_type, result_list, sample_indices):
    predictions = model.predict(X_data)
    y_pred = np.argsort(predictions, axis=1)[:, ::-1]
    save_pred_to_csv(sample_indices, y_pred, top_k=[1,2,3], target_csv=f'preds_{model_name}_{data_type}.csv')
    true = np.argmax(y_data, axis=1).reshape(-1, 1)
    acc = compute_acc(y_pred, true, top_k=[1, 3, 5])
    score = compute_DBA_score(y_pred, true, max_k=3, delta=5)
    recall = recall_score(true, y_pred[:, 0], average='weighted')
    precision = precision_score(true, y_pred[:, 0], average='weighted')
    PF_mean = compute_powerfactor(y_pred, pwrs_array, k=3)
    top_beams = calculate_top_beams(predictions, pwrs_array)
   
    result_list.append({
        'type': data_type,
        'acc': acc,
        'score': round(score, 2),
        'top31_beam': top_beams[0],
        'top33_beam': top_beams[1],
        'PF1_mean': PF_mean[0],
        'PF2_mean': PF_mean[1],
        'PF3_mean': PF_mean[2],
        'recall': round(recall, 2),
        'precision': round(precision, 2)
    })

# Define the seeds used for training
seeds = [42, 123, 456, 789, 101112]

# Placeholder for storing results from all seeds
all_results = []

for seed in seeds:
    print(f"\nEvaluating model with seed {seed}")

    # Train-Test Split with the current seed
    X_train, X_test, y_train, y_test, train_indices, test_indices = train_test_split(
        vision, classes, np.arange(len(vision)), test_size=0.1, stratify=classes, random_state=seed)

    df_train = pd.read_csv('./ml_challenge_dev_multi_modal_v3_all_scenarios_with_LoS_status.csv')

    # Find LoS and NLoS samples in the train and test indices
    train_los_indices = df_train[df_train['LoS_status'] == 'LoS'].index.intersection(train_indices)
    train_nlos_indices = df_train[df_train['LoS_status'] == 'NLoS'].index.intersection(train_indices)
    test_los_indices = df_train[df_train['LoS_status'] == 'LoS'].index.intersection(test_indices)
    test_nlos_indices = df_train[df_train['LoS_status'] == 'NLoS'].index.intersection(test_indices)

    # Extract LoS and NLoS samples from the data and classes
    X_train_los = vision[train_los_indices]
    X_train_nlos = vision[train_nlos_indices]
    X_test_los = vision[test_los_indices]
    X_test_nlos = vision[test_nlos_indices]
    y_train_los = classes[train_los_indices]
    y_train_nlos = classes[train_nlos_indices]
    y_test_los = classes[test_los_indices]
    y_test_nlos = classes[test_nlos_indices]

    # Power analysis - make sure to get the correct power arrays for each seed
    pwrs_array = np.zeros((df_train.shape[0], N_CLASSES))
    for sample_idx in range(df_train.shape[0]):
        pwr_abs_path = df_train['unit1_pwr_60ghz'].values[sample_idx]
        pwrs_array[sample_idx] = np.loadtxt(pwr_abs_path)

    pwrs_array[np.isnan(pwrs_array)] = 0
    pwrs_array_train = pwrs_array[train_indices]
    pwrs_array_test_los = pwrs_array[test_los_indices]
    pwrs_array_test_nlos = pwrs_array[test_nlos_indices]

    model = load_model(f'chkp/{model_name}_seed_{seed}.hdf5')

    # Initialize results list for the current seed
    seed_results = []

    # Evaluate on training data
    evaluate_model(model, X_train, y_train, pwrs_array_train, 'Train', seed_results, train_indices)

    # Evaluate on test data
    evaluate_model(model, X_test_los, y_test_los, pwrs_array_test_los, 'Test_LoS', seed_results, test_los_indices)
    evaluate_model(model, X_test_nlos, y_test_nlos, pwrs_array_test_nlos, 'Test_NLoS', seed_results, test_nlos_indices)

    # Store the results of this seed in all_results
    all_results.append(seed_results)

# Function to average results across all seeds
def average_results(all_results, metric):
    averages = {}
    types = ['Train', 'Test_LoS', 'Test_NLoS']
    for data_type in types:
        type_results = [res for seed_res in all_results for res in seed_res if res['type'] == data_type]
        avg_metric = np.mean([res[metric] for res in type_results], axis=0)
        std_metric = np.std([res[metric] for res in type_results], axis=0)
        averages[data_type] = (avg_metric, std_metric)
    return averages

# Compute averages and standard deviations for each metric
avg_accuracies = average_results(all_results, 'acc')
avg_scores = average_results(all_results, 'score')
avg_top31_beams = average_results(all_results, 'top31_beam')
avg_top33_beams = average_results(all_results, 'top33_beam')
avg_PF1_means = average_results(all_results, 'PF1_mean')
avg_PF2_means = average_results(all_results, 'PF2_mean')
avg_PF3_means = average_results(all_results, 'PF3_mean')
avg_recalls = average_results(all_results, 'recall')
avg_precisions = average_results(all_results, 'precision')

# Print the average results across all seeds
print("\nAverage Results Across All Seeds:")
for data_type in avg_accuracies:
    print(f"Type: {data_type} - Avg Accuracies: {avg_accuracies[data_type][0]} ± {avg_accuracies[data_type][1]}, "
          f"Avg Score: {avg_scores[data_type][0]} ± {avg_scores[data_type][1]}, "
          f"top31_beam: {avg_top31_beams[data_type][0]} ± {avg_top31_beams[data_type][1]}, "
          f"top33_beam: {avg_top33_beams[data_type][0]} ± {avg_top33_beams[data_type][1]}, "
          f"PF1_mean: {avg_PF1_means[data_type][0]} ± {avg_PF1_means[data_type][1]}, "
          f"PF2_mean: {avg_PF2_means[data_type][0]} ± {avg_PF2_means[data_type][1]}, "
          f"PF3_mean: {avg_PF3_means[data_type][0]} ± {avg_PF3_means[data_type][1]}, "
          f"Recall: {avg_recalls[data_type][0]} ± {avg_recalls[data_type][1]}, "
          f"Precision: {avg_precisions[data_type][0]} ± {avg_precisions[data_type][1]}")

gc.collect()
# Out:
# Evaluating model with seed 42
# 314/314 [==============================] - 8s 24ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 34/34 [==============================] - 1s 23ms/step
# 2/2 [==============================] - 0s 14ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Evaluating model with seed 123
# 314/314 [==============================] - 8s 23ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 34/34 [==============================] - 1s 23ms/step
# 2/2 [==============================] - 0s 17ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Evaluating model with seed 456
# 314/314 [==============================] - 8s 24ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 34/34 [==============================] - 1s 23ms/step
# 2/2 [==============================] - 0s 18ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Evaluating model with seed 789
# 314/314 [==============================] - 8s 24ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 34/34 [==============================] - 1s 23ms/step
# 2/2 [==============================] - 0s 15ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Evaluating model with seed 101112
# 314/314 [==============================] - 8s 23ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 34/34 [==============================] - 1s 22ms/step
# 2/2 [==============================] - 0s 15ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Average Results Across All Seeds:
# Type: Train - Avg Accuracies: [0.56392 0.89236 0.95654] ± [0.0140286  0.00710482 0.00462022], Avg Score: 0.9120000000000001 ± 0.007483314773547889, top31_beam: 0.866 ± 0.008000000000000007, top33_beam: 0.97 ± 0.0, PF1_mean: 0.9800000000000001 ± 1.1102230246251565e-16, PF2_mean: 0.99 ± 0.0, PF3_mean: 0.9960000000000001 ± 0.00489897948556636, Recall: 0.566 ± 0.013564659966250506, Precision: 0.544 ± 0.016248076809271934
# Type: Test_LoS - Avg Accuracies: [0.43648 0.80998 0.93012] ± [0.0073153  0.00996422 0.0098597 ], Avg Score: 0.8779999999999999 ± 0.007483314773547889, top31_beam: 0.8140000000000001 ± 0.013564659966250505, top33_beam: 0.962 ± 0.007483314773547889, PF1_mean: 0.97 ± 0.0, PF2_mean: 0.99 ± 0.0, PF3_mean: 0.99 ± 0.0, Recall: 0.438 ± 0.007483314773547889, Precision: 0.38 ± 0.012649110640673528
# Type: Test_NLoS - Avg Accuracies: [0.0543  0.12236 0.17046] ± [0.03639121 0.04718494 0.0499492 ], Avg Score: 0.16599999999999998 ± 0.051224993899462785, top31_beam: 0.284 ± 0.07812809993849844, top33_beam: 0.476 ± 0.08546344247688599, PF1_mean: 0.9 ± 0.017888543819998333, PF2_mean: 0.9200000000000002 ± 0.008944271909999166, PF3_mean: 0.932 ± 0.009797958971132666, Recall: 0.054000000000000006 ± 0.03773592452822641, Precision: 0.09 ± 0.08124038404635961
# 55596

# %%
# Define a function to format mean ± std
def format_mean_std(mean, std):
    return f"{mean:.2f} ± {std:.2f}"

# Initialize the final results list
formatted_results = []

# Process the results for saving
for data_type in avg_accuracies:
    acc_means, acc_stds = avg_accuracies[data_type]
    row = {
        'Type': data_type,
        'Acc': ', '.join([format_mean_std(m, s) for m, s in zip(acc_means, acc_stds)]),
        'Score': format_mean_std(*avg_scores[data_type]),
        'top31_beam': format_mean_std(*avg_top31_beams[data_type]),
        'top33_beam': format_mean_std(*avg_top33_beams[data_type]),
        'PF1_mean': format_mean_std(*avg_PF1_means[data_type]),
        'PF2_mean': format_mean_std(*avg_PF2_means[data_type]),
        'PF3_mean': format_mean_std(*avg_PF3_means[data_type]),
        'Recall': format_mean_std(*avg_recalls[data_type]),
        'Precision': format_mean_std(*avg_precisions[data_type])
    }
    formatted_results.append(row)

# Convert the list to a DataFrame
df = pd.DataFrame(formatted_results)

# Save to CSV
df.to_csv(f'results_{model_name}_AllScens.csv', index=False)

print("Results saved to CSV:")
print(df)
# Out:
# Results saved to CSV:
#         Type                                    Acc        Score   top31_beam  \
# 0      Train  0.56 ± 0.01, 0.89 ± 0.01, 0.96 ± 0.00  0.91 ± 0.01  0.87 ± 0.01
# 1   Test_LoS  0.44 ± 0.01, 0.81 ± 0.01, 0.93 ± 0.01  0.88 ± 0.01  0.81 ± 0.01
# 2  Test_NLoS  0.05 ± 0.04, 0.12 ± 0.05, 0.17 ± 0.05  0.17 ± 0.05  0.28 ± 0.08
#
#     top33_beam     PF1_mean     PF2_mean     PF3_mean       Recall  \
# 0  0.97 ± 0.00  0.98 ± 0.00  0.99 ± 0.00  1.00 ± 0.00  0.57 ± 0.01
# 1  0.96 ± 0.01  0.97 ± 0.00  0.99 ± 0.00  0.99 ± 0.00  0.44 ± 0.01
# 2  0.48 ± 0.09  0.90 ± 0.02  0.92 ± 0.01  0.93 ± 0.01  0.05 ± 0.04
#
#      Precision
# 0  0.54 ± 0.02
# 1  0.38 ± 0.01
# 2  0.09 ± 0.08
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
