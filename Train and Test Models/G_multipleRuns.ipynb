# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Apr 19 13:55:28 2023

@author: Saba
"""

import gc
import os
import numpy as np
import pandas as pd
from keras.layers import Conv2D, BatchNormalization, MaxPool2D, GlobalMaxPool2D
from keras.layers import TimeDistributed, GRU, Dense, Dropout
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow import keras
from sklearn.metrics import precision_score, recall_score
from keras.models import load_model
from keras.models import Sequential
from sklearn.model_selection import KFold
import matplotlib.lines as mlines
import utm
from collections import Counter
import random
import cv2
import seaborn as sns
import math
import pickle 

np.random.seed(42)
tf.random.set_seed(42)  # Set TensorFlow seed as well
random.seed = 42
     
#%% Main                
#Score function
def compute_acc(y_pred, y_true, top_k=[1,3,5]):
    """ Computes top-k accuracy given prediction and ground truth labels."""
    n_top_k = len(top_k)
    total_hits = np.zeros(n_top_k)
    
    n_test_samples = len(y_true)
    if len(y_pred) != n_test_samples:
        raise Exception('Number of predicted beams does not match number of labels.')
    
    # For each test sample, count times where true beam is in k top guesses
    for samp_idx in range(len(y_true)):
        for k_idx in range(n_top_k):
            hit = np.any(y_pred[samp_idx,:top_k[k_idx]] == y_true[samp_idx, -1])
            total_hits[k_idx] += 1 if hit else 0
    
    # Average the number of correct guesses (over the total samples)
    return np.round(total_hits / len(y_true), 4)

def save_pred_to_csv(sample_index, y_pred, top_k=[1,2,3], target_csv='beam_pred.csv'):
    """ 
    Saves the predicted beam results to a csv file. 
    Expects y_pred: n_samples x N_BEAMS, and saves the top_k columns only. 
    """
    
    cols = [f'top-{i} beam' for i in top_k]
    df = pd.DataFrame(data=y_pred[:, np.array(top_k)-1], columns=cols)
    df.index.name = 'index'
    df['sample_index'] = sample_index
    df.to_csv(target_csv)

def compute_DBA_score(y_pred, y_true, max_k=3, delta=5):
    """ 
    The top-k MBD (Minimum Beam Distance) as the minimum distance
    of any beam in the top-k set of predicted beams to the ground truth beam. 
    
    Then we take the average across all samples.
    
    Then we average that number over all the considered Ks.
    """
    n_samples = y_pred.shape[0]
    #n_beams = y_pred.shape[-1] 
    
    yk = np.zeros(max_k)
    for k in range(max_k):
        acc_avg_min_beam_dist = 0
        idxs_up_to_k = np.arange(k+1)
        for i in range(n_samples):
            aux1 = np.abs(y_pred[i, idxs_up_to_k] - y_true[i]) / delta
            # Compute min between beam diff and 1
            aux2 = np.min(np.stack((aux1, np.zeros_like(aux1)+1), axis=0), axis=0)
            acc_avg_min_beam_dist += np.min(aux2)
            
        yk[k] = 1 - acc_avg_min_beam_dist / n_samples
    
    return np.mean(yk)

#%% Power factor
def compute_powerfactor(y_pred, pwrs_array, k=3):
    '''
    Calculate the maximum power factor for top-1 to top-k predictions.
    
    Args:
    y_pred (numpy array): Sorted predictions (n_samples, 64), indices of beams sorted by probability.
    pwrs_array (numpy array): Power values for beams (n_samples, 64).
    k (int): The top-k predictions to consider.
    
    Returns:
    numpy array: Array of average max PFs from top-1 to top-k.
    '''
    max_Pr = np.max(pwrs_array, axis=1)  # Maximum power across all beams for each sample
    PF_max_k = np.zeros(k)  # Array to store the average of maximum PFs for each top-k
    #PF_max_k_stds = np.zeros(k)  # Array to store the standard deviation of maximum PFs for each top-k
    
    for i in range(1, k+1):
        max_PF = np.zeros(pwrs_array.shape[0])  # Array to hold the max PF for each sample for current top-i
        for j in range(pwrs_array.shape[0]):  # Iterate over each sample
            # Calculate PFs for the top-i predictions and find the maximum
            top_k_PFs = pwrs_array[j, y_pred[j, :i]] / max_Pr[j]
            max_PF[j] = np.max(top_k_PFs)  # Maximum PF for this sample among top-i
        PF_max_k[i-1] = np.round(np.mean(max_PF), 2)  # Average of maximum PFs across all samples for top-i
        #PF_max_k_stds[i-1] = np.round(np.std(max_PF), 2)  # Standard deviation of maximum PFs for top-i

    return PF_max_k #, PF_max_k_stds

def calculate_top_beams(predictions, truths):
    correct_top1_count = 0
    correct_top3_count = 0
    total_count = len(predictions)  # Assuming predictions and truths are lists of numpy arrays
    
    for pred, true in zip(predictions, truths):
        # Find the index of the highest value in the predicted array
        top_pred_index = np.argmax(pred)
        
        # Find the indices of the top 3 highest values in the true array
        top_true_indices = np.argsort(true)[-3:]
        
        # Check if the top predicted index is among the top 3 true indices for top-1 accuracy
        if top_pred_index in top_true_indices:
            correct_top1_count += 1
        
        # Find the indices of the top 3 highest values in the predicted array
        top_pred_indices = np.argsort(pred)[-3:]
        
        # Check if there is any intersection between the top 3 predicted indices and the top 3 true indices for top-3 accuracy
        if set(top_pred_indices) & set(top_true_indices):
            correct_top3_count += 1
    
    # Calculate the percentage of correct predictions for top-1 and top-3 accuracies
    top1_accuracy = (correct_top1_count / total_count)
    top3_accuracy = (correct_top3_count / total_count) 
    top1_accuracy  = round(top1_accuracy, 2)
    top3_accuracy  = round(top3_accuracy, 2)
    return [top1_accuracy,top3_accuracy]

# %%
'''
#%% GPU optimization
#
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
        
#
os.environ["TF_GPU_ALLOCATOR"]="cuda_malloc_async" #to allow automatic assignment of operations to different GPUs to prevent OOM issue
'''   

# Set environment variables to disable GPU usage and use CPU instead
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'  # This line disables GPU

# %%
#%% some global params
model_name = "G_remake_v1_2_multipleRuns"

# %%
#%%Load data
def add_noise(data, noise_level):
    noisy_data = data + np.random.normal(scale=noise_level, size=data.shape)
    return noisy_data

'''
def add_gps_noise(GPS, noise_level):
    GPS_noisy = np.zeros(GPS.shape)
    GPS_noisy[:,:,0] = GPS[:,:,0] + np.random.normal(scale=noise_level, size=GPS[:,:,0].shape)
    GPS_noisy[:,:,1] = GPS[:,:,1] + np.random.normal(scale=noise_level, size=GPS[:,:,1].shape)
    return GPS_noisy
'''

df_train =  pd.read_csv('./ml_challenge_dev_multi_modal_v2.csv')
index = df_train['unit1_beam'].values

#data = np.load('GPS_11143x5x210x360.npz')
GPS = np.load('GPS_11143x5x2.npz')['GPS']
#GPS = rescale(data['GPS'])
#GPS = add_noise(GPS, 0.05)
print(GPS.shape)
gc.collect()

'''multiModalData = np.zeros([11143,5,imageX,imageY,4])
multiModalData[:,:,:,:,0] = lidar
multiModalData[:,:,:,:,1] = vision
multiModalData[:,:,:,:,2] = radar
multiModalData[:,:,:,:,3] = GPS
multiModalData = tf.keras.utils.normalize(multiModalData.reshape([11143*5,-1]))  
multiModalData = multiModalData.reshape([11143,5,imageX,imageY,4])'''

classes = to_categorical(df_train['unit1_beam'].values - 1, num_classes = 64, dtype ="int32")
# Out:
# (11143, 5, 2)

# %%
#%% Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dropout, Dense
from tensorflow.keras.initializers import Constant
from tensorflow.keras.utils import to_categorical

def GNU_model(input_shape=(5, 2), nbout=64):
    model = Sequential()
    model.add(GRU(64, input_shape=input_shape))  # Adjusted input shape
    model.add(Dropout(0.8))
    
    model.add(Dense(nbout, activation='softmax'))
    return model

# %%
seeds = [42, 123, 456, 789, 101112]

results = []

for seed in seeds:
    print(f"\nRunning model with seed {seed}")
    
    X_train, X_test, y_train, y_test, train_indices, test_indices = train_test_split(
        GPS, classes, np.arange(len(GPS)), test_size=0.1, stratify=classes, random_state=seed)    
        
    #%% Scenarios and LoS NLoS analysis of train and test samples
    df_train = pd.read_csv('./ml_challenge_dev_multi_modal_v3_all_scenarios_with_LoS_status.csv')

    # Find LoS and NLoS samples in the train and test indices
    train_los_indices = df_train[df_train['LoS_status'] == 'LoS'].index.intersection(train_indices)
    train_nlos_indices = df_train[df_train['LoS_status'] == 'NLoS'].index.intersection(train_indices)
    test_los_indices = df_train[df_train['LoS_status'] == 'LoS'].index.intersection(test_indices)
    test_nlos_indices = df_train[df_train['LoS_status'] == 'NLoS'].index.intersection(test_indices)

    # Verify that all train and test samples are classified
    assert len(train_los_indices) + len(train_nlos_indices) == len(train_indices), "Mismatch in total train samples"
    assert len(test_los_indices) + len(test_nlos_indices) == len(test_indices), "Mismatch in total test samples"

    # Identify scenarios
    scenario_path = df_train['unit2_loc_1']

    # Function to count LoS and NLoS samples for a scenario
    def count_scenario_samples(scenario_keyword, los_indices, nlos_indices):
        scenario_indices = df_train[scenario_path.str.contains(scenario_keyword)].index
        los_count = len(np.intersect1d(los_indices, scenario_indices))
        nlos_count = len(np.intersect1d(nlos_indices, scenario_indices))
        return los_count, nlos_count

    # Count LoS and NLoS samples for each scenario in train and test sets
    scenario_los_nlos_counts_train = {}
    scenario_los_nlos_counts_test = {}
    for scenario_keyword in ['scenario32', 'scenario33', 'scenario34']:
        los_count_train, nlos_count_train = count_scenario_samples(scenario_keyword, train_los_indices, train_nlos_indices)
        los_count_test, nlos_count_test = count_scenario_samples(scenario_keyword, test_los_indices, test_nlos_indices)
        scenario_los_nlos_counts_train[scenario_keyword] = {'LoS': los_count_train, 'NLoS': nlos_count_train}
        scenario_los_nlos_counts_test[scenario_keyword] = {'LoS': los_count_test, 'NLoS': nlos_count_test}

    # Print the counts for each scenario in train and test sets
    print("Train Data Scenario Counts:")
    for scenario, counts in scenario_los_nlos_counts_train.items():
        print(f"{scenario} - LoS samples count: {counts['LoS']}, NLoS samples count: {counts['NLoS']}")

    print("\nTest Data Scenario Counts:")
    for scenario, counts in scenario_los_nlos_counts_test.items():
        print(f"{scenario} - LoS samples count: {counts['LoS']}, NLoS samples count: {counts['NLoS']}")

    # Extract LoS and NLoS samples from the modalities and classes
    X_train_los = GPS[train_los_indices]
    X_train_nlos = GPS[train_nlos_indices]
    X_test_los = GPS[test_los_indices]
    X_test_nlos = GPS[test_nlos_indices]
    y_train_los = classes[train_los_indices]
    y_train_nlos = classes[train_nlos_indices]
    y_test_los = classes[test_los_indices]
    y_test_nlos = classes[test_nlos_indices]

    # Print shapes of train and test datasets for each modality
    print(f'LoS Train Shape: {X_train_los.shape}, LoS Test Shape: {X_test_los.shape}')
    print(f'NLoS Train Shape: {X_train_nlos.shape}, NLoS Test Shape: {X_test_nlos.shape}')

    # Print shapes of train and test labels
    print(f'Train Labels Shape: {y_train.shape}')
    print(f'Test Labels Shape: {y_test.shape}')
    print(f'Train LoS Labels Shape: {y_train_los.shape}')
    print(f'Train NLoS Labels Shape: {y_train_nlos.shape}')
    print(f'Test LoS Labels Shape: {y_test_los.shape}')
    print(f'Test NLoS Labels Shape: {y_test_nlos.shape}')

    gc.collect()

    # some global params
    NBFRAME = 5
    N_CLASSES = 64
    INSHAPE = (5,2)
    model = GNU_model(INSHAPE, N_CLASSES)
    optimizer = keras.optimizers.Adam(0.01) 
    model.compile(optimizer, 'categorical_crossentropy', metrics=['acc'])
    print(model.summary())

    #Run the training
    EPOCHS=300
    BS = 30

    callbacks = [
        keras.callbacks.EarlyStopping(monitor='val_loss', patience=12, mode='min', verbose=1),
        keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=8, mode='min', verbose=1),
        keras.callbacks.ModelCheckpoint(
            f'chkp/{model_name}_seed_{seed}.hdf5', 
            monitor='val_acc',  # Monitor validation accuracy
            save_best_only  = True,
            mode='max',  # Maximize the monitored quantity
            verbose=1),
    ]

    history = model.fit(
        x=X_train,
        y=y_train,
        validation_split = 0.2, #0
        #validation_data=(X_val, y_val),
        verbose=1,
        #verbose='auto', #auto
        epochs=EPOCHS,
        batch_size =BS,
        callbacks=callbacks
    )

    gc.collect()
# Out:
# Running model with seed 42
# Train Data Scenario Counts:
# scenario32 - LoS samples count: 2683, NLoS samples count: 110
# scenario33 - LoS samples count: 3329, NLoS samples count: 120
# scenario34 - LoS samples count: 3691, NLoS samples count: 95
#
# Test Data Scenario Counts:
# scenario32 - LoS samples count: 311, NLoS samples count: 11
# scenario33 - LoS samples count: 372, NLoS samples count: 16
# scenario34 - LoS samples count: 391, NLoS samples count: 14
# LoS Train Shape: (9703, 5, 2), LoS Test Shape: (1074, 5, 2)
# NLoS Train Shape: (325, 5, 2), NLoS Test Shape: (41, 5, 2)
# Train Labels Shape: (10028, 64)
# Test Labels Shape: (1115, 64)
# Train LoS Labels Shape: (9703, 64)
# Train NLoS Labels Shape: (325, 64)
# Test LoS Labels Shape: (1074, 64)
# Test NLoS Labels Shape: (41, 64)
# 2024-08-21 15:23:26.674822: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2024-08-21 15:23:26.674871: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: edison
# 2024-08-21 15:23:26.674877: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: edison
# 2024-08-21 15:23:26.675060: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 560.28.3
# 2024-08-21 15:23:26.675103: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: NOT_FOUND: could not find kernel module information in driver version file contents: "NVRM version: NVIDIA UNIX Open Kernel Module for x86_64  560.28.03  Release Build  (dvs-builder@U16-A24-27-4)  Thu Jul 18 20:46:24 UTC 2024
# GCC version:  gcc version 11.4.0 (Ubuntu 11.4.0-1ubuntu1~22.04)
# "
# 2024-08-21 15:23:26.676014: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 64)                13056
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 64)                4160
#
# =================================================================
# Total params: 17,216
# Trainable params: 17,216
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/300
# 267/268 [============================>.] - ETA: 0s - loss: 3.6310 - acc: 0.0873
# Epoch 1: val_acc improved from -inf to 0.10917, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 5s 12ms/step - loss: 3.6317 - acc: 0.0874 - val_loss: 3.3568 - val_acc: 0.1092 - lr: 0.0100
# Epoch 2/300
# 265/268 [============================>.] - ETA: 0s - loss: 3.3924 - acc: 0.1119
# Epoch 2: val_acc improved from 0.10917 to 0.12861, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 11ms/step - loss: 3.3918 - acc: 0.1119 - val_loss: 3.2227 - val_acc: 0.1286 - lr: 0.0100
# Epoch 3/300
# 268/268 [==============================] - ETA: 0s - loss: 3.3031 - acc: 0.1290
# Epoch 3: val_acc improved from 0.12861 to 0.13061, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 11ms/step - loss: 3.3031 - acc: 0.1290 - val_loss: 3.2308 - val_acc: 0.1306 - lr: 0.0100
# Epoch 4/300
# 263/268 [============================>.] - ETA: 0s - loss: 3.2093 - acc: 0.1360
# Epoch 4: val_acc improved from 0.13061 to 0.18794, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 11ms/step - loss: 3.2055 - acc: 0.1375 - val_loss: 2.9868 - val_acc: 0.1879 - lr: 0.0100
# Epoch 5/300
# 266/268 [============================>.] - ETA: 0s - loss: 3.0773 - acc: 0.1524
# Epoch 5: val_acc improved from 0.18794 to 0.19242, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 11ms/step - loss: 3.0766 - acc: 0.1526 - val_loss: 2.7985 - val_acc: 0.1924 - lr: 0.0100
# Epoch 6/300
# 263/268 [============================>.] - ETA: 0s - loss: 2.9870 - acc: 0.1587
# Epoch 6: val_acc did not improve from 0.19242
# 268/268 [==============================] - 3s 12ms/step - loss: 2.9841 - acc: 0.1582 - val_loss: 2.7602 - val_acc: 0.1755 - lr: 0.0100
# Epoch 7/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.8983 - acc: 0.1638
# Epoch 7: val_acc improved from 0.19242 to 0.21087, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 11ms/step - loss: 2.8979 - acc: 0.1638 - val_loss: 2.6606 - val_acc: 0.2109 - lr: 0.0100
# Epoch 8/300
# 266/268 [============================>.] - ETA: 0s - loss: 2.8323 - acc: 0.1802
# Epoch 8: val_acc did not improve from 0.21087
# 268/268 [==============================] - 3s 11ms/step - loss: 2.8326 - acc: 0.1801 - val_loss: 2.6399 - val_acc: 0.2059 - lr: 0.0100
# Epoch 9/300
# 264/268 [============================>.] - ETA: 0s - loss: 2.7549 - acc: 0.1976
# Epoch 9: val_acc did not improve from 0.21087
# 268/268 [==============================] - 3s 11ms/step - loss: 2.7572 - acc: 0.1975 - val_loss: 2.5810 - val_acc: 0.1864 - lr: 0.0100
# Epoch 10/300
# 268/268 [==============================] - ETA: 0s - loss: 2.7185 - acc: 0.1987
# Epoch 10: val_acc improved from 0.21087 to 0.26770, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 11ms/step - loss: 2.7185 - acc: 0.1987 - val_loss: 2.4273 - val_acc: 0.2677 - lr: 0.0100
# Epoch 11/300
# 266/268 [============================>.] - ETA: 0s - loss: 2.6806 - acc: 0.2139
# Epoch 11: val_acc did not improve from 0.26770
# 268/268 [==============================] - 3s 11ms/step - loss: 2.6805 - acc: 0.2139 - val_loss: 2.4892 - val_acc: 0.2074 - lr: 0.0100
# Epoch 12/300
# 265/268 [============================>.] - ETA: 0s - loss: 2.6706 - acc: 0.2146
# Epoch 12: val_acc improved from 0.26770 to 0.27318, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 11ms/step - loss: 2.6707 - acc: 0.2148 - val_loss: 2.3654 - val_acc: 0.2732 - lr: 0.0100
# Epoch 13/300
# 265/268 [============================>.] - ETA: 0s - loss: 2.6433 - acc: 0.2132
# Epoch 13: val_acc did not improve from 0.27318
# 268/268 [==============================] - 3s 11ms/step - loss: 2.6452 - acc: 0.2125 - val_loss: 2.4828 - val_acc: 0.2253 - lr: 0.0100
# Epoch 14/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.6326 - acc: 0.2195
# Epoch 14: val_acc did not improve from 0.27318
# 268/268 [==============================] - 3s 12ms/step - loss: 2.6322 - acc: 0.2194 - val_loss: 2.3754 - val_acc: 0.2592 - lr: 0.0100
# Epoch 15/300
# 265/268 [============================>.] - ETA: 0s - loss: 2.5938 - acc: 0.2244
# Epoch 15: val_acc did not improve from 0.27318
# 268/268 [==============================] - 3s 12ms/step - loss: 2.5922 - acc: 0.2248 - val_loss: 2.5004 - val_acc: 0.2059 - lr: 0.0100
# Epoch 16/300
# 268/268 [==============================] - ETA: 0s - loss: 2.5863 - acc: 0.2311
# Epoch 16: val_acc did not improve from 0.27318
# 268/268 [==============================] - 3s 12ms/step - loss: 2.5863 - acc: 0.2311 - val_loss: 2.3672 - val_acc: 0.2527 - lr: 0.0100
# Epoch 17/300
# 268/268 [==============================] - ETA: 0s - loss: 2.5691 - acc: 0.2407
# Epoch 17: val_acc improved from 0.27318 to 0.27617, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 2.5691 - acc: 0.2407 - val_loss: 2.3294 - val_acc: 0.2762 - lr: 0.0100
# Epoch 18/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.5400 - acc: 0.2444
# Epoch 18: val_acc improved from 0.27617 to 0.28215, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 11ms/step - loss: 2.5394 - acc: 0.2447 - val_loss: 2.3096 - val_acc: 0.2822 - lr: 0.0100
# Epoch 19/300
# 265/268 [============================>.] - ETA: 0s - loss: 2.5466 - acc: 0.2375
# Epoch 19: val_acc improved from 0.28215 to 0.28514, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 11ms/step - loss: 2.5459 - acc: 0.2373 - val_loss: 2.2723 - val_acc: 0.2851 - lr: 0.0100
# Epoch 20/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.4893 - acc: 0.2506
# Epoch 20: val_acc improved from 0.28514 to 0.29711, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 2.4894 - acc: 0.2507 - val_loss: 2.3130 - val_acc: 0.2971 - lr: 0.0100
# Epoch 21/300
# 265/268 [============================>.] - ETA: 0s - loss: 2.5234 - acc: 0.2375
# Epoch 21: val_acc did not improve from 0.29711
# 268/268 [==============================] - 3s 11ms/step - loss: 2.5239 - acc: 0.2373 - val_loss: 2.2475 - val_acc: 0.2742 - lr: 0.0100
# Epoch 22/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.4827 - acc: 0.2573
# Epoch 22: val_acc did not improve from 0.29711
# 268/268 [==============================] - 3s 11ms/step - loss: 2.4819 - acc: 0.2574 - val_loss: 2.2481 - val_acc: 0.2817 - lr: 0.0100
# Epoch 23/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.4692 - acc: 0.2513
# Epoch 23: val_acc improved from 0.29711 to 0.30259, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 2.4696 - acc: 0.2511 - val_loss: 2.2385 - val_acc: 0.3026 - lr: 0.0100
# Epoch 24/300
# 265/268 [============================>.] - ETA: 0s - loss: 2.4597 - acc: 0.2561
# Epoch 24: val_acc did not improve from 0.30259
# 268/268 [==============================] - 3s 11ms/step - loss: 2.4621 - acc: 0.2563 - val_loss: 2.2520 - val_acc: 0.2762 - lr: 0.0100
# Epoch 25/300
# 265/268 [============================>.] - ETA: 0s - loss: 2.4589 - acc: 0.2606
# Epoch 25: val_acc did not improve from 0.30259
# 268/268 [==============================] - 3s 11ms/step - loss: 2.4575 - acc: 0.2612 - val_loss: 2.1914 - val_acc: 0.2996 - lr: 0.0100
# Epoch 26/300
# 265/268 [============================>.] - ETA: 0s - loss: 2.4278 - acc: 0.2639
# Epoch 26: val_acc did not improve from 0.30259
# 268/268 [==============================] - 3s 11ms/step - loss: 2.4264 - acc: 0.2644 - val_loss: 2.2475 - val_acc: 0.2767 - lr: 0.0100
# Epoch 27/300
# 266/268 [============================>.] - ETA: 0s - loss: 2.4391 - acc: 0.2618
# Epoch 27: val_acc improved from 0.30259 to 0.31107, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 2.4375 - acc: 0.2618 - val_loss: 2.1615 - val_acc: 0.3111 - lr: 0.0100
# Epoch 28/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.4463 - acc: 0.2624
# Epoch 28: val_acc did not improve from 0.31107
# 268/268 [==============================] - 3s 11ms/step - loss: 2.4471 - acc: 0.2622 - val_loss: 2.1827 - val_acc: 0.2926 - lr: 0.0100
# Epoch 29/300
# 266/268 [============================>.] - ETA: 0s - loss: 2.4500 - acc: 0.2591
# Epoch 29: val_acc did not improve from 0.31107
# 268/268 [==============================] - 3s 11ms/step - loss: 2.4509 - acc: 0.2592 - val_loss: 2.1875 - val_acc: 0.2976 - lr: 0.0100
# Epoch 30/300
# 268/268 [==============================] - ETA: 0s - loss: 2.4142 - acc: 0.2648
# Epoch 30: val_acc did not improve from 0.31107
# 268/268 [==============================] - 3s 11ms/step - loss: 2.4142 - acc: 0.2648 - val_loss: 2.1658 - val_acc: 0.3101 - lr: 0.0100
# Epoch 31/300
# 266/268 [============================>.] - ETA: 0s - loss: 2.4027 - acc: 0.2723
# Epoch 31: val_acc did not improve from 0.31107
# 268/268 [==============================] - 3s 12ms/step - loss: 2.4049 - acc: 0.2716 - val_loss: 2.1896 - val_acc: 0.2836 - lr: 0.0100
# Epoch 32/300
# 266/268 [============================>.] - ETA: 0s - loss: 2.4022 - acc: 0.2673
# Epoch 32: val_acc improved from 0.31107 to 0.31805, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 2.4024 - acc: 0.2671 - val_loss: 2.1470 - val_acc: 0.3180 - lr: 0.0100
# Epoch 33/300
# 268/268 [==============================] - ETA: 0s - loss: 2.3929 - acc: 0.2725
# Epoch 33: val_acc did not improve from 0.31805
# 268/268 [==============================] - 3s 11ms/step - loss: 2.3929 - acc: 0.2725 - val_loss: 2.1887 - val_acc: 0.2961 - lr: 0.0100
# Epoch 34/300
# 266/268 [============================>.] - ETA: 0s - loss: 2.3793 - acc: 0.2748
# Epoch 34: val_acc did not improve from 0.31805
# 268/268 [==============================] - 3s 11ms/step - loss: 2.3800 - acc: 0.2747 - val_loss: 2.1521 - val_acc: 0.3091 - lr: 0.0100
# Epoch 35/300
# 266/268 [============================>.] - ETA: 0s - loss: 2.3742 - acc: 0.2782
# Epoch 35: val_acc did not improve from 0.31805
# 268/268 [==============================] - 3s 11ms/step - loss: 2.3739 - acc: 0.2780 - val_loss: 2.1688 - val_acc: 0.3116 - lr: 0.0100
# Epoch 36/300
# 268/268 [==============================] - ETA: 0s - loss: 2.4088 - acc: 0.2698
# Epoch 36: val_acc did not improve from 0.31805
# 268/268 [==============================] - 3s 12ms/step - loss: 2.4088 - acc: 0.2698 - val_loss: 2.1027 - val_acc: 0.3161 - lr: 0.0100
# Epoch 37/300
# 266/268 [============================>.] - ETA: 0s - loss: 2.3787 - acc: 0.2781
# Epoch 37: val_acc did not improve from 0.31805
# 268/268 [==============================] - 3s 12ms/step - loss: 2.3791 - acc: 0.2779 - val_loss: 2.2074 - val_acc: 0.2817 - lr: 0.0100
# Epoch 38/300
# 268/268 [==============================] - ETA: 0s - loss: 2.3594 - acc: 0.2811
# Epoch 38: val_acc improved from 0.31805 to 0.32303, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 2.3594 - acc: 0.2811 - val_loss: 2.1166 - val_acc: 0.3230 - lr: 0.0100
# Epoch 39/300
# 266/268 [============================>.] - ETA: 0s - loss: 2.3718 - acc: 0.2801
# Epoch 39: val_acc improved from 0.32303 to 0.33948, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 2.3710 - acc: 0.2801 - val_loss: 2.0582 - val_acc: 0.3395 - lr: 0.0100
# Epoch 40/300
# 264/268 [============================>.] - ETA: 0s - loss: 2.3620 - acc: 0.2814
# Epoch 40: val_acc did not improve from 0.33948
# 268/268 [==============================] - 3s 12ms/step - loss: 2.3610 - acc: 0.2818 - val_loss: 2.0892 - val_acc: 0.3175 - lr: 0.0100
# Epoch 41/300
# 266/268 [============================>.] - ETA: 0s - loss: 2.3373 - acc: 0.2836
# Epoch 41: val_acc did not improve from 0.33948
# 268/268 [==============================] - 3s 12ms/step - loss: 2.3378 - acc: 0.2836 - val_loss: 2.1478 - val_acc: 0.3051 - lr: 0.0100
# Epoch 42/300
# 265/268 [============================>.] - ETA: 0s - loss: 2.3321 - acc: 0.2914
# Epoch 42: val_acc did not improve from 0.33948
# 268/268 [==============================] - 3s 12ms/step - loss: 2.3318 - acc: 0.2913 - val_loss: 2.1847 - val_acc: 0.2996 - lr: 0.0100
# Epoch 43/300
# 266/268 [============================>.] - ETA: 0s - loss: 2.3379 - acc: 0.2845
# Epoch 43: val_acc did not improve from 0.33948
# 268/268 [==============================] - 3s 11ms/step - loss: 2.3361 - acc: 0.2853 - val_loss: 2.1151 - val_acc: 0.3260 - lr: 0.0100
# Epoch 44/300
# 266/268 [============================>.] - ETA: 0s - loss: 2.3161 - acc: 0.2812
# Epoch 44: val_acc did not improve from 0.33948
# 268/268 [==============================] - 3s 12ms/step - loss: 2.3182 - acc: 0.2811 - val_loss: 2.0698 - val_acc: 0.3350 - lr: 0.0100
# Epoch 45/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.3117 - acc: 0.2958
# Epoch 45: val_acc did not improve from 0.33948
# 268/268 [==============================] - 3s 12ms/step - loss: 2.3120 - acc: 0.2957 - val_loss: 2.0661 - val_acc: 0.3250 - lr: 0.0100
# Epoch 46/300
# 264/268 [============================>.] - ETA: 0s - loss: 2.3221 - acc: 0.2884
# Epoch 46: val_acc did not improve from 0.33948
# 268/268 [==============================] - 3s 12ms/step - loss: 2.3232 - acc: 0.2880 - val_loss: 2.0560 - val_acc: 0.3395 - lr: 0.0100
# Epoch 47/300
# 264/268 [============================>.] - ETA: 0s - loss: 2.3294 - acc: 0.2913
# Epoch 47: val_acc improved from 0.33948 to 0.34247, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 2.3310 - acc: 0.2912 - val_loss: 2.0404 - val_acc: 0.3425 - lr: 0.0100
# Epoch 48/300
# 263/268 [============================>.] - ETA: 0s - loss: 2.3080 - acc: 0.2854
# Epoch 48: val_acc did not improve from 0.34247
# 268/268 [==============================] - 3s 11ms/step - loss: 2.3080 - acc: 0.2856 - val_loss: 2.0941 - val_acc: 0.3131 - lr: 0.0100
# Epoch 49/300
# 266/268 [============================>.] - ETA: 0s - loss: 2.3024 - acc: 0.2961
# Epoch 49: val_acc did not improve from 0.34247
# 268/268 [==============================] - 3s 11ms/step - loss: 2.3027 - acc: 0.2959 - val_loss: 2.0160 - val_acc: 0.3400 - lr: 0.0100
# Epoch 50/300
# 265/268 [============================>.] - ETA: 0s - loss: 2.3017 - acc: 0.2906
# Epoch 50: val_acc improved from 0.34247 to 0.34546, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 11ms/step - loss: 2.3035 - acc: 0.2905 - val_loss: 2.0180 - val_acc: 0.3455 - lr: 0.0100
# Epoch 51/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.3341 - acc: 0.2894
# Epoch 51: val_acc did not improve from 0.34546
# 268/268 [==============================] - 3s 11ms/step - loss: 2.3335 - acc: 0.2892 - val_loss: 2.0138 - val_acc: 0.3345 - lr: 0.0100
# Epoch 52/300
# 265/268 [============================>.] - ETA: 0s - loss: 2.3211 - acc: 0.2833
# Epoch 52: val_acc improved from 0.34546 to 0.34696, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 11ms/step - loss: 2.3197 - acc: 0.2841 - val_loss: 2.0261 - val_acc: 0.3470 - lr: 0.0100
# Epoch 53/300
# 264/268 [============================>.] - ETA: 0s - loss: 2.2865 - acc: 0.2965
# Epoch 53: val_acc did not improve from 0.34696
# 268/268 [==============================] - 3s 11ms/step - loss: 2.2837 - acc: 0.2968 - val_loss: 2.0408 - val_acc: 0.3420 - lr: 0.0100
# Epoch 54/300
# 268/268 [==============================] - ETA: 0s - loss: 2.3054 - acc: 0.2956
# Epoch 54: val_acc improved from 0.34696 to 0.35244, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 2.3054 - acc: 0.2956 - val_loss: 1.9917 - val_acc: 0.3524 - lr: 0.0100
# Epoch 55/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.2668 - acc: 0.2971
# Epoch 55: val_acc did not improve from 0.35244
# 268/268 [==============================] - 3s 12ms/step - loss: 2.2665 - acc: 0.2974 - val_loss: 2.0307 - val_acc: 0.3400 - lr: 0.0100
# Epoch 56/300
# 265/268 [============================>.] - ETA: 0s - loss: 2.2873 - acc: 0.3015
# Epoch 56: val_acc did not improve from 0.35244
# 268/268 [==============================] - 3s 12ms/step - loss: 2.2873 - acc: 0.3009 - val_loss: 2.0388 - val_acc: 0.3390 - lr: 0.0100
# Epoch 57/300
# 265/268 [============================>.] - ETA: 0s - loss: 2.2813 - acc: 0.2940
# Epoch 57: val_acc did not improve from 0.35244
# 268/268 [==============================] - 3s 11ms/step - loss: 2.2819 - acc: 0.2939 - val_loss: 1.9906 - val_acc: 0.3375 - lr: 0.0100
# Epoch 58/300
# 265/268 [============================>.] - ETA: 0s - loss: 2.2827 - acc: 0.2928
# Epoch 58: val_acc improved from 0.35244 to 0.37039, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 2.2816 - acc: 0.2926 - val_loss: 1.9602 - val_acc: 0.3704 - lr: 0.0100
# Epoch 59/300
# 268/268 [==============================] - ETA: 0s - loss: 2.2506 - acc: 0.3079
# Epoch 59: val_acc did not improve from 0.37039
# 268/268 [==============================] - 3s 12ms/step - loss: 2.2506 - acc: 0.3079 - val_loss: 1.9882 - val_acc: 0.3445 - lr: 0.0100
# Epoch 60/300
# 264/268 [============================>.] - ETA: 0s - loss: 2.2990 - acc: 0.2913
# Epoch 60: val_acc did not improve from 0.37039
# 268/268 [==============================] - 3s 11ms/step - loss: 2.3033 - acc: 0.2913 - val_loss: 1.9872 - val_acc: 0.3500 - lr: 0.0100
# Epoch 61/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.2470 - acc: 0.3101
# Epoch 61: val_acc did not improve from 0.37039
# 268/268 [==============================] - 3s 11ms/step - loss: 2.2467 - acc: 0.3103 - val_loss: 2.0015 - val_acc: 0.3360 - lr: 0.0100
# Epoch 62/300
# 268/268 [==============================] - ETA: 0s - loss: 2.2592 - acc: 0.3058
# Epoch 62: val_acc did not improve from 0.37039
# 268/268 [==============================] - 3s 12ms/step - loss: 2.2592 - acc: 0.3058 - val_loss: 2.1116 - val_acc: 0.3116 - lr: 0.0100
# Epoch 63/300
# 265/268 [============================>.] - ETA: 0s - loss: 2.2547 - acc: 0.3005
# Epoch 63: val_acc did not improve from 0.37039
# 268/268 [==============================] - 3s 12ms/step - loss: 2.2571 - acc: 0.2999 - val_loss: 1.9615 - val_acc: 0.3639 - lr: 0.0100
# Epoch 64/300
# 264/268 [============================>.] - ETA: 0s - loss: 2.2420 - acc: 0.3045
# Epoch 64: val_acc did not improve from 0.37039
# 268/268 [==============================] - 3s 12ms/step - loss: 2.2430 - acc: 0.3049 - val_loss: 2.0903 - val_acc: 0.3225 - lr: 0.0100
# Epoch 65/300
# 265/268 [============================>.] - ETA: 0s - loss: 2.2440 - acc: 0.3087
# Epoch 65: val_acc did not improve from 0.37039
# 268/268 [==============================] - 3s 12ms/step - loss: 2.2408 - acc: 0.3094 - val_loss: 2.0035 - val_acc: 0.3480 - lr: 0.0100
# Epoch 66/300
# 266/268 [============================>.] - ETA: 0s - loss: 2.2602 - acc: 0.2940
# Epoch 66: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
#
# Epoch 66: val_acc did not improve from 0.37039
# 268/268 [==============================] - 3s 12ms/step - loss: 2.2616 - acc: 0.2939 - val_loss: 2.0002 - val_acc: 0.3450 - lr: 0.0100
# Epoch 67/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.1656 - acc: 0.3286
# Epoch 67: val_acc improved from 0.37039 to 0.37986, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 2.1648 - acc: 0.3285 - val_loss: 1.8950 - val_acc: 0.3799 - lr: 1.0000e-03
# Epoch 68/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0919 - acc: 0.3393
# Epoch 68: val_acc improved from 0.37986 to 0.38385, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0927 - acc: 0.3392 - val_loss: 1.8815 - val_acc: 0.3838 - lr: 1.0000e-03
# Epoch 69/300
# 265/268 [============================>.] - ETA: 0s - loss: 2.0710 - acc: 0.3473
# Epoch 69: val_acc improved from 0.38385 to 0.38833, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0734 - acc: 0.3469 - val_loss: 1.8658 - val_acc: 0.3883 - lr: 1.0000e-03
# Epoch 70/300
# 268/268 [==============================] - ETA: 0s - loss: 2.0626 - acc: 0.3508
# Epoch 70: val_acc improved from 0.38833 to 0.39232, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0626 - acc: 0.3508 - val_loss: 1.8568 - val_acc: 0.3923 - lr: 1.0000e-03
# Epoch 71/300
# 268/268 [==============================] - ETA: 0s - loss: 2.0800 - acc: 0.3452
# Epoch 71: val_acc did not improve from 0.39232
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0800 - acc: 0.3452 - val_loss: 1.8689 - val_acc: 0.3868 - lr: 1.0000e-03
# Epoch 72/300
# 266/268 [============================>.] - ETA: 0s - loss: 2.0711 - acc: 0.3519
# Epoch 72: val_acc did not improve from 0.39232
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0726 - acc: 0.3513 - val_loss: 1.8575 - val_acc: 0.3878 - lr: 1.0000e-03
# Epoch 73/300
# 265/268 [============================>.] - ETA: 0s - loss: 2.0451 - acc: 0.3547
# Epoch 73: val_acc did not improve from 0.39232
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0447 - acc: 0.3546 - val_loss: 1.8511 - val_acc: 0.3908 - lr: 1.0000e-03
# Epoch 74/300
# 265/268 [============================>.] - ETA: 0s - loss: 2.0513 - acc: 0.3533
# Epoch 74: val_acc improved from 0.39232 to 0.39282, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0481 - acc: 0.3533 - val_loss: 1.8483 - val_acc: 0.3928 - lr: 1.0000e-03
# Epoch 75/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0485 - acc: 0.3564
# Epoch 75: val_acc did not improve from 0.39282
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0490 - acc: 0.3561 - val_loss: 1.8532 - val_acc: 0.3903 - lr: 1.0000e-03
# Epoch 76/300
# 268/268 [==============================] - ETA: 0s - loss: 2.0440 - acc: 0.3613
# Epoch 76: val_acc improved from 0.39282 to 0.39382, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0440 - acc: 0.3613 - val_loss: 1.8381 - val_acc: 0.3938 - lr: 1.0000e-03
# Epoch 77/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0523 - acc: 0.3643
# Epoch 77: val_acc improved from 0.39382 to 0.40080, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0523 - acc: 0.3641 - val_loss: 1.8410 - val_acc: 0.4008 - lr: 1.0000e-03
# Epoch 78/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0411 - acc: 0.3549
# Epoch 78: val_acc did not improve from 0.40080
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0416 - acc: 0.3553 - val_loss: 1.8369 - val_acc: 0.3943 - lr: 1.0000e-03
# Epoch 79/300
# 266/268 [============================>.] - ETA: 0s - loss: 2.0312 - acc: 0.3672
# Epoch 79: val_acc did not improve from 0.40080
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0309 - acc: 0.3666 - val_loss: 1.8342 - val_acc: 0.3973 - lr: 1.0000e-03
# Epoch 80/300
# 267/268 [============================>.] - ETA: 0s - loss: 2.0280 - acc: 0.3612
# Epoch 80: val_acc improved from 0.40080 to 0.40229, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0284 - acc: 0.3613 - val_loss: 1.8251 - val_acc: 0.4023 - lr: 1.0000e-03
# Epoch 81/300
# 268/268 [==============================] - ETA: 0s - loss: 2.0268 - acc: 0.3601
# Epoch 81: val_acc improved from 0.40229 to 0.40429, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0268 - acc: 0.3601 - val_loss: 1.8290 - val_acc: 0.4043 - lr: 1.0000e-03
# Epoch 82/300
# 264/268 [============================>.] - ETA: 0s - loss: 2.0316 - acc: 0.3605
# Epoch 82: val_acc improved from 0.40429 to 0.40528, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0312 - acc: 0.3605 - val_loss: 1.8186 - val_acc: 0.4053 - lr: 1.0000e-03
# Epoch 83/300
# 266/268 [============================>.] - ETA: 0s - loss: 2.0262 - acc: 0.3664
# Epoch 83: val_acc did not improve from 0.40528
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0253 - acc: 0.3664 - val_loss: 1.8270 - val_acc: 0.4038 - lr: 1.0000e-03
# Epoch 84/300
# 266/268 [============================>.] - ETA: 0s - loss: 2.0358 - acc: 0.3579
# Epoch 84: val_acc did not improve from 0.40528
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0351 - acc: 0.3574 - val_loss: 1.8170 - val_acc: 0.4043 - lr: 1.0000e-03
# Epoch 85/300
# 264/268 [============================>.] - ETA: 0s - loss: 2.0191 - acc: 0.3631
# Epoch 85: val_acc did not improve from 0.40528
# 268/268 [==============================] - 3s 11ms/step - loss: 2.0210 - acc: 0.3634 - val_loss: 1.8196 - val_acc: 0.4018 - lr: 1.0000e-03
# Epoch 86/300
# 265/268 [============================>.] - ETA: 0s - loss: 2.0219 - acc: 0.3679
# Epoch 86: val_acc did not improve from 0.40528
# 268/268 [==============================] - 3s 11ms/step - loss: 2.0245 - acc: 0.3684 - val_loss: 1.8266 - val_acc: 0.4013 - lr: 1.0000e-03
# Epoch 87/300
# 265/268 [============================>.] - ETA: 0s - loss: 2.0150 - acc: 0.3603
# Epoch 87: val_acc did not improve from 0.40528
# 268/268 [==============================] - 3s 11ms/step - loss: 2.0158 - acc: 0.3604 - val_loss: 1.8220 - val_acc: 0.4023 - lr: 1.0000e-03
# Epoch 88/300
# 266/268 [============================>.] - ETA: 0s - loss: 2.0187 - acc: 0.3599
# Epoch 88: val_acc did not improve from 0.40528
# 268/268 [==============================] - 3s 11ms/step - loss: 2.0184 - acc: 0.3593 - val_loss: 1.8189 - val_acc: 0.4028 - lr: 1.0000e-03
# Epoch 89/300
# 268/268 [==============================] - ETA: 0s - loss: 2.0191 - acc: 0.3694
# Epoch 89: val_acc did not improve from 0.40528
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0191 - acc: 0.3694 - val_loss: 1.8118 - val_acc: 0.4033 - lr: 1.0000e-03
# Epoch 90/300
# 268/268 [==============================] - ETA: 0s - loss: 2.0203 - acc: 0.3674
# Epoch 90: val_acc did not improve from 0.40528
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0203 - acc: 0.3674 - val_loss: 1.8134 - val_acc: 0.4043 - lr: 1.0000e-03
# Epoch 91/300
# 265/268 [============================>.] - ETA: 0s - loss: 1.9980 - acc: 0.3688
# Epoch 91: val_acc improved from 0.40528 to 0.40977, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0001 - acc: 0.3680 - val_loss: 1.8087 - val_acc: 0.4098 - lr: 1.0000e-03
# Epoch 92/300
# 265/268 [============================>.] - ETA: 0s - loss: 1.9999 - acc: 0.3688
# Epoch 92: val_acc improved from 0.40977 to 0.41276, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0019 - acc: 0.3682 - val_loss: 1.8081 - val_acc: 0.4128 - lr: 1.0000e-03
# Epoch 93/300
# 268/268 [==============================] - ETA: 0s - loss: 2.0200 - acc: 0.3647
# Epoch 93: val_acc did not improve from 0.41276
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0200 - acc: 0.3647 - val_loss: 1.8098 - val_acc: 0.3978 - lr: 1.0000e-03
# Epoch 94/300
# 265/268 [============================>.] - ETA: 0s - loss: 2.0003 - acc: 0.3678
# Epoch 94: val_acc did not improve from 0.41276
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0012 - acc: 0.3681 - val_loss: 1.8068 - val_acc: 0.4078 - lr: 1.0000e-03
# Epoch 95/300
# 264/268 [============================>.] - ETA: 0s - loss: 2.0036 - acc: 0.3674
# Epoch 95: val_acc did not improve from 0.41276
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0039 - acc: 0.3675 - val_loss: 1.8042 - val_acc: 0.3998 - lr: 1.0000e-03
# Epoch 96/300
# 264/268 [============================>.] - ETA: 0s - loss: 1.9924 - acc: 0.3736
# Epoch 96: val_acc did not improve from 0.41276
# 268/268 [==============================] - 3s 12ms/step - loss: 1.9905 - acc: 0.3736 - val_loss: 1.8040 - val_acc: 0.4093 - lr: 1.0000e-03
# Epoch 97/300
# 264/268 [============================>.] - ETA: 0s - loss: 2.0082 - acc: 0.3658
# Epoch 97: val_acc did not improve from 0.41276
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0120 - acc: 0.3641 - val_loss: 1.7974 - val_acc: 0.4093 - lr: 1.0000e-03
# Epoch 98/300
# 264/268 [============================>.] - ETA: 0s - loss: 2.0096 - acc: 0.3658
# Epoch 98: val_acc did not improve from 0.41276
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0077 - acc: 0.3667 - val_loss: 1.7995 - val_acc: 0.4083 - lr: 1.0000e-03
# Epoch 99/300
# 266/268 [============================>.] - ETA: 0s - loss: 2.0083 - acc: 0.3702
# Epoch 99: val_acc did not improve from 0.41276
# 268/268 [==============================] - 3s 11ms/step - loss: 2.0068 - acc: 0.3707 - val_loss: 1.7999 - val_acc: 0.4063 - lr: 1.0000e-03
# Epoch 100/300
# 264/268 [============================>.] - ETA: 0s - loss: 2.0014 - acc: 0.3665
# Epoch 100: val_acc did not improve from 0.41276
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9996 - acc: 0.3671 - val_loss: 1.7946 - val_acc: 0.4058 - lr: 1.0000e-03
# Epoch 101/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9997 - acc: 0.3672
# Epoch 101: val_acc did not improve from 0.41276
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9998 - acc: 0.3669 - val_loss: 1.7953 - val_acc: 0.4093 - lr: 1.0000e-03
# Epoch 102/300
# 264/268 [============================>.] - ETA: 0s - loss: 2.0059 - acc: 0.3667
# Epoch 102: val_acc did not improve from 0.41276
# 268/268 [==============================] - 3s 11ms/step - loss: 2.0069 - acc: 0.3656 - val_loss: 1.8045 - val_acc: 0.4028 - lr: 1.0000e-03
# Epoch 103/300
# 264/268 [============================>.] - ETA: 0s - loss: 1.9980 - acc: 0.3746
# Epoch 103: val_acc did not improve from 0.41276
# 268/268 [==============================] - 3s 12ms/step - loss: 1.9988 - acc: 0.3757 - val_loss: 1.8017 - val_acc: 0.4033 - lr: 1.0000e-03
# Epoch 104/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9963 - acc: 0.3715
# Epoch 104: val_acc did not improve from 0.41276
# 268/268 [==============================] - 3s 12ms/step - loss: 1.9962 - acc: 0.3719 - val_loss: 1.8101 - val_acc: 0.4053 - lr: 1.0000e-03
# Epoch 105/300
# 264/268 [============================>.] - ETA: 0s - loss: 1.9864 - acc: 0.3740
# Epoch 105: val_acc did not improve from 0.41276
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9833 - acc: 0.3746 - val_loss: 1.8092 - val_acc: 0.4083 - lr: 1.0000e-03
# Epoch 106/300
# 263/268 [============================>.] - ETA: 0s - loss: 1.9874 - acc: 0.3696
# Epoch 106: val_acc did not improve from 0.41276
# 268/268 [==============================] - 3s 12ms/step - loss: 1.9884 - acc: 0.3694 - val_loss: 1.7893 - val_acc: 0.4118 - lr: 1.0000e-03
# Epoch 107/300
# 266/268 [============================>.] - ETA: 0s - loss: 1.9838 - acc: 0.3774
# Epoch 107: val_acc did not improve from 0.41276
# 268/268 [==============================] - 3s 12ms/step - loss: 1.9833 - acc: 0.3772 - val_loss: 1.7882 - val_acc: 0.4113 - lr: 1.0000e-03
# Epoch 108/300
# 264/268 [============================>.] - ETA: 0s - loss: 1.9892 - acc: 0.3701
# Epoch 108: val_acc did not improve from 0.41276
# 268/268 [==============================] - 3s 12ms/step - loss: 1.9898 - acc: 0.3694 - val_loss: 1.7940 - val_acc: 0.4103 - lr: 1.0000e-03
# Epoch 109/300
# 265/268 [============================>.] - ETA: 0s - loss: 1.9903 - acc: 0.3696
# Epoch 109: val_acc did not improve from 0.41276
# 268/268 [==============================] - 3s 12ms/step - loss: 1.9882 - acc: 0.3697 - val_loss: 1.8118 - val_acc: 0.4073 - lr: 1.0000e-03
# Epoch 110/300
# 265/268 [============================>.] - ETA: 0s - loss: 2.0059 - acc: 0.3626
# Epoch 110: val_acc did not improve from 0.41276
# 268/268 [==============================] - 3s 12ms/step - loss: 2.0069 - acc: 0.3624 - val_loss: 1.7947 - val_acc: 0.4103 - lr: 1.0000e-03
# Epoch 111/300
# 266/268 [============================>.] - ETA: 0s - loss: 1.9914 - acc: 0.3756
# Epoch 111: val_acc did not improve from 0.41276
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9891 - acc: 0.3763 - val_loss: 1.8151 - val_acc: 0.4013 - lr: 1.0000e-03
# Epoch 112/300
# 266/268 [============================>.] - ETA: 0s - loss: 1.9864 - acc: 0.3728
# Epoch 112: val_acc did not improve from 0.41276
# 268/268 [==============================] - 3s 12ms/step - loss: 1.9855 - acc: 0.3730 - val_loss: 1.7914 - val_acc: 0.4093 - lr: 1.0000e-03
# Epoch 113/300
# 268/268 [==============================] - ETA: 0s - loss: 1.9878 - acc: 0.3778
# Epoch 113: val_acc did not improve from 0.41276
# 268/268 [==============================] - 3s 12ms/step - loss: 1.9878 - acc: 0.3778 - val_loss: 1.7898 - val_acc: 0.4093 - lr: 1.0000e-03
# Epoch 114/300
# 264/268 [============================>.] - ETA: 0s - loss: 1.9755 - acc: 0.3758
# Epoch 114: val_acc did not improve from 0.41276
# 268/268 [==============================] - 3s 12ms/step - loss: 1.9794 - acc: 0.3753 - val_loss: 1.8054 - val_acc: 0.4048 - lr: 1.0000e-03
# Epoch 115/300
# 263/268 [============================>.] - ETA: 0s - loss: 1.9923 - acc: 0.3705
# Epoch 115: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
#
# Epoch 115: val_acc did not improve from 0.41276
# 268/268 [==============================] - 3s 12ms/step - loss: 1.9899 - acc: 0.3709 - val_loss: 1.7885 - val_acc: 0.4058 - lr: 1.0000e-03
# Epoch 116/300
# 268/268 [==============================] - ETA: 0s - loss: 1.9573 - acc: 0.3755
# Epoch 116: val_acc improved from 0.41276 to 0.41525, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 1.9573 - acc: 0.3755 - val_loss: 1.7809 - val_acc: 0.4153 - lr: 1.0000e-04
# Epoch 117/300
# 264/268 [============================>.] - ETA: 0s - loss: 1.9598 - acc: 0.3793
# Epoch 117: val_acc did not improve from 0.41525
# 268/268 [==============================] - 3s 12ms/step - loss: 1.9615 - acc: 0.3792 - val_loss: 1.7775 - val_acc: 0.4143 - lr: 1.0000e-04
# Epoch 118/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9720 - acc: 0.3747
# Epoch 118: val_acc improved from 0.41525 to 0.41725, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 1.9717 - acc: 0.3750 - val_loss: 1.7740 - val_acc: 0.4172 - lr: 1.0000e-04
# Epoch 119/300
# 266/268 [============================>.] - ETA: 0s - loss: 1.9567 - acc: 0.3798
# Epoch 119: val_acc did not improve from 0.41725
# 268/268 [==============================] - 3s 12ms/step - loss: 1.9548 - acc: 0.3805 - val_loss: 1.7758 - val_acc: 0.4158 - lr: 1.0000e-04
# Epoch 120/300
# 264/268 [============================>.] - ETA: 0s - loss: 1.9761 - acc: 0.3761
# Epoch 120: val_acc improved from 0.41725 to 0.41974, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9737 - acc: 0.3765 - val_loss: 1.7730 - val_acc: 0.4197 - lr: 1.0000e-04
# Epoch 121/300
# 263/268 [============================>.] - ETA: 0s - loss: 1.9740 - acc: 0.3741
# Epoch 121: val_acc improved from 0.41974 to 0.42173, saving model to chkp/G_remake_v1_2_multipleRuns_seed_42.hdf5
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9741 - acc: 0.3750 - val_loss: 1.7735 - val_acc: 0.4217 - lr: 1.0000e-04
# Epoch 122/300
# 268/268 [==============================] - ETA: 0s - loss: 1.9553 - acc: 0.3751
# Epoch 122: val_acc did not improve from 0.42173
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9553 - acc: 0.3751 - val_loss: 1.7736 - val_acc: 0.4187 - lr: 1.0000e-04
# Epoch 123/300
# 268/268 [==============================] - ETA: 0s - loss: 1.9555 - acc: 0.3778
# Epoch 123: val_acc did not improve from 0.42173
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9555 - acc: 0.3778 - val_loss: 1.7730 - val_acc: 0.4192 - lr: 1.0000e-04
# Epoch 124/300
# 264/268 [============================>.] - ETA: 0s - loss: 1.9750 - acc: 0.3764
# Epoch 124: val_acc did not improve from 0.42173
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9720 - acc: 0.3768 - val_loss: 1.7735 - val_acc: 0.4143 - lr: 1.0000e-04
# Epoch 125/300
# 268/268 [==============================] - ETA: 0s - loss: 1.9689 - acc: 0.3792
# Epoch 125: val_acc did not improve from 0.42173
# 268/268 [==============================] - 3s 12ms/step - loss: 1.9689 - acc: 0.3792 - val_loss: 1.7748 - val_acc: 0.4167 - lr: 1.0000e-04
# Epoch 126/300
# 266/268 [============================>.] - ETA: 0s - loss: 1.9636 - acc: 0.3752
# Epoch 126: val_acc did not improve from 0.42173
# 268/268 [==============================] - 3s 12ms/step - loss: 1.9631 - acc: 0.3755 - val_loss: 1.7713 - val_acc: 0.4192 - lr: 1.0000e-04
# Epoch 127/300
# 266/268 [============================>.] - ETA: 0s - loss: 1.9626 - acc: 0.3794
# Epoch 127: val_acc did not improve from 0.42173
# 268/268 [==============================] - 3s 12ms/step - loss: 1.9629 - acc: 0.3792 - val_loss: 1.7742 - val_acc: 0.4197 - lr: 1.0000e-04
# Epoch 128/300
# 264/268 [============================>.] - ETA: 0s - loss: 1.9440 - acc: 0.3811
# Epoch 128: val_acc did not improve from 0.42173
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9422 - acc: 0.3807 - val_loss: 1.7737 - val_acc: 0.4187 - lr: 1.0000e-04
# Epoch 129/300
# 268/268 [==============================] - ETA: 0s - loss: 1.9557 - acc: 0.3786
# Epoch 129: val_acc did not improve from 0.42173
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9557 - acc: 0.3786 - val_loss: 1.7753 - val_acc: 0.4143 - lr: 1.0000e-04
# Epoch 130/300
# 266/268 [============================>.] - ETA: 0s - loss: 1.9654 - acc: 0.3807
# Epoch 130: val_acc did not improve from 0.42173
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9649 - acc: 0.3807 - val_loss: 1.7730 - val_acc: 0.4192 - lr: 1.0000e-04
# Epoch 131/300
# 265/268 [============================>.] - ETA: 0s - loss: 1.9779 - acc: 0.3777
# Epoch 131: val_acc did not improve from 0.42173
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9752 - acc: 0.3783 - val_loss: 1.7736 - val_acc: 0.4182 - lr: 1.0000e-04
# Epoch 132/300
# 265/268 [============================>.] - ETA: 0s - loss: 1.9635 - acc: 0.3858
# Epoch 132: val_acc did not improve from 0.42173
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9641 - acc: 0.3856 - val_loss: 1.7728 - val_acc: 0.4172 - lr: 1.0000e-04
# Epoch 133/300
# 264/268 [============================>.] - ETA: 0s - loss: 1.9549 - acc: 0.3804
# Epoch 133: val_acc did not improve from 0.42173
# 268/268 [==============================] - 3s 12ms/step - loss: 1.9530 - acc: 0.3805 - val_loss: 1.7740 - val_acc: 0.4187 - lr: 1.0000e-04
# Epoch 134/300
# 263/268 [============================>.] - ETA: 0s - loss: 1.9494 - acc: 0.3837
# Epoch 134: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
#
# Epoch 134: val_acc did not improve from 0.42173
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9533 - acc: 0.3837 - val_loss: 1.7740 - val_acc: 0.4182 - lr: 1.0000e-04
# Epoch 135/300
# 265/268 [============================>.] - ETA: 0s - loss: 1.9576 - acc: 0.3760
# Epoch 135: val_acc did not improve from 0.42173
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9567 - acc: 0.3770 - val_loss: 1.7725 - val_acc: 0.4207 - lr: 1.0000e-05
# Epoch 136/300
# 264/268 [============================>.] - ETA: 0s - loss: 1.9686 - acc: 0.3793
# Epoch 136: val_acc did not improve from 0.42173
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9678 - acc: 0.3803 - val_loss: 1.7732 - val_acc: 0.4177 - lr: 1.0000e-05
# Epoch 137/300
# 268/268 [==============================] - ETA: 0s - loss: 1.9585 - acc: 0.3777
# Epoch 137: val_acc did not improve from 0.42173
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9585 - acc: 0.3777 - val_loss: 1.7723 - val_acc: 0.4212 - lr: 1.0000e-05
# Epoch 138/300
# 266/268 [============================>.] - ETA: 0s - loss: 1.9535 - acc: 0.3793
# Epoch 138: val_acc did not improve from 0.42173
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9544 - acc: 0.3791 - val_loss: 1.7726 - val_acc: 0.4217 - lr: 1.0000e-05
# Epoch 138: early stopping
#
# Running model with seed 123
# Train Data Scenario Counts:
# scenario32 - LoS samples count: 2729, NLoS samples count: 109
# scenario33 - LoS samples count: 3322, NLoS samples count: 119
# scenario34 - LoS samples count: 3652, NLoS samples count: 97
#
# Test Data Scenario Counts:
# scenario32 - LoS samples count: 265, NLoS samples count: 12
# scenario33 - LoS samples count: 379, NLoS samples count: 17
# scenario34 - LoS samples count: 430, NLoS samples count: 12
# LoS Train Shape: (9703, 5, 2), LoS Test Shape: (1074, 5, 2)
# NLoS Train Shape: (325, 5, 2), NLoS Test Shape: (41, 5, 2)
# Train Labels Shape: (10028, 64)
# Test Labels Shape: (1115, 64)
# Train LoS Labels Shape: (9703, 64)
# Train NLoS Labels Shape: (325, 64)
# Test LoS Labels Shape: (1074, 64)
# Test NLoS Labels Shape: (41, 64)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 64)                13056
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
# =================================================================
# Total params: 17,216
# Trainable params: 17,216
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/300
# 266/268 [============================>.] - ETA: 0s - loss: 3.6406 - acc: 0.0877
# Epoch 1: val_acc improved from -inf to 0.11366, saving model to chkp/G_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 6s 14ms/step - loss: 3.6405 - acc: 0.0876 - val_loss: 3.3724 - val_acc: 0.1137 - lr: 0.0100
# Epoch 2/300
# 264/268 [============================>.] - ETA: 0s - loss: 3.3867 - acc: 0.1135
# Epoch 2: val_acc improved from 0.11366 to 0.11565, saving model to chkp/G_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 3s 12ms/step - loss: 3.3854 - acc: 0.1136 - val_loss: 3.2406 - val_acc: 0.1157 - lr: 0.0100
# Epoch 3/300
# 263/268 [============================>.] - ETA: 0s - loss: 3.2629 - acc: 0.1255
# Epoch 3: val_acc did not improve from 0.11565
# 268/268 [==============================] - 3s 11ms/step - loss: 3.2660 - acc: 0.1253 - val_loss: 3.2944 - val_acc: 0.1007 - lr: 0.0100
# Epoch 4/300
# 263/268 [============================>.] - ETA: 0s - loss: 3.1757 - acc: 0.1290
# Epoch 4: val_acc improved from 0.11565 to 0.19591, saving model to chkp/G_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 3s 11ms/step - loss: 3.1734 - acc: 0.1290 - val_loss: 2.8722 - val_acc: 0.1959 - lr: 0.0100
# Epoch 5/300
# 263/268 [============================>.] - ETA: 0s - loss: 3.0178 - acc: 0.1565
# Epoch 5: val_acc did not improve from 0.19591
# 268/268 [==============================] - 3s 11ms/step - loss: 3.0161 - acc: 0.1568 - val_loss: 2.8360 - val_acc: 0.1685 - lr: 0.0100
# Epoch 6/300
# 266/268 [============================>.] - ETA: 0s - loss: 2.9134 - acc: 0.1633
# Epoch 6: val_acc improved from 0.19591 to 0.21186, saving model to chkp/G_remake_v1_2_multipleRuns_seed_123.hdf5
# 268/268 [==============================] - 3s 11ms/step - loss: 2.9132 - acc: 0.1633 - val_loss: 2.6207 - val_acc: 0.2119 - lr: 0.0100
# Epoch 7/300
# 266/268 [============================>.] - ETA: 0s - loss: 2.8338 - acc: 0.1749
# Epoch 7: val_acc did not improve from 0.21186
# 268/268 [==============================] - 3s 11ms/step - loss: 2.8338 - acc: 0.1759 - val_loss: 2.8051 - val_acc: 0.1879 - lr: 0.0100
# Epoch 8/300
# 268/268 [==============================] - ETA: 0s - loss: 2.7725 - acc: 0.1814
# Epoch 8: val_acc improved from 0.21186 to 0.26720, saving model to chkp/G_remake_v1_2_multipleRuns_seed_123.hdf5
# ...
# Epoch 119/300
# 264/268 [============================>.] - ETA: 0s - loss: 1.9861 - acc: 0.3699
# Epoch 119: val_acc did not improve from 0.41825
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9896 - acc: 0.3699 - val_loss: 1.8490 - val_acc: 0.3988 - lr: 1.0000e-03
# Epoch 120/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9818 - acc: 0.3665
# Epoch 120: val_acc did not improve from 0.41825
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9812 - acc: 0.3669 - val_loss: 1.8309 - val_acc: 0.4108 - lr: 1.0000e-03
# Epoch 121/300
# 265/268 [============================>.] - ETA: 0s - loss: 1.9938 - acc: 0.3678
# Epoch 121: val_acc did not improve from 0.41825
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9943 - acc: 0.3675 - val_loss: 1.8470 - val_acc: 0.4108 - lr: 1.0000e-03
# Epoch 122/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9906 - acc: 0.3668
# Epoch 122: val_acc did not improve from 0.41825
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9907 - acc: 0.3669 - val_loss: 1.8218 - val_acc: 0.4167 - lr: 1.0000e-03
# Epoch 123/300
# 263/268 [============================>.] - ETA: 0s - loss: 1.9620 - acc: 0.3670
# Epoch 123: val_acc did not improve from 0.41825
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9670 - acc: 0.3664 - val_loss: 1.8242 - val_acc: 0.4138 - lr: 1.0000e-03
# Epoch 124/300
# 263/268 [============================>.] - ETA: 0s - loss: 1.9755 - acc: 0.3730
# Epoch 124: val_acc did not improve from 0.41825
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9723 - acc: 0.3747 - val_loss: 1.8355 - val_acc: 0.4163 - lr: 1.0000e-03
# Epoch 125/300
# 266/268 [============================>.] - ETA: 0s - loss: 1.9888 - acc: 0.3707
# Epoch 125: val_acc did not improve from 0.41825
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9881 - acc: 0.3709 - val_loss: 1.8244 - val_acc: 0.4167 - lr: 1.0000e-03
# Epoch 126/300
# 263/268 [============================>.] - ETA: 0s - loss: 1.9786 - acc: 0.3662
# Epoch 126: val_acc improved from 0.41825 to 0.41874, saving model to chkp/G_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9795 - acc: 0.3652 - val_loss: 1.8208 - val_acc: 0.4187 - lr: 1.0000e-03
# Epoch 127/300
# 266/268 [============================>.] - ETA: 0s - loss: 1.9667 - acc: 0.3754
# Epoch 127: val_acc did not improve from 0.41874
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9667 - acc: 0.3753 - val_loss: 1.8210 - val_acc: 0.4098 - lr: 1.0000e-03
# Epoch 128/300
# 265/268 [============================>.] - ETA: 0s - loss: 1.9782 - acc: 0.3689
# Epoch 128: val_acc did not improve from 0.41874
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9776 - acc: 0.3686 - val_loss: 1.8351 - val_acc: 0.4078 - lr: 1.0000e-03
# Epoch 129/300
# 264/268 [============================>.] - ETA: 0s - loss: 1.9683 - acc: 0.3689
# Epoch 129: val_acc did not improve from 0.41874
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9697 - acc: 0.3692 - val_loss: 1.8379 - val_acc: 0.4043 - lr: 1.0000e-03
# Epoch 130/300
# 268/268 [==============================] - ETA: 0s - loss: 1.9598 - acc: 0.3783
# Epoch 130: val_acc did not improve from 0.41874
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9598 - acc: 0.3783 - val_loss: 1.8399 - val_acc: 0.4113 - lr: 1.0000e-03
# Epoch 131/300
# 264/268 [============================>.] - ETA: 0s - loss: 1.9623 - acc: 0.3784
# Epoch 131: val_acc did not improve from 0.41874
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9651 - acc: 0.3771 - val_loss: 1.8267 - val_acc: 0.4153 - lr: 1.0000e-03
# Epoch 132/300
# 263/268 [============================>.] - ETA: 0s - loss: 1.9728 - acc: 0.3767
# Epoch 132: val_acc did not improve from 0.41874
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9711 - acc: 0.3763 - val_loss: 1.8102 - val_acc: 0.4172 - lr: 1.0000e-03
# Epoch 133/300
# 264/268 [============================>.] - ETA: 0s - loss: 1.9621 - acc: 0.3720
# Epoch 133: val_acc did not improve from 0.41874
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9650 - acc: 0.3735 - val_loss: 1.8181 - val_acc: 0.4172 - lr: 1.0000e-03
# Epoch 134/300
# 266/268 [============================>.] - ETA: 0s - loss: 1.9534 - acc: 0.3742
# Epoch 134: val_acc improved from 0.41874 to 0.41974, saving model to chkp/G_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9532 - acc: 0.3742 - val_loss: 1.8129 - val_acc: 0.4197 - lr: 1.0000e-03
# Epoch 135/300
# 263/268 [============================>.] - ETA: 0s - loss: 1.9446 - acc: 0.3783
# Epoch 135: val_acc did not improve from 0.41974
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9432 - acc: 0.3786 - val_loss: 1.8182 - val_acc: 0.4123 - lr: 1.0000e-03
# Epoch 136/300
# 266/268 [============================>.] - ETA: 0s - loss: 1.9638 - acc: 0.3689
# Epoch 136: val_acc did not improve from 0.41974
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9628 - acc: 0.3692 - val_loss: 1.8153 - val_acc: 0.4108 - lr: 1.0000e-03
# Epoch 137/300
# 265/268 [============================>.] - ETA: 0s - loss: 1.9591 - acc: 0.3821
# Epoch 137: val_acc did not improve from 0.41974
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9593 - acc: 0.3815 - val_loss: 1.8234 - val_acc: 0.4088 - lr: 1.0000e-03
# Epoch 138/300
# 264/268 [============================>.] - ETA: 0s - loss: 1.9558 - acc: 0.3711
# Epoch 138: val_acc did not improve from 0.41974
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9606 - acc: 0.3715 - val_loss: 1.8130 - val_acc: 0.4177 - lr: 1.0000e-03
# Epoch 139/300
# 263/268 [============================>.] - ETA: 0s - loss: 1.9569 - acc: 0.3778
# Epoch 139: val_acc did not improve from 0.41974
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9554 - acc: 0.3777 - val_loss: 1.8038 - val_acc: 0.4197 - lr: 1.0000e-03
# Epoch 140/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9548 - acc: 0.3798
# Epoch 140: val_acc did not improve from 0.41974
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9551 - acc: 0.3797 - val_loss: 1.8123 - val_acc: 0.4187 - lr: 1.0000e-03
# Epoch 141/300
# 265/268 [============================>.] - ETA: 0s - loss: 1.9720 - acc: 0.3725
# Epoch 141: val_acc did not improve from 0.41974
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9699 - acc: 0.3735 - val_loss: 1.8066 - val_acc: 0.4167 - lr: 1.0000e-03
# Epoch 142/300
# 265/268 [============================>.] - ETA: 0s - loss: 1.9453 - acc: 0.3681
# Epoch 142: val_acc did not improve from 0.41974
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9444 - acc: 0.3679 - val_loss: 1.8059 - val_acc: 0.4163 - lr: 1.0000e-03
# Epoch 143/300
# 266/268 [============================>.] - ETA: 0s - loss: 1.9572 - acc: 0.3746
# Epoch 143: val_acc did not improve from 0.41974
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9566 - acc: 0.3747 - val_loss: 1.8074 - val_acc: 0.4163 - lr: 1.0000e-03
# Epoch 144/300
# 266/268 [============================>.] - ETA: 0s - loss: 1.9438 - acc: 0.3846
# Epoch 144: val_acc did not improve from 0.41974
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9441 - acc: 0.3842 - val_loss: 1.8171 - val_acc: 0.4133 - lr: 1.0000e-03
# Epoch 145/300
# 265/268 [============================>.] - ETA: 0s - loss: 1.9566 - acc: 0.3776
# Epoch 145: val_acc improved from 0.41974 to 0.42124, saving model to chkp/G_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9576 - acc: 0.3777 - val_loss: 1.8041 - val_acc: 0.4212 - lr: 1.0000e-03
# Epoch 146/300
# 266/268 [============================>.] - ETA: 0s - loss: 1.9573 - acc: 0.3776
# Epoch 146: val_acc did not improve from 0.42124
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9564 - acc: 0.3782 - val_loss: 1.8150 - val_acc: 0.4118 - lr: 1.0000e-03
# Epoch 147/300
# 264/268 [============================>.] - ETA: 0s - loss: 1.9463 - acc: 0.3801
# Epoch 147: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
#
# Epoch 147: val_acc did not improve from 0.42124
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9498 - acc: 0.3801 - val_loss: 1.8058 - val_acc: 0.4113 - lr: 1.0000e-03
# Epoch 148/300
# 264/268 [============================>.] - ETA: 0s - loss: 1.9445 - acc: 0.3878
# Epoch 148: val_acc did not improve from 0.42124
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9441 - acc: 0.3869 - val_loss: 1.7976 - val_acc: 0.4163 - lr: 1.0000e-04
# Epoch 149/300
# 264/268 [============================>.] - ETA: 0s - loss: 1.9426 - acc: 0.3881
# Epoch 149: val_acc did not improve from 0.42124
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9399 - acc: 0.3888 - val_loss: 1.8000 - val_acc: 0.4167 - lr: 1.0000e-04
# Epoch 150/300
# 265/268 [============================>.] - ETA: 0s - loss: 1.9266 - acc: 0.3787
# Epoch 150: val_acc did not improve from 0.42124
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9256 - acc: 0.3795 - val_loss: 1.7956 - val_acc: 0.4202 - lr: 1.0000e-04
# Epoch 151/300
# 264/268 [============================>.] - ETA: 0s - loss: 1.9246 - acc: 0.3896
# Epoch 151: val_acc did not improve from 0.42124
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9262 - acc: 0.3898 - val_loss: 1.7973 - val_acc: 0.4138 - lr: 1.0000e-04
# Epoch 152/300
# 263/268 [============================>.] - ETA: 0s - loss: 1.9255 - acc: 0.3843
# Epoch 152: val_acc did not improve from 0.42124
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9258 - acc: 0.3834 - val_loss: 1.7955 - val_acc: 0.4202 - lr: 1.0000e-04
# Epoch 153/300
# 263/268 [============================>.] - ETA: 0s - loss: 1.9326 - acc: 0.3847
# Epoch 153: val_acc did not improve from 0.42124
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9340 - acc: 0.3846 - val_loss: 1.7957 - val_acc: 0.4167 - lr: 1.0000e-04
# Epoch 154/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9262 - acc: 0.3809
# Epoch 154: val_acc did not improve from 0.42124
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9258 - acc: 0.3812 - val_loss: 1.7948 - val_acc: 0.4182 - lr: 1.0000e-04
# Epoch 155/300
# 268/268 [==============================] - ETA: 0s - loss: 1.9365 - acc: 0.3847
# Epoch 155: val_acc did not improve from 0.42124
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9365 - acc: 0.3847 - val_loss: 1.7939 - val_acc: 0.4163 - lr: 1.0000e-04
# Epoch 156/300
# 268/268 [==============================] - ETA: 0s - loss: 1.9372 - acc: 0.3808
# Epoch 156: val_acc did not improve from 0.42124
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9372 - acc: 0.3808 - val_loss: 1.7949 - val_acc: 0.4202 - lr: 1.0000e-04
# Epoch 157/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9229 - acc: 0.3906
# Epoch 157: val_acc did not improve from 0.42124
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9226 - acc: 0.3907 - val_loss: 1.7943 - val_acc: 0.4167 - lr: 1.0000e-04
# Epoch 158/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9082 - acc: 0.3855
# Epoch 158: val_acc improved from 0.42124 to 0.42273, saving model to chkp/G_remake_v1_2_multipleRuns_seed_101112.hdf5
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9092 - acc: 0.3854 - val_loss: 1.7925 - val_acc: 0.4227 - lr: 1.0000e-04
# Epoch 159/300
# 266/268 [============================>.] - ETA: 0s - loss: 1.9185 - acc: 0.3906
# Epoch 159: val_acc did not improve from 0.42273
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9189 - acc: 0.3908 - val_loss: 1.7939 - val_acc: 0.4172 - lr: 1.0000e-04
# Epoch 160/300
# 268/268 [==============================] - ETA: 0s - loss: 1.9243 - acc: 0.3783
# Epoch 160: val_acc did not improve from 0.42273
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9243 - acc: 0.3783 - val_loss: 1.7916 - val_acc: 0.4172 - lr: 1.0000e-04
# Epoch 161/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9238 - acc: 0.3760
# Epoch 161: val_acc did not improve from 0.42273
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9234 - acc: 0.3760 - val_loss: 1.7915 - val_acc: 0.4207 - lr: 1.0000e-04
# Epoch 162/300
# 265/268 [============================>.] - ETA: 0s - loss: 1.9382 - acc: 0.3809
# Epoch 162: val_acc did not improve from 0.42273
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9371 - acc: 0.3816 - val_loss: 1.7915 - val_acc: 0.4197 - lr: 1.0000e-04
# Epoch 163/300
# 268/268 [==============================] - ETA: 0s - loss: 1.9388 - acc: 0.3821
# Epoch 163: val_acc did not improve from 0.42273
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9388 - acc: 0.3821 - val_loss: 1.7981 - val_acc: 0.4207 - lr: 1.0000e-04
# Epoch 164/300
# 265/268 [============================>.] - ETA: 0s - loss: 1.9399 - acc: 0.3838
# Epoch 164: val_acc did not improve from 0.42273
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9384 - acc: 0.3838 - val_loss: 1.7944 - val_acc: 0.4158 - lr: 1.0000e-04
# Epoch 165/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9255 - acc: 0.3869
# Epoch 165: val_acc did not improve from 0.42273
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9250 - acc: 0.3871 - val_loss: 1.7935 - val_acc: 0.4187 - lr: 1.0000e-04
# Epoch 166/300
# 264/268 [============================>.] - ETA: 0s - loss: 1.9310 - acc: 0.3830
# Epoch 166: val_acc did not improve from 0.42273
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9320 - acc: 0.3829 - val_loss: 1.7924 - val_acc: 0.4212 - lr: 1.0000e-04
# Epoch 167/300
# 268/268 [==============================] - ETA: 0s - loss: 1.9238 - acc: 0.3813
# Epoch 167: val_acc did not improve from 0.42273
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9238 - acc: 0.3813 - val_loss: 1.7926 - val_acc: 0.4192 - lr: 1.0000e-04
# Epoch 168/300
# 267/268 [============================>.] - ETA: 0s - loss: 1.9241 - acc: 0.3815
# Epoch 168: val_acc did not improve from 0.42273
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9230 - acc: 0.3819 - val_loss: 1.7922 - val_acc: 0.4202 - lr: 1.0000e-04
# Epoch 169/300
# 266/268 [============================>.] - ETA: 0s - loss: 1.9301 - acc: 0.3838
# Epoch 169: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
#
# Epoch 169: val_acc did not improve from 0.42273
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9298 - acc: 0.3837 - val_loss: 1.7929 - val_acc: 0.4202 - lr: 1.0000e-04
# Epoch 170/300
# 263/268 [============================>.] - ETA: 0s - loss: 1.9151 - acc: 0.3829
# Epoch 170: val_acc did not improve from 0.42273
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9162 - acc: 0.3829 - val_loss: 1.7928 - val_acc: 0.4182 - lr: 1.0000e-05
# Epoch 171/300
# 263/268 [============================>.] - ETA: 0s - loss: 1.9383 - acc: 0.3897
# Epoch 171: val_acc did not improve from 0.42273
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9355 - acc: 0.3894 - val_loss: 1.7929 - val_acc: 0.4187 - lr: 1.0000e-05
# Epoch 172/300
# 266/268 [============================>.] - ETA: 0s - loss: 1.9194 - acc: 0.3789
# Epoch 172: val_acc did not improve from 0.42273
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9182 - acc: 0.3791 - val_loss: 1.7927 - val_acc: 0.4192 - lr: 1.0000e-05
# Epoch 173/300
# 265/268 [============================>.] - ETA: 0s - loss: 1.9212 - acc: 0.3862
# Epoch 173: val_acc did not improve from 0.42273
# 268/268 [==============================] - 3s 11ms/step - loss: 1.9189 - acc: 0.3871 - val_loss: 1.7929 - val_acc: 0.4192 - lr: 1.0000e-05
# Epoch 173: early stopping

# %%
#%% Test on all scens together
#%%Test on Train and Test data (top-1,2,3)

# Model evaluation and prediction
def evaluate_model(model, X_data, y_data, pwrs_array, data_type, result_list, sample_indices):
    predictions = model.predict(X_data)
    y_pred = np.argsort(predictions, axis=1)[:, ::-1]
    save_pred_to_csv(sample_indices, y_pred, top_k=[1,2,3], target_csv=f'preds_{model_name}_{data_type}.csv')
    true = np.argmax(y_data, axis=1).reshape(-1, 1)
    acc = compute_acc(y_pred, true, top_k=[1, 3, 5])
    score = compute_DBA_score(y_pred, true, max_k=3, delta=5)
    recall = recall_score(true, y_pred[:, 0], average='weighted')
    precision = precision_score(true, y_pred[:, 0], average='weighted')
    PF_mean = compute_powerfactor(y_pred, pwrs_array, k=3)
    top_beams = calculate_top_beams(predictions, pwrs_array)
   
    result_list.append({
        'type': data_type,
        'acc': acc,
        'score': round(score, 2),
        'top31_beam': top_beams[0],
        'top33_beam': top_beams[1],
        'PF1_mean': PF_mean[0],
        'PF2_mean': PF_mean[1],
        'PF3_mean': PF_mean[2],
        'recall': round(recall, 2),
        'precision': round(precision, 2)
    })


# Define the seeds used for training
seeds = [42, 123, 456, 789, 101112]

# Placeholder for storing results from all seeds
all_results = []

for seed in seeds:
    print(f"\nEvaluating model with seed {seed}")

    # Train-Test Split with the current seed
    X_train, X_test, y_train, y_test, train_indices, test_indices = train_test_split(
        GPS, classes, np.arange(len(GPS)), test_size=0.1, stratify=classes, random_state=seed)

    gc.collect()

    # Reload the scenario data
    df_train = pd.read_csv('./ml_challenge_dev_multi_modal_v3_all_scenarios_with_LoS_status.csv')

    # Find LoS and NLoS samples in the train and test indices
    train_los_indices = df_train[df_train['LoS_status'] == 'LoS'].index.intersection(train_indices)
    train_nlos_indices = df_train[df_train['LoS_status'] == 'NLoS'].index.intersection(train_indices)
    test_los_indices = df_train[df_train['LoS_status'] == 'LoS'].index.intersection(test_indices)
    test_nlos_indices = df_train[df_train['LoS_status'] == 'NLoS'].index.intersection(test_indices)

    # Extract LoS and NLoS samples from the data and classes
    X_test_los = GPS[test_los_indices]
    X_test_nlos = GPS[test_nlos_indices]
    y_test_los = classes[test_los_indices]
    y_test_nlos = classes[test_nlos_indices]

    # Power analysis - make sure to get the correct power arrays for each seed
    N_CLASSES = 64
    pwrs_array = np.zeros((df_train.shape[0], N_CLASSES))
    for sample_idx in range(df_train.shape[0]):
        pwr_abs_path = df_train['unit1_pwr_60ghz'].values[sample_idx]
        pwrs_array[sample_idx] = np.loadtxt(pwr_abs_path)

    pwrs_array[np.isnan(pwrs_array)] = 0
    pwrs_array_train = pwrs_array[train_indices]
    pwrs_array_test_los = pwrs_array[test_los_indices]
    pwrs_array_test_nlos = pwrs_array[test_nlos_indices]

    # Load the model corresponding to the current seed
    model = load_model(f'chkp/{model_name}_seed_{seed}.hdf5')

    # Initialize results list for the current seed
    seed_results = []

    # Evaluate on training data
    evaluate_model(model, X_train, y_train, pwrs_array_train, 'Train', seed_results, train_indices)

    # Evaluate on test data
    evaluate_model(model, X_test_los, y_test_los, pwrs_array_test_los, 'Test_LoS', seed_results, test_los_indices)
    evaluate_model(model, X_test_nlos, y_test_nlos, pwrs_array_test_nlos, 'Test_NLoS', seed_results, test_nlos_indices)

    # Store the results of this seed in all_results
    all_results.append(seed_results)

# Function to average results across all seeds
def average_results(all_results, metric):
    averages = {}
    types = ['Train', 'Test_LoS', 'Test_NLoS']
    for data_type in types:
        type_results = [res for seed_res in all_results for res in seed_res if res['type'] == data_type]
        avg_metric = np.mean([res[metric] for res in type_results], axis=0)
        std_metric = np.std([res[metric] for res in type_results], axis=0)
        averages[data_type] = (avg_metric, std_metric)
    return averages

# Compute averages and standard deviations for each metric
avg_accuracies = average_results(all_results, 'acc')
avg_scores = average_results(all_results, 'score')
avg_top31_beams = average_results(all_results, 'top31_beam')
avg_top33_beams = average_results(all_results, 'top33_beam')
avg_PF1_means = average_results(all_results, 'PF1_mean')
avg_PF2_means = average_results(all_results, 'PF2_mean')
avg_PF3_means = average_results(all_results, 'PF3_mean')
avg_recalls = average_results(all_results, 'recall')
avg_precisions = average_results(all_results, 'precision')

# Print the average results across all seeds
print("\nAverage Results Across All Seeds:")
for data_type in avg_accuracies:
    print(f"Type: {data_type} - Avg Accuracies: {avg_accuracies[data_type][0]} ± {avg_accuracies[data_type][1]}, "
          f"Avg Score: {avg_scores[data_type][0]} ± {avg_scores[data_type][1]}, "
          f"top31_beam: {avg_top31_beams[data_type][0]} ± {avg_top31_beams[data_type][1]}, "
          f"top33_beam: {avg_top33_beams[data_type][0]} ± {avg_top33_beams[data_type][1]}, "
          f"PF1_mean: {avg_PF1_means[data_type][0]} ± {avg_PF1_means[data_type][1]}, "
          f"PF2_mean: {avg_PF2_means[data_type][0]} ± {avg_PF2_means[data_type][1]}, "
          f"PF3_mean: {avg_PF3_means[data_type][0]} ± {avg_PF3_means[data_type][1]}, "
          f"Recall: {avg_recalls[data_type][0]} ± {avg_recalls[data_type][1]}, "
          f"Precision: {avg_precisions[data_type][0]} ± {avg_precisions[data_type][1]}")

gc.collect()
# Out:
# Evaluating model with seed 42
# 2024-08-24 23:58:01.964860: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2024-08-24 23:58:01.964916: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: edison
# 2024-08-24 23:58:01.964923: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: edison
# 2024-08-24 23:58:01.965163: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 560.35.3
# 2024-08-24 23:58:01.965206: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: NOT_FOUND: could not find kernel module information in driver version file contents: "NVRM version: NVIDIA UNIX Open Kernel Module for x86_64  560.35.03  Release Build  (dvs-builder@U16-I1-N07-12-3)  Fri Aug 16 21:42:42 UTC 2024
# GCC version:  gcc version 11.4.0 (Ubuntu 11.4.0-1ubuntu1~22.04)
# "
# 2024-08-24 23:58:01.965671: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 314/314 [==============================] - 2s 4ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 34/34 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 5ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Evaluating model with seed 123
# 314/314 [==============================] - 2s 4ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 34/34 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Evaluating model with seed 456
# 314/314 [==============================] - 1s 4ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 34/34 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 5ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Evaluating model with seed 789
# 314/314 [==============================] - 2s 5ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 34/34 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Evaluating model with seed 101112
# 314/314 [==============================] - 1s 3ms/step
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 34/34 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
#
# Average Results Across All Seeds:
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sa457043/miniconda3/envs/tf_jupyter/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Type: Train - Avg Accuracies: [0.44626 0.80392 0.9087 ] ± [0.00748935 0.01105539 0.0060663 ], Avg Score: 0.8620000000000001 ± 0.00748331477354789, top31_beam: 0.796 ± 0.008000000000000007, top33_beam: 0.9480000000000001 ± 0.004000000000000004, PF1_mean: 0.97 ± 0.0, PF2_mean: 0.9880000000000001 ± 0.004000000000000004, PF3_mean: 0.99 ± 0.0, Recall: 0.44800000000000006 ± 0.007483314773547889, Precision: 0.37 ± 0.016733200530681506
# Type: Test_LoS - Avg Accuracies: [0.45176 0.81314 0.92382] ± [0.0120016  0.01234416 0.00727335], Avg Score: 0.8780000000000001 ± 0.007483314773547889, top31_beam: 0.8119999999999999 ± 0.01939071942966528, top33_beam: 0.9639999999999999 ± 0.008000000000000007, PF1_mean: 0.97 ± 0.0, PF2_mean: 0.9880000000000001 ± 0.004000000000000004, PF3_mean: 0.99 ± 0.0, Recall: 0.45200000000000007 ± 0.013266499161421596, Precision: 0.35200000000000004 ± 0.011661903789690587
# Type: Test_NLoS - Avg Accuracies: [0.00942 0.05848 0.0821 ] ± [0.01154961 0.02948216 0.01865626], Avg Score: 0.07999999999999999 ± 0.01414213562373095, top31_beam: 0.282 ± 0.05455272678794343, top33_beam: 0.40800000000000003 ± 0.05418486873657627, PF1_mean: 0.8940000000000001 ± 0.004898979485566361, PF2_mean: 0.914 ± 0.00489897948556636, PF3_mean: 0.9179999999999999 ± 0.011661903789690568, Recall: 0.008 ± 0.009797958971132711, Precision: 0.006 ± 0.008
# 5726

# %%
# Define a function to format mean ± std
def format_mean_std(mean, std):
    return f"{mean:.2f} ± {std:.2f}"

# Initialize the final results list
formatted_results = []

# Process the results for saving
for data_type in avg_accuracies:
    acc_means, acc_stds = avg_accuracies[data_type]
    row = {
        'Type': data_type,
        'Acc': ', '.join([format_mean_std(m, s) for m, s in zip(acc_means, acc_stds)]),
        'Score': format_mean_std(*avg_scores[data_type]),
        'top31_beam': format_mean_std(*avg_top31_beams[data_type]),
        'top33_beam': format_mean_std(*avg_top33_beams[data_type]),
        'PF1_mean': format_mean_std(*avg_PF1_means[data_type]),
        'PF2_mean': format_mean_std(*avg_PF2_means[data_type]),
        'PF3_mean': format_mean_std(*avg_PF3_means[data_type]),
        'Recall': format_mean_std(*avg_recalls[data_type]),
        'Precision': format_mean_std(*avg_precisions[data_type])
    }
    formatted_results.append(row)

# Convert the list to a DataFrame
df = pd.DataFrame(formatted_results)

# Save to CSV
df.to_csv(f'results_{model_name}_AllScens.csv', index=False)

print("Results saved to CSV:")
print(df)
# Out:
# Results saved to CSV:
#         Type                                    Acc        Score   top31_beam  \
# 0      Train  0.45 ± 0.01, 0.80 ± 0.01, 0.91 ± 0.01  0.86 ± 0.01  0.80 ± 0.01
# 1   Test_LoS  0.45 ± 0.01, 0.81 ± 0.01, 0.92 ± 0.01  0.88 ± 0.01  0.81 ± 0.02
# 2  Test_NLoS  0.01 ± 0.01, 0.06 ± 0.03, 0.08 ± 0.02  0.08 ± 0.01  0.28 ± 0.05
#
#     top33_beam     PF1_mean     PF2_mean     PF3_mean       Recall  \
# 0  0.95 ± 0.00  0.97 ± 0.00  0.99 ± 0.00  0.99 ± 0.00  0.45 ± 0.01
# 1  0.96 ± 0.01  0.97 ± 0.00  0.99 ± 0.00  0.99 ± 0.00  0.45 ± 0.01
# 2  0.41 ± 0.05  0.89 ± 0.00  0.91 ± 0.00  0.92 ± 0.01  0.01 ± 0.01
#
#      Precision
# 0  0.37 ± 0.02
# 1  0.35 ± 0.01
# 2  0.01 ± 0.01
